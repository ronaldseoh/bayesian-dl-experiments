# %% [markdown]
# ## Experiment Setup

# %% [markdown]
# ### Random seed / PyTorch / CUDA related

# %%
import torch
import numpy as np

# Google Colab-only setup.
use_colab = True

# Is this running on Colab?
import importlib
colab_available = importlib.util.find_spec("google.colab") is not None

if use_colab and colab_available:
    # Mount my Google Drive root folder
    from google.colab import drive
    drive.mount('/content/drive')

    # cd to bayesian-dl-experiments directory
    # %cd 'drive/My Drive/Colab Notebooks/bayesian-dl-experiments'
    # !ls

# IPython reloading magic
# %load_ext autoreload
# %autoreload 2

# Random seeds
# Based on https://pytorch.org/docs/stable/notes/randomness.html
torch.manual_seed(682)
np.random.seed(682)

# torch.device / CUDA Setup
use_cuda = True

if use_cuda and torch.cuda.is_available():
    torch_device = torch.device('cuda')
    torch.backends.cudnn.deterministic = True
    # Note: https://discuss.pytorch.org/t/what-does-torch-backends-cudnn-benchmark-do/5936
    torch.backends.cudnn.benchmark = False
    use_pin_memory=True # Faster Host to GPU copies with page-locked memory
else:
    torch_device = torch.device('cpu')
    use_pin_memory=False
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/Colab Notebooks/bayesian-dl-experiments
# datasets_files			LICENSE     test_results
# experiment_comparison.ipynb	README.md
# experiment_nn_capacity_1.ipynb	ronald_bdl

# %% [markdown]
# ### Variable settings

# %%
# Dataset to use
dataset_name = 'protein-tertiary-structure'

# Training set size
dataset_train_size = 0.8

# Epochs
n_epochs = 400

# Data batch sizes
n_training_batch = 128

# Set the training/test set sizes
subset_proportions = [0.4, 0.6, 0.8, 1]

# NN hyperparameters
network_hidden_dims = [25, 50, 100]
network_hidden_layers = [1, 3, 5]
network_dropout_rates = [0.005, 0.01, 0.05, 0.1]

# Regularization strengths
regularization_strengths = [0.025, 0.05, 0.075]

# Number of test predictions (for each data point)
prediction_runs = [3, 10, 100, 1000, 3000, 5000, 7000, 10000]

# %% [markdown]
# ### Training setup

# %%
import time
import datetime
import os
from itertools import product

from torch import nn, optim
from torch.utils.data import random_split, DataLoader, RandomSampler
from ronald_bdl import models, datasets

# Mean Squared Error for loss function to minimize
objective = nn.MSELoss()

# Test start time
test_start_time = datetime.datetime.today().strftime('%Y%m%d%H%M')

# %% [markdown]
# ## Train the network

# %%
for subset_prop, hidden_dim, n_hidden, dropout_rate, reg_strength in product(
    subset_proportions,
    network_hidden_dims, network_hidden_layers, network_dropout_rates,
    regularization_strengths,
):
    
    # Create directory to store results for the current test configuration
    test_results_path = os.path.join(
        './test_results',
        'nn_capacity_1',
        dataset_name,
        test_start_time,
        (
            str(subset_prop) 
            + '_' + str(hidden_dim) 
            + '_' + str(n_hidden) 
            + '_' + str(dropout_rate) 
            + '_' + str(reg_strength)),
    )
    
    os.makedirs(test_results_path)
    
    test_results_rmse_mc_path = os.path.join(
        test_results_path,
        "rmse_mc.txt"
    )
    
    test_results_lls_mc_path = os.path.join(
        test_results_path,
        "lls_mc.txt"
    )
    
    test_results_times_mc_path = os.path.join(
        test_results_path,
        "times_mc.txt"
    )

    # Prepare new subset of the original dataset
    subset = datasets.UCIDatasets(
        dataset_name, root_dir='./datasets_files', 
        limit_size=subset_prop, transform=None, download=True)

    # Determine sizes of training and testing set
    train_size = int(dataset_train_size * len(subset))
    test_size = len(subset) - train_size
    
    # Print the size of the subset
    print("subset size = " + str((len(subset), subset.n_features)))
    print("training set size = %d" % train_size)
    print("test set size = %d" % test_size)
    
    train, test = random_split(subset, lengths=[train_size, test_size])

    train_loader = DataLoader(train, batch_size=n_training_batch, pin_memory=use_pin_memory)

    # Prepare network
    network = models.FCNetMCDropout(
        input_dim=subset.n_features, 
        output_dim=subset.n_targets,
        hidden_dim=hidden_dim,
        n_hidden=n_hidden,
        dropout_rate=dropout_rate,
        dropout_type='bernoulli',
    )
    
    # Send the whole model to the selected torch.device
    network.to(torch_device)

    # Print the network structure
    print(network)
    
    # Model to train mode
    network.train()
    
    # Adam optimizer
    # https://pytorch.org/docs/stable/optim.html?highlight=adam#torch.optim.Adam
    # NOTE: Need to set L2 regularization from here
    optimizer = optim.Adam(
        network.parameters(),
        lr=0.01,
        weight_decay=reg_strength, # L2 regularization
    )

    print()

    """
    Training
    """

    print(
        "Starting subset %f, n_hidden %d, hidden_dim %d, dropout_rate %f, reg_strength %f"
        % (subset_prop, n_hidden, hidden_dim, dropout_rate, reg_strength))

    # Record training start time (for this split)
    tic = time.time()

    for epoch in range(n_epochs): # loop over the dataset multiple times

        for i, data in enumerate(train_loader):
            # get the inputs; data is a list of [inputs, labels]
            inputs, targets = data

            # Store the batch to torch_device's memory
            inputs = inputs.to(torch_device)
            targets = targets.to(torch_device)

            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            outputs = network(inputs)

            loss = objective(outputs, targets)
            loss.backward()

            optimizer.step()
            
    # Record training end time
    toc = time.time()

    # Report the final loss
    print("final loss = %f" % (loss.item()))

    """
    Testing
    """

    # Model to eval mode
    #network.eval()

    # Get the test data
    inputs, targets = test.dataset[test.indices]

    # Store the batch to torch_device's memory
    inputs = inputs.to(torch_device)
    targets = targets.to(torch_device)

    for n_predictions in prediction_runs:
        print(str(n_predictions) + " test runs...")

        # Record testing start time (for this split)
        tic_testing = time.time()

        _, mean, var, metrics = network.predict_dist(inputs, n_predictions, y_test=targets, reg_strength=reg_strength)

        # Record testing end time
        toc_testing = time.time()

        # store additional metrics
        if len(metrics) > 0:
            with open(test_results_times_mc_path, 'a+') as times_mc_file:
                times_mc_file.write('%d %f \n' % (n_predictions, toc_testing-tic_testing))

            for key, value in metrics.items():
                print(str(key) + " = " + str(value))

                if key == 'rmse_mc':
                    with open(test_results_rmse_mc_path, 'a+') as rmse_mc_file:
                        rmse_mc_file.write('%d %f \n' % (n_predictions, value))

                elif key == 'test_ll_mc':
                    with open(test_results_lls_mc_path, 'a+') as lls_mc_file:
                        lls_mc_file.write('%d %f \n' % (n_predictions, value))
            print()
            
    # Report the total training time
    print("training time = " + str(toc - tic) + " seconds")
    
    # Report the total testing time
    print("testing time (last run) = " + str(toc_testing - tic_testing) + " seconds")

    print()
# Out:
# Using downloaded and verified file: ./datasets_files/yacht/yacht_hydrodynamics.data
# subset size = (123, 6)
# training set size = 98
# test set size = 25
# FCNetMCDropout(
#   (input): Sequential(
#     (0): Linear(in_features=6, out_features=25, bias=True)
#     (1): Dropout(p=0.005, inplace=False)
#   )
#   (hidden_layers): ModuleList(
#     (0): Sequential(
#       (0): Linear(in_features=25, out_features=25, bias=True)
#       (1): Dropout(p=0.005, inplace=False)
#     )
#   )
#   (output): Linear(in_features=25, out_features=1, bias=True)
# )
#
# Starting subset 0.400000, n_hidden 1, hidden_dim 25, dropout_rate 0.005000, reg_strength 0.025000
# final loss = 7.751255
# 10 test runs...
# rmse_mc = tensor(3.1010, device='cuda:0')
# rmse_non_mc = tensor(2.9446, device='cuda:0')
# test_ll_mc = tensor(-2.8932, device='cuda:0')
#
# 100 test runs...
# rmse_mc = tensor(2.9338, device='cuda:0')
# rmse_non_mc = tensor(2.9446, device='cuda:0')
# test_ll_mc = tensor(-2.8790, device='cuda:0')
#
# 1000 test runs...
# rmse_mc = tensor(2.9392, device='cuda:0')
# rmse_non_mc = tensor(2.9446, device='cuda:0')
# test_ll_mc = tensor(-2.8818, device='cuda:0')
#
# 3000 test runs...
# rmse_mc = tensor(2.9536, device='cuda:0')
# rmse_non_mc = tensor(2.9446, device='cuda:0')
# test_ll_mc = tensor(-2.8830, device='cuda:0')
#
# 5000 test runs...
# rmse_mc = tensor(2.9454, device='cuda:0')
# rmse_non_mc = tensor(2.9446, device='cuda:0')
# test_ll_mc = tensor(-2.8825, device='cuda:0')
#
# 7000 test runs...
# rmse_mc = tensor(2.9488, device='cuda:0')
# rmse_non_mc = tensor(2.9446, device='cuda:0')
# test_ll_mc = tensor(-2.8825, device='cuda:0')
#
# 10000 test runs...
# rmse_mc = tensor(2.9404, device='cuda:0')
# rmse_non_mc = tensor(2.9446, device='cuda:0')
# test_ll_mc = tensor(-2.8823, device='cuda:0')
#
# training time = 2.0329599380493164 seconds
# testing time (last run) = 1.57295823097229 seconds
#
# Using downloaded and verified file: ./datasets_files/yacht/yacht_hydrodynamics.data
# subset size = (123, 6)
# training set size = 98
# test set size = 25
# FCNetMCDropout(
#   (input): Sequential(
#     (0): Linear(in_features=6, out_features=25, bias=True)
#     (1): Dropout(p=0.005, inplace=False)
#   )
#   (hidden_layers): ModuleList(
#     (0): Sequential(
#       (0): Linear(in_features=25, out_features=25, bias=True)
#       (1): Dropout(p=0.005, inplace=False)
#     )
#   )
#   (output): Linear(in_features=25, out_features=1, bias=True)
# )
#
# Starting subset 0.400000, n_hidden 1, hidden_dim 25, dropout_rate 0.005000, reg_strength 0.050000
# final loss = 8.346438
# 10 test runs...
# rmse_mc = tensor(4.2836, device='cuda:0')
# rmse_non_mc = tensor(3.9544, device='cuda:0')
# test_ll_mc = tensor(-2.8253, device='cuda:0')
#
# 100 test runs...
# rmse_mc = tensor(4.0105, device='cuda:0')
# rmse_non_mc = tensor(3.9544, device='cuda:0')
# test_ll_mc = tensor(-2.7945, device='cuda:0')
#
# 1000 test runs...
# rmse_mc = tensor(3.9607, device='cuda:0')
# rmse_non_mc = tensor(3.9544, device='cuda:0')
# test_ll_mc = tensor(-2.7682, device='cuda:0')
#
# 3000 test runs...
# rmse_mc = tensor(3.9540, device='cuda:0')
# rmse_non_mc = tensor(3.9544, device='cuda:0')
# test_ll_mc = tensor(-2.7626, device='cuda:0')
#
# 5000 test runs...
# rmse_mc = tensor(3.9523, device='cuda:0')
# rmse_non_mc = tensor(3.9544, device='cuda:0')
# test_ll_mc = tensor(-2.7613, device='cuda:0')
#
# 7000 test runs...
# rmse_mc = tensor(3.9587, device='cuda:0')
# rmse_non_mc = tensor(3.9544, device='cuda:0')
# test_ll_mc = tensor(-2.7676, device='cuda:0')
#
# 10000 test runs...
# rmse_mc = tensor(3.9578, device='cuda:0')
# rmse_non_mc = tensor(3.9544, device='cuda:0')
# test_ll_mc = tensor(-2.7620, device='cuda:0')
#
# training time = 1.982231855392456 seconds
# testing time (last run) = 1.588411808013916 seconds
#
# Using downloaded and verified file: ./datasets_files/yacht/yacht_hydrodynamics.data
# subset size = (123, 6)
# training set size = 98
# test set size = 25
# FCNetMCDropout(
#   (input): Sequential(
#     (0): Linear(in_features=6, out_features=25, bias=True)
#     (1): Dropout(p=0.005, inplace=False)
#   )
#   (hidden_layers): ModuleList(
#     (0): Sequential(
#       (0): Linear(in_features=25, out_features=25, bias=True)
#       (1): Dropout(p=0.005, inplace=False)
#     )
#   )
#   (output): Linear(in_features=25, out_features=1, bias=True)
# )
#
# Starting subset 0.400000, n_hidden 1, hidden_dim 25, dropout_rate 0.005000, reg_strength 0.075000
# final loss = 7.503870
# 10 test runs...
# rmse_mc = tensor(1.5747, device='cuda:0')
# rmse_non_mc = tensor(1.5834, device='cuda:0')
# test_ll_mc = tensor(-2.3025, device='cuda:0')
#
# 100 test runs...
# rmse_mc = tensor(1.5254, device='cuda:0')
# rmse_non_mc = tensor(1.5834, device='cuda:0')
# test_ll_mc = tensor(-2.3044, device='cuda:0')
#
# 1000 test runs...
# rmse_mc = tensor(1.5913, device='cuda:0')
# rmse_non_mc = tensor(1.5834, device='cuda:0')
# test_ll_mc = tensor(-2.3098, device='cuda:0')
#
# 3000 test runs...
# rmse_mc = tensor(1.5926, device='cuda:0')
# rmse_non_mc = tensor(1.5834, device='cuda:0')
# test_ll_mc = tensor(-2.3103, device='cuda:0')
#
# 5000 test runs...
# rmse_mc = tensor(1.5817, device='cuda:0')
# rmse_non_mc = tensor(1.5834, device='cuda:0')
# test_ll_mc = tensor(-2.3092, device='cuda:0')
#
# 7000 test runs...
# rmse_mc = tensor(1.5845, device='cuda:0')
# rmse_non_mc = tensor(1.5834, device='cuda:0')
# test_ll_mc = tensor(-2.3096, device='cuda:0')
#
# 10000 test runs...
# rmse_mc = tensor(1.5899, device='cuda:0')
# rmse_non_mc = tensor(1.5834, device='cuda:0')
# test_ll_mc = tensor(-2.3105, device='cuda:0')
#
# training time = 2.0302534103393555 seconds
# testing time (last run) = 1.6073482036590576 seconds
#
# Using downloaded and verified file: ./datasets_files/yacht/yacht_hydrodynamics.data
# subset size = (123, 6)
# training set size = 98
# test set size = 25
# FCNetMCDropout(
#   (input): Sequential(
#     (0): Linear(in_features=6, out_features=25, bias=True)
#     (1): Dropout(p=0.01, inplace=False)
#   )
#   (hidden_layers): ModuleList(
#     (0): Sequential(
#       (0): Linear(in_features=25, out_features=25, bias=True)
#       (1): Dropout(p=0.01, inplace=False)
#     )
#   )
#   (output): Linear(in_features=25, out_features=1, bias=True)
# )
#
# Starting subset 0.400000, n_hidden 1, hidden_dim 25, dropout_rate 0.010000, reg_strength 0.025000
# final loss = 13.229984
# 10 test runs...
# rmse_mc = tensor(3.6229, device='cuda:0')
# rmse_non_mc = tensor(3.7281, device='cuda:0')
# test_ll_mc = tensor(-2.9347, device='cuda:0')
#
# 100 test runs...
# rmse_mc = tensor(3.8104, device='cuda:0')
# rmse_non_mc = tensor(3.7281, device='cuda:0')
# test_ll_mc = tensor(-2.9430, device='cuda:0')
#
# 1000 test runs...
# rmse_mc = tensor(3.7403, device='cuda:0')
# rmse_non_mc = tensor(3.7281, device='cuda:0')
# test_ll_mc = tensor(-2.9398, device='cuda:0')
#
# 3000 test runs...
# rmse_mc = tensor(3.7332, device='cuda:0')
# rmse_non_mc = tensor(3.7281, device='cuda:0')
# test_ll_mc = tensor(-2.9397, device='cuda:0')
#
# 5000 test runs...
# rmse_mc = tensor(3.7390, device='cuda:0')
# rmse_non_mc = tensor(3.7281, device='cuda:0')
# test_ll_mc = tensor(-2.9396, device='cuda:0')
#
# 7000 test runs...
# rmse_mc = tensor(3.7490, device='cuda:0')
# rmse_non_mc = tensor(3.7281, device='cuda:0')
# test_ll_mc = tensor(-2.9396, device='cuda:0')
#
# 10000 test runs...
# rmse_mc = tensor(3.7413, device='cuda:0')
# rmse_non_mc = tensor(3.7281, device='cuda:0')
# test_ll_mc = tensor(-2.9397, device='cuda:0')
#
# training time = 2.033785581588745 seconds
# testing time (last run) = 1.6426939964294434 seconds
#
# Using downloaded and verified file: ./datasets_files/yacht/yacht_hydrodynamics.data
# subset size = (123, 6)
# training set size = 98
# test set size = 25
# FCNetMCDropout(
#   (input): Sequential(
#     (0): Linear(in_features=6, out_features=25, bias=True)
#     (1): Dropout(p=0.01, inplace=False)
#   )
#   (hidden_layers): ModuleList(
#     (0): Sequential(
#       (0): Linear(in_features=25, out_features=25, bias=True)
#       (1): Dropout(p=0.01, inplace=False)
#     )
#   )
#   (output): Linear(in_features=25, out_features=1, bias=True)
# )
#
# Starting subset 0.400000, n_hidden 1, hidden_dim 25, dropout_rate 0.010000, reg_strength 0.050000
# final loss = 5.706067
# 10 test runs...
# rmse_mc = tensor(2.7271, device='cuda:0')
# rmse_non_mc = tensor(2.8561, device='cuda:0')
# test_ll_mc = tensor(-2.6158, device='cuda:0')
#
# 100 test runs...
# rmse_mc = tensor(2.8151, device='cuda:0')
# rmse_non_mc = tensor(2.8561, device='cuda:0')
# test_ll_mc = tensor(-2.6221, device='cuda:0')
#
# 1000 test runs...
# rmse_mc = tensor(2.8417, device='cuda:0')
# rmse_non_mc = tensor(2.8561, device='cuda:0')
# test_ll_mc = tensor(-2.6244, device='cuda:0')
#
# 3000 test runs...
# rmse_mc = tensor(2.8433, device='cuda:0')
# rmse_non_mc = tensor(2.8561, device='cuda:0')
# test_ll_mc = tensor(-2.6212, device='cuda:0')
#
# 5000 test runs...
# rmse_mc = tensor(2.8443, device='cuda:0')
# rmse_non_mc = tensor(2.8561, device='cuda:0')
# test_ll_mc = tensor(-2.6211, device='cuda:0')
#
# 7000 test runs...
# rmse_mc = tensor(2.8410, device='cuda:0')
# rmse_non_mc = tensor(2.8561, device='cuda:0')
# test_ll_mc = tensor(-2.6207, device='cuda:0')
#
# 10000 test runs...
# rmse_mc = tensor(2.8481, device='cuda:0')
# rmse_non_mc = tensor(2.8561, device='cuda:0')
# test_ll_mc = tensor(-2.6220, device='cuda:0')
#
# training time = 2.0205888748168945 seconds
# testing time (last run) = 1.5822937488555908 seconds
#
# Using downloaded and verified file: ./datasets_files/yacht/yacht_hydrodynamics.data
# subset size = (123, 6)
# training set size = 98
# test set size = 25
# FCNetMCDropout(
#   (input): Sequential(
#     (0): Linear(in_features=6, out_features=25, bias=True)
#     (1): Dropout(p=0.01, inplace=False)
#   )
#   (hidden_layers): ModuleList(
#     (0): Sequential(
#       (0): Linear(in_features=25, out_features=25, bias=True)
#       (1): Dropout(p=0.01, inplace=False)
#     )
#   )
#   (output): Linear(in_features=25, out_features=1, bias=True)
# )
#
# Starting subset 0.400000, n_hidden 1, hidden_dim 25, dropout_rate 0.010000, reg_strength 0.075000
# final loss = 10.558375
# 10 test runs...
# rmse_mc = tensor(2.7683, device='cuda:0')
# rmse_non_mc = tensor(2.9343, device='cuda:0')
# test_ll_mc = tensor(-2.5197, device='cuda:0')
#
# 100 test runs...
# rmse_mc = tensor(3.0138, device='cuda:0')
# rmse_non_mc = tensor(2.9343, device='cuda:0')
# test_ll_mc = tensor(-2.5322, device='cuda:0')
#
# 1000 test runs...
# rmse_mc = tensor(2.9416, device='cuda:0')
# rmse_non_mc = tensor(2.9343, device='cuda:0')
# test_ll_mc = tensor(-2.5232, device='cuda:0')
#
# 3000 test runs...
# rmse_mc = tensor(2.9382, device='cuda:0')
# rmse_non_mc = tensor(2.9343, device='cuda:0')
# test_ll_mc = tensor(-2.5166, device='cuda:0')
#
# 5000 test runs...
# rmse_mc = tensor(2.9364, device='cuda:0')
# rmse_non_mc = tensor(2.9343, device='cuda:0')
# test_ll_mc = tensor(-2.5203, device='cuda:0')
#
# 7000 test runs...
# rmse_mc = tensor(2.9387, device='cuda:0')
# rmse_non_mc = tensor(2.9343, device='cuda:0')
# test_ll_mc = tensor(-2.5214, device='cuda:0')
#
# 10000 test runs...
# rmse_mc = tensor(2.9403, device='cuda:0')
# rmse_non_mc = tensor(2.9343, device='cuda:0')
# test_ll_mc = tensor(-2.5186, device='cuda:0')
#
# training time = 2.0177552700042725 seconds
# testing time (last run) = 1.6053788661956787 seconds
#
# Using downloaded and verified file: ./datasets_files/yacht/yacht_hydrodynamics.data
# subset size = (123, 6)
# training set size = 98
# test set size = 25
# FCNetMCDropout(
#   (input): Sequential(
#     (0): Linear(in_features=6, out_features=25, bias=True)
#     (1): Dropout(p=0.05, inplace=False)
#   )
#   (hidden_layers): ModuleList(
#     (0): Sequential(
#       (0): Linear(in_features=25, out_features=25, bias=True)
#       (1): Dropout(p=0.05, inplace=False)
#     )
#   )
#   (output): Linear(in_features=25, out_features=1, bias=True)
# )
#
# Starting subset 0.400000, n_hidden 1, hidden_dim 25, dropout_rate 0.050000, reg_strength 0.025000
# final loss = 10.789791
# 10 test runs...
# rmse_mc = tensor(1.0470, device='cuda:0')
# rmse_non_mc = tensor(0.9882, device='cuda:0')
# test_ll_mc = tensor(-2.8020, device='cuda:0')
#
# 100 test runs...
# rmse_mc = tensor(1.0672, device='cuda:0')
# rmse_non_mc = tensor(0.9882, device='cuda:0')
# test_ll_mc = tensor(-2.7987, device='cuda:0')
#
# 1000 test runs...
# rmse_mc = tensor(1.0111, device='cuda:0')
# rmse_non_mc = tensor(0.9882, device='cuda:0')
# test_ll_mc = tensor(-2.7971, device='cuda:0')
#
# 3000 test runs...
# rmse_mc = tensor(0.9995, device='cuda:0')
# rmse_non_mc = tensor(0.9882, device='cuda:0')
# test_ll_mc = tensor(-2.7968, device='cuda:0')
#
# 5000 test runs...
# rmse_mc = tensor(1.0071, device='cuda:0')
# rmse_non_mc = tensor(0.9882, device='cuda:0')
# test_ll_mc = tensor(-2.7972, device='cuda:0')
#
# 7000 test runs...
# rmse_mc = tensor(1.0060, device='cuda:0')
# rmse_non_mc = tensor(0.9882, device='cuda:0')
# test_ll_mc = tensor(-2.7970, device='cuda:0')
#
# 10000 test runs...
# rmse_mc = tensor(1.0078, device='cuda:0')
# rmse_non_mc = tensor(0.9882, device='cuda:0')
# test_ll_mc = tensor(-2.7972, device='cuda:0')
#
# training time = 2.0392258167266846 seconds
# testing time (last run) = 1.5807573795318604 seconds
#
# Using downloaded and verified file: ./datasets_files/yacht/yacht_hydrodynamics.data
# subset size = (123, 6)
# training set size = 98
# test set size = 25
# FCNetMCDropout(
#   (input): Sequential(
#     (0): Linear(in_features=6, out_features=25, bias=True)
#     (1): Dropout(p=0.05, inplace=False)
#   )
#   (hidden_layers): ModuleList(
#     (0): Sequential(
#       (0): Linear(in_features=25, out_features=25, bias=True)
#       (1): Dropout(p=0.05, inplace=False)
#     )
#   )
#   (output): Linear(in_features=25, out_features=1, bias=True)
# )
#
# Starting subset 0.400000, n_hidden 1, hidden_dim 25, dropout_rate 0.050000, reg_strength 0.050000
# final loss = 8.347785
# 10 test runs...
# rmse_mc = tensor(2.4753, device='cuda:0')
# rmse_non_mc = tensor(2.1417, device='cuda:0')
# test_ll_mc = tensor(-2.5912, device='cuda:0')
#
# 100 test runs...
# rmse_mc = tensor(2.1575, device='cuda:0')
# rmse_non_mc = tensor(2.1417, device='cuda:0')
# test_ll_mc = tensor(-2.5656, device='cuda:0')
#
# 1000 test runs...
# rmse_mc = tensor(2.1705, device='cuda:0')
# rmse_non_mc = tensor(2.1417, device='cuda:0')
# test_ll_mc = tensor(-2.5642, device='cuda:0')
#
# 3000 test runs...
# rmse_mc = tensor(2.1255, device='cuda:0')
# rmse_non_mc = tensor(2.1417, device='cuda:0')
# test_ll_mc = tensor(-2.5626, device='cuda:0')
#
# 5000 test runs...
# rmse_mc = tensor(2.1403, device='cuda:0')
# rmse_non_mc = tensor(2.1417, device='cuda:0')
# test_ll_mc = tensor(-2.5629, device='cuda:0')
#
# 7000 test runs...
# rmse_mc = tensor(2.1154, device='cuda:0')
# rmse_non_mc = tensor(2.1417, device='cuda:0')
# test_ll_mc = tensor(-2.5615, device='cuda:0')
#
# 10000 test runs...
# rmse_mc = tensor(2.1344, device='cuda:0')
# rmse_non_mc = tensor(2.1417, device='cuda:0')
# test_ll_mc = tensor(-2.5626, device='cuda:0')
#
# training time = 1.983231782913208 seconds
# testing time (last run) = 1.6130192279815674 seconds
#
# Using downloaded and verified file: ./datasets_files/yacht/yacht_hydrodynamics.data
# subset size = (123, 6)
# training set size = 98
# test set size = 25
# FCNetMCDropout(
#   (input): Sequential(
#     (0): Linear(in_features=6, out_features=25, bias=True)
#     (1): Dropout(p=0.05, inplace=False)
#   )
#   (hidden_layers): ModuleList(
#     (0): Sequential(
#       (0): Linear(in_features=25, out_features=25, bias=True)
#       (1): Dropout(p=0.05, inplace=False)
#     )
#   )
#   (output): Linear(in_features=25, out_features=1, bias=True)
# )
#
# Starting subset 0.400000, n_hidden 1, hidden_dim 25, dropout_rate 0.050000, reg_strength 0.075000
# final loss = 11.921147
# 10 test runs...
# rmse_mc = tensor(2.2111, device='cuda:0')
# rmse_non_mc = tensor(2.0279, device='cuda:0')
# test_ll_mc = tensor(-2.4170, device='cuda:0')
#
# 100 test runs...
# rmse_mc = tensor(1.9711, device='cuda:0')
# rmse_non_mc = tensor(2.0279, device='cuda:0')
# test_ll_mc = tensor(-2.3965, device='cuda:0')
#
# 1000 test runs...
# rmse_mc = tensor(2.0518, device='cuda:0')
# rmse_non_mc = tensor(2.0279, device='cuda:0')
# test_ll_mc = tensor(-2.3988, device='cuda:0')
#
# 3000 test runs...
# rmse_mc = tensor(2.0131, device='cuda:0')
# rmse_non_mc = tensor(2.0279, device='cuda:0')
# test_ll_mc = tensor(-2.3959, device='cuda:0')
#
# 5000 test runs...
# rmse_mc = tensor(2.0481, device='cuda:0')
# rmse_non_mc = tensor(2.0279, device='cuda:0')
# test_ll_mc = tensor(-2.3987, device='cuda:0')
#
# 7000 test runs...
# rmse_mc = tensor(2.0509, device='cuda:0')
# rmse_non_mc = tensor(2.0279, device='cuda:0')
# test_ll_mc = tensor(-2.3985, device='cuda:0')
#
# 10000 test runs...
# rmse_mc = tensor(2.0251, device='cuda:0')
# rmse_non_mc = tensor(2.0279, device='cuda:0')
# test_ll_mc = tensor(-2.3969, device='cuda:0')
#
# training time = 2.0327236652374268 seconds
# testing time (last run) = 1.6747961044311523 seconds
#
# Using downloaded and verified file: ./datasets_files/yacht/yacht_hydrodynamics.data
# subset size = (123, 6)
# training set size = 98
# test set size = 25
# FCNetMCDropout(
#   (input): Sequential(
#     (0): Linear(in_features=6, out_features=25, bias=True)
#     (1): Dropout(p=0.1, inplace=False)
#   )
#   (hidden_layers): ModuleList(
#     (0): Sequential(
#       (0): Linear(in_features=25, out_features=25, bias=True)
#       (1): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (output): Linear(in_features=25, out_features=1, bias=True)
# )
#
# Starting subset 0.400000, n_hidden 1, hidden_dim 25, dropout_rate 0.100000, reg_strength 0.025000
# final loss = 14.991612
# 10 test runs...
# rmse_mc = tensor(5.7499, device='cuda:0')
# rmse_non_mc = tensor(5.9237, device='cuda:0')
# test_ll_mc = tensor(-3.1507, device='cuda:0')
#
# 100 test runs...
# rmse_mc = tensor(5.9608, device='cuda:0')
# rmse_non_mc = tensor(5.9237, device='cuda:0')
# test_ll_mc = tensor(-3.1577, device='cuda:0')
#
# 1000 test runs...
# rmse_mc = tensor(5.9597, device='cuda:0')
# rmse_non_mc = tensor(5.9237, device='cuda:0')
# test_ll_mc = tensor(-3.1613, device='cuda:0')
#
# 3000 test runs...
# rmse_mc = tensor(5.9320, device='cuda:0')
# rmse_non_mc = tensor(5.9237, device='cuda:0')
# test_ll_mc = tensor(-3.1582, device='cuda:0')
#
# 5000 test runs...
# rmse_mc = tensor(5.9156, device='cuda:0')
# rmse_non_mc = tensor(5.9237, device='cuda:0')
# test_ll_mc = tensor(-3.1560, device='cuda:0')
#
# 7000 test runs...
# rmse_mc = tensor(5.9314, device='cuda:0')
# rmse_non_mc = tensor(5.9237, device='cuda:0')
# test_ll_mc = tensor(-3.1561, device='cuda:0')
#
# 10000 test runs...
# rmse_mc = tensor(5.9193, device='cuda:0')
# rmse_non_mc = tensor(5.9237, device='cuda:0')
# test_ll_mc = tensor(-3.1557, device='cuda:0')
#
# training time = 2.045973539352417 seconds
# testing time (last run) = 1.5984759330749512 seconds
#
# Using downloaded and verified file: ./datasets_files/yacht/yacht_hydrodynamics.data
# subset size = (123, 6)
# training set size = 98
# test set size = 25
# FCNetMCDropout(
#   (input): Sequential(
#     (0): Linear(in_features=6, out_features=25, bias=True)
#     (1): Dropout(p=0.1, inplace=False)
#   )
#   (hidden_layers): ModuleList(
#     (0): Sequential(
#       (0): Linear(in_features=25, out_features=25, bias=True)
#       (1): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (output): Linear(in_features=25, out_features=1, bias=True)
# )
#
# Starting subset 0.400000, n_hidden 1, hidden_dim 25, dropout_rate 0.100000, reg_strength 0.050000
# final loss = 13.096137
# 10 test runs...
# rmse_mc = tensor(3.8522, device='cuda:0')
# rmse_non_mc = tensor(3.9144, device='cuda:0')
# test_ll_mc = tensor(-2.6900, device='cuda:0')
#
# 100 test runs...
# rmse_mc = tensor(3.9718, device='cuda:0')
# rmse_non_mc = tensor(3.9144, device='cuda:0')
# test_ll_mc = tensor(-2.7377, device='cuda:0')
#
# 1000 test runs...
# rmse_mc = tensor(3.8987, device='cuda:0')
# rmse_non_mc = tensor(3.9144, device='cuda:0')
# test_ll_mc = tensor(-2.7247, device='cuda:0')
#
# 3000 test runs...
# rmse_mc = tensor(3.8969, device='cuda:0')
# rmse_non_mc = tensor(3.9144, device='cuda:0')
# test_ll_mc = tensor(-2.7275, device='cuda:0')
#
# 5000 test runs...
# rmse_mc = tensor(3.9140, device='cuda:0')
# rmse_non_mc = tensor(3.9144, device='cuda:0')
# test_ll_mc = tensor(-2.7285, device='cuda:0')
#
# 7000 test runs...
# rmse_mc = tensor(3.9188, device='cuda:0')
# rmse_non_mc = tensor(3.9144, device='cuda:0')
# test_ll_mc = tensor(-2.7304, device='cuda:0')
#
# 10000 test runs...
# rmse_mc = tensor(3.9157, device='cuda:0')
# rmse_non_mc = tensor(3.9144, device='cuda:0')
# test_ll_mc = tensor(-2.7292, device='cuda:0')
#
# training time = 2.069495677947998 seconds
# testing time (last run) = 1.5889153480529785 seconds
#
# Using downloaded and verified file: ./datasets_files/yacht/yacht_hydrodynamics.data
# subset size = (123, 6)
# training set size = 98
# test set size = 25
# FCNetMCDropout(
#   (input): Sequential(
#     (0): Linear(in_features=6, out_features=25, bias=True)
#     (1): Dropout(p=0.1, inplace=False)
#   )
#   (hidden_layers): ModuleList(
#     (0): Sequential(
#       (0): Linear(in_features=25, out_features=25, bias=True)
#       (1): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (output): Linear(in_features=25, out_features=1, bias=True)
# )
#
# Starting subset 0.400000, n_hidden 1, hidden_dim 25, dropout_rate 0.100000, reg_strength 0.075000
# final loss = 16.698513
# 10 test runs...
# rmse_mc = tensor(2.2473, device='cuda:0')
# rmse_non_mc = tensor(2.4266, device='cuda:0')
# test_ll_mc = tensor(-2.4632, device='cuda:0')
#
# 100 test runs...
# rmse_mc = tensor(2.3507, device='cuda:0')
# rmse_non_mc = tensor(2.4266, device='cuda:0')
# test_ll_mc = tensor(-2.4370, device='cuda:0')
#
# 1000 test runs...
# rmse_mc = tensor(2.4079, device='cuda:0')
# rmse_non_mc = tensor(2.4266, device='cuda:0')
# test_ll_mc = tensor(-2.4546, device='cuda:0')
#
# 3000 test runs...
# rmse_mc = tensor(2.4458, device='cuda:0')
# rmse_non_mc = tensor(2.4266, device='cuda:0')
# test_ll_mc = tensor(-2.4560, device='cuda:0')
#
# 5000 test runs...
# rmse_mc = tensor(2.4143, device='cuda:0')
# rmse_non_mc = tensor(2.4266, device='cuda:0')
# test_ll_mc = tensor(-2.4542, device='cuda:0')
#
# 7000 test runs...
# rmse_mc = tensor(2.4661, device='cuda:0')
# rmse_non_mc = tensor(2.4266, device='cuda:0')
# test_ll_mc = tensor(-2.4568, device='cuda:0')
#
# 10000 test runs...
# rmse_mc = tensor(2.4484, device='cuda:0')
# rmse_non_mc = tensor(2.4266, device='cuda:0')
# test_ll_mc = tensor(-2.4569, device='cuda:0')
#
# training time = 1.9969263076782227 seconds
# testing time (last run) = 1.584770917892456 seconds
#
# Using downloaded and verified file: ./datasets_files/yacht/yacht_hydrodynamics.data
# subset size = (123, 6)
# training set size = 98
# test set size = 25
# FCNetMCDropout(
#   (input): Sequential(
#     (0): Linear(in_features=6, out_features=25, bias=True)
#     (1): Dropout(p=0.005, inplace=False)
#   )
#   (hidden_layers): ModuleList(
#     (0): Sequential(
#       (0): Linear(in_features=25, out_features=25, bias=True)
#       (1): Dropout(p=0.005, inplace=False)
#     )
#     (1): Sequential(
#       (0): Linear(in_features=25, out_features=25, bias=True)
#       (1): Dropout(p=0.005, inplace=False)
#     )
#     (2): Sequential(
#       (0): Linear(in_features=25, out_features=25, bias=True)
#       (1): Dropout(p=0.005, inplace=False)
#     )
#   )
#   (output): Linear(in_features=25, out_features=1, bias=True)
# )
#
# Starting subset 0.400000, n_hidden 3, hidden_dim 25, dropout_rate 0.005000, reg_strength 0.025000
# final loss = 3.081057
# 10 test runs...
# rmse_mc = tensor(2.8704, device='cuda:0')
# rmse_non_mc = tensor(2.8189, device='cuda:0')
# test_ll_mc = tensor(-2.8744, device='cuda:0')
#
# 100 test runs...
# rmse_mc = tensor(2.6873, device='cuda:0')
# rmse_non_mc = tensor(2.8189, device='cuda:0')
# test_ll_mc = tensor(-2.8741, device='cuda:0')
#
# 1000 test runs...
# rmse_mc = tensor(2.8718, device='cuda:0')
# rmse_non_mc = tensor(2.8189, device='cuda:0')
# test_ll_mc = tensor(-2.8767, device='cuda:0')
#
# 3000 test runs...
# rmse_mc = tensor(2.8309, device='cuda:0')
# rmse_non_mc = tensor(2.8189, device='cuda:0')
# test_ll_mc = tensor(-2.8749, device='cuda:0')
#
# 5000 test runs...
# rmse_mc = tensor(2.8387, device='cuda:0')
# rmse_non_mc = tensor(2.8189, device='cuda:0')
# test_ll_mc = tensor(-2.8746, device='cuda:0')
#
# 7000 test runs...
# rmse_mc = tensor(2.8353, device='cuda:0')
# rmse_non_mc = tensor(2.8189, device='cuda:0')
# test_ll_mc = tensor(-2.8754, device='cuda:0')
#
# 10000 test runs...
# rmse_mc = tensor(2.8346, device='cuda:0')
# rmse_non_mc = tensor(2.8189, device='cuda:0')
# test_ll_mc = tensor(-2.8756, device='cuda:0')
#
# training time = 2.347261428833008 seconds
# testing time (last run) = 2.8460702896118164 seconds
#
# Using downloaded and verified file: ./datasets_files/yacht/yacht_hydrodynamics.data
# subset size = (123, 6)
# training set size = 98
# test set size = 25
# FCNetMCDropout(
#   (input): Sequential(
#     (0): Linear(in_features=6, out_features=25, bias=True)
#     (1): Dropout(p=0.005, inplace=False)
#   )
#   (hidden_layers): ModuleList(
#     (0): Sequential(
#       (0): Linear(in_features=25, out_features=25, bias=True)
#       (1): Dropout(p=0.005, inplace=False)
#     )
#     (1): Sequential(
#       (0): Linear(in_features=25, out_features=25, bias=True)
#       (1): Dropout(p=0.005, inplace=False)
#     )
#     (2): Sequential(
#       (0): Linear(in_features=25, out_features=25, bias=True)
#       (1): Dropout(p=0.005, inplace=False)
#     )
#   )
#   (output): Linear(in_features=25, out_features=1, bias=True)
# )
#
# Starting subset 0.400000, n_hidden 3, hidden_dim 25, dropout_rate 0.005000, reg_strength 0.050000
# final loss = 8.662031
# 10 test runs...
# rmse_mc = tensor(3.5128, device='cuda:0')
# rmse_non_mc = tensor(3.5138, device='cuda:0')
# test_ll_mc = tensor(-2.7120, device='cuda:0')
#
# 100 test runs...
# rmse_mc = tensor(3.5347, device='cuda:0')
# rmse_non_mc = tensor(3.5138, device='cuda:0')
# test_ll_mc = tensor(-2.7143, device='cuda:0')
#
# 1000 test runs...
# rmse_mc = tensor(3.5216, device='cuda:0')
# rmse_non_mc = tensor(3.5138, device='cuda:0')
# test_ll_mc = tensor(-2.7108, device='cuda:0')
#
# 3000 test runs...
# rmse_mc = tensor(3.5118, device='cuda:0')
# rmse_non_mc = tensor(3.5138, device='cuda:0')
# test_ll_mc = tensor(-2.7098, device='cuda:0')
#
# 5000 test runs...
# rmse_mc = tensor(3.5126, device='cuda:0')
# rmse_non_mc = tensor(3.5138, device='cuda:0')
# test_ll_mc = tensor(-2.7101, device='cuda:0')
#
# 7000 test runs...
# rmse_mc = tensor(3.5125, device='cuda:0')
# rmse_non_mc = tensor(3.5138, device='cuda:0')
# test_ll_mc = tensor(-2.7099, device='cuda:0')
#
# 10000 test runs...
# rmse_mc = tensor(3.5170, device='cuda:0')
# rmse_non_mc = tensor(3.5138, device='cuda:0')
# test_ll_mc = tensor(-2.7097, device='cuda:0')
#
# training time = 2.363778829574585 seconds
# testing time (last run) = 2.802358627319336 seconds
#
# Using downloaded and verified file: ./datasets_files/yacht/yacht_hydrodynamics.data
# subset size = (123, 6)
# training set size = 98
# test set size = 25
# FCNetMCDropout(
#   (input): Sequential(
#     (0): Linear(in_features=6, out_features=25, bias=True)
#     (1): Dropout(p=0.005, inplace=False)
#   )
#   (hidden_layers): ModuleList(
#     (0): Sequential(
#       (0): Linear(in_features=25, out_features=25, bias=True)
#       (1): Dropout(p=0.005, inplace=False)
#     )
#     (1): Sequential(
#       (0): Linear(in_features=25, out_features=25, bias=True)
#       (1): Dropout(p=0.005, inplace=False)
#     )
#     (2): Sequential(
#       (0): Linear(in_features=25, out_features=25, bias=True)
#       (1): Dropout(p=0.005, inplace=False)
#     )
#   )
#   (output): Linear(in_features=25, out_features=1, bias=True)
# )
#
# Starting subset 0.400000, n_hidden 3, hidden_dim 25, dropout_rate 0.005000, reg_strength 0.075000
# final loss = 21.886375
# 10 test runs...
# rmse_mc = tensor(9.2064, device='cuda:0')
# rmse_non_mc = tensor(8.9959, device='cuda:0')
# test_ll_mc = tensor(-5.1676, device='cuda:0')
#
# 100 test runs...
# rmse_mc = tensor(9.0391, device='cuda:0')
# rmse_non_mc = tensor(8.9959, device='cuda:0')
# test_ll_mc = tensor(-4.5446, device='cuda:0')
#
# 1000 test runs...
# rmse_mc = tensor(8.9638, device='cuda:0')
# rmse_non_mc = tensor(8.9959, device='cuda:0')
# test_ll_mc = tensor(-4.0002, device='cuda:0')
#
# 3000 test runs...
# rmse_mc = tensor(8.9932, device='cuda:0')
# rmse_non_mc = tensor(8.9959, device='cuda:0')
# test_ll_mc = tensor(-4.0481, device='cuda:0')
#
# 5000 test runs...
# rmse_mc = tensor(8.9998, device='cuda:0')
# rmse_non_mc = tensor(8.9959, device='cuda:0')
# test_ll_mc = tensor(-3.4249, device='cuda:0')
#
# 7000 test runs...
# rmse_mc = tensor(8.9997, device='cuda:0')
# rmse_non_mc = tensor(8.9959, device='cuda:0')
# test_ll_mc = tensor(-4.0369, device='cuda:0')
#
# 10000 test runs...
# rmse_mc = tensor(8.9899, device='cuda:0')
# rmse_non_mc = tensor(8.9959, device='cuda:0')
# test_ll_mc = tensor(-3.4478, device='cuda:0')
#
# training time = 2.4051151275634766 seconds
# testing time (last run) = 2.7874467372894287 seconds
#
# Using downloaded and verified file: ./datasets_files/yacht/yacht_hydrodynamics.data
# subset size = (123, 6)
# training set size = 98
# test set size = 25
# FCNetMCDropout(
#   (input): Sequential(
#     (0): Linear(in_features=6, out_features=25, bias=True)
#     (1): Dropout(p=0.01, inplace=False)
#   )
#   (hidden_layers): ModuleList(
#     (0): Sequential(
#       (0): Linear(in_features=25, out_features=25, bias=True)
#       (1): Dropout(p=0.01, inplace=False)
#     )
#     (1): Sequential(
#       (0): Linear(in_features=25, out_features=25, bias=True)
#       (1): Dropout(p=0.01, inplace=False)
#     )
#     (2): Sequential(
#       (0): Linear(in_features=25, out_features=25, bias=True)
#       (1): Dropout(p=0.01, inplace=False)
#     )
#   )
#   (output): Linear(in_features=25, out_features=1, bias=True)
# )
#
# Starting subset 0.400000, n_hidden 3, hidden_dim 25, dropout_rate 0.010000, reg_strength 0.025000
# final loss = 7.990500
# 10 test runs...
# rmse_mc = tensor(4.1008, device='cuda:0')
# rmse_non_mc = tensor(3.5383, device='cuda:0')
# test_ll_mc = tensor(-2.9638, device='cuda:0')
#
# 100 test runs...
# rmse_mc = tensor(3.5072, device='cuda:0')
# rmse_non_mc = tensor(3.5383, device='cuda:0')
# test_ll_mc = tensor(-2.9328, device='cuda:0')
#
# 1000 test runs...
# rmse_mc = tensor(3.5223, device='cuda:0')
# rmse_non_mc = tensor(3.5383, device='cuda:0')
# test_ll_mc = tensor(-2.9370, device='cuda:0')
#
# 3000 test runs...
# rmse_mc = tensor(3.5632, device='cuda:0')
# rmse_non_mc = tensor(3.5383, device='cuda:0')
# test_ll_mc = tensor(-2.9395, device='cuda:0')
#
# 5000 test runs...
# rmse_mc = tensor(3.5460, device='cuda:0')
# rmse_non_mc = tensor(3.5383, device='cuda:0')
# test_ll_mc = tensor(-2.9379, device='cuda:0')
#
# 7000 test runs...
# rmse_mc = tensor(3.5628, device='cuda:0')
# rmse_non_mc = tensor(3.5383, device='cuda:0')
# test_ll_mc = tensor(-2.9387, device='cuda:0')
#
# 10000 test runs...
# rmse_mc = tensor(3.5587, device='cuda:0')
# rmse_non_mc = tensor(3.5383, device='cuda:0')
# test_ll_mc = tensor(-2.9386, device='cuda:0')
#
# training time = 2.3648080825805664 seconds
# testing time (last run) = 2.9048514366149902 seconds
#
# Using downloaded and verified file: ./datasets_files/yacht/yacht_hydrodynamics.data
# subset size = (123, 6)
# training set size = 98
# test set size = 25
# FCNetMCDropout(
#   (input): Sequential(
#     (0): Linear(in_features=6, out_features=25, bias=True)
#     (1): Dropout(p=0.01, inplace=False)
#   )
#   (hidden_layers): ModuleList(
#     (0): Sequential(
#       (0): Linear(in_features=25, out_features=25, bias=True)
#       (1): Dropout(p=0.01, inplace=False)
#     )
#     (1): Sequential(
#       (0): Linear(in_features=25, out_features=25, bias=True)
#       (1): Dropout(p=0.01, inplace=False)
#     )
#     (2): Sequential(
#       (0): Linear(in_features=25, out_features=25, bias=True)
#       (1): Dropout(p=0.01, inplace=False)
#     )
#   )
#   (output): Linear(in_features=25, out_features=1, bias=True)
# )
#
# Starting subset 0.400000, n_hidden 3, hidden_dim 25, dropout_rate 0.010000, reg_strength 0.050000
# final loss = 8.919585
# 10 test runs...
# rmse_mc = tensor(3.0108, device='cuda:0')
# rmse_non_mc = tensor(3.1026, device='cuda:0')
# test_ll_mc = tensor(-2.6489, device='cuda:0')
#
# 100 test runs...
# rmse_mc = tensor(3.1736, device='cuda:0')
# rmse_non_mc = tensor(3.1026, device='cuda:0')
# test_ll_mc = tensor(-2.6655, device='cuda:0')
#
# 1000 test runs...
# rmse_mc = tensor(3.1262, device='cuda:0')
# rmse_non_mc = tensor(3.1026, device='cuda:0')
# test_ll_mc = tensor(-2.6585, device='cuda:0')
#
# 3000 test runs...
# rmse_mc = tensor(3.1043, device='cuda:0')
# rmse_non_mc = tensor(3.1026, device='cuda:0')
# test_ll_mc = tensor(-2.6585, device='cuda:0')
#
# 5000 test runs...
# rmse_mc = tensor(3.1089, device='cuda:0')
# rmse_non_mc = tensor(3.1026, device='cuda:0')
# test_ll_mc = tensor(-2.6587, device='cuda:0')
#
# 7000 test runs...
# rmse_mc = tensor(3.1049, device='cuda:0')
# rmse_non_mc = tensor(3.1026, device='cuda:0')
# test_ll_mc = tensor(-2.6580, device='cuda:0')
#
# 10000 test runs...
# rmse_mc = tensor(3.1026, device='cuda:0')
# rmse_non_mc = tensor(3.1026, device='cuda:0')
# test_ll_mc = tensor(-2.6585, device='cuda:0')
#
# training time = 2.3829922676086426 seconds
# testing time (last run) = 2.875196695327759 seconds
#
# Using downloaded and verified file: ./datasets_files/yacht/yacht_hydrodynamics.data
# subset size = (123, 6)
# training set size = 98
# test set size = 25
# FCNetMCDropout(
#   (input): Sequential(
#     (0): Linear(in_features=6, out_features=25, bias=True)
#     (1): Dropout(p=0.01, inplace=False)
#   )
#   (hidden_layers): ModuleList(
#     (0): Sequential(
#       (0): Linear(in_features=25, out_features=25, bias=True)
#       (1): Dropout(p=0.01, inplace=False)
#     )
#     (1): Sequential(
#       (0): Linear(in_features=25, out_features=25, bias=True)
#       (1): Dropout(p=0.01, inplace=False)
#     )
#     (2): Sequential(
#       (0): Linear(in_features=25, out_features=25, bias=True)
#       (1): Dropout(p=0.01, inplace=False)
#     )
#   )
#   (output): Linear(in_features=25, out_features=1, bias=True)
# )
#
# Starting subset 0.400000, n_hidden 3, hidden_dim 25, dropout_rate 0.010000, reg_strength 0.075000
# final loss = 9.183121
# 10 test runs...
# rmse_mc = tensor(4.0630, device='cuda:0')
# rmse_non_mc = tensor(4.1088, device='cuda:0')
# test_ll_mc = tensor(-2.7553, device='cuda:0')
#
# 100 test runs...
# rmse_mc = tensor(4.0918, device='cuda:0')
# rmse_non_mc = tensor(4.1088, device='cuda:0')
# test_ll_mc = tensor(-2.7828, device='cuda:0')
#
# 1000 test runs...
# rmse_mc = tensor(4.1588, device='cuda:0')
# rmse_non_mc = tensor(4.1088, device='cuda:0')
# test_ll_mc = tensor(-2.7801, device='cuda:0')
#
# 3000 test runs...
# rmse_mc = tensor(4.1542, device='cuda:0')
# rmse_non_mc = tensor(4.1088, device='cuda:0')
# test_ll_mc = tensor(-2.7760, device='cuda:0')
#
# 5000 test runs...
# rmse_mc = tensor(4.1378, device='cuda:0')
# rmse_non_mc = tensor(4.1088, device='cuda:0')
# test_ll_mc = tensor(-2.7760, device='cuda:0')
#
# 7000 test runs...
# rmse_mc = tensor(4.1426, device='cuda:0')
# rmse_non_mc = tensor(4.1088, device='cuda:0')
# test_ll_mc = tensor(-2.7765, device='cuda:0')
#
# 10000 test runs...
# rmse_mc = tensor(4.1399, device='cuda:0')
# rmse_non_mc = tensor(4.1088, device='cuda:0')
# test_ll_mc = tensor(-2.7755, device='cuda:0')
#
# training time = 2.441920042037964 seconds
# testing time (last run) = 2.876197338104248 seconds
#
# Using downloaded and verified file: ./datasets_files/yacht/yacht_hydrodynamics.data
# subset size = (123, 6)
# training set size = 98
# test set size = 25
# FCNetMCDropout(
#   (input): Sequential(
#     (0): Linear(in_features=6, out_features=25, bias=True)
#     (1): Dropout(p=0.05, inplace=False)
#   )
#   (hidden_layers): ModuleList(
#     (0): Sequential(
#       (0): Linear(in_features=25, out_features=25, bias=True)
#       (1): Dropout(p=0.05, inplace=False)
#     )
#     (1): Sequential(
#       (0): Linear(in_features=25, out_features=25, bias=True)
#       (1): Dropout(p=0.05, inplace=False)
#     )
#     (2): Sequential(
#       (0): Linear(in_features=25, out_features=25, bias=True)
#       (1): Dropout(p=0.05, inplace=False)
#     )
#   )
#   (output): Linear(in_features=25, out_features=1, bias=True)
# )
#
# Starting subset 0.400000, n_hidden 3, hidden_dim 25, dropout_rate 0.050000, reg_strength 0.025000
# final loss = 14.262354
# 10 test runs...
# rmse_mc = tensor(4.0274, device='cuda:0')
# rmse_non_mc = tensor(4.0075, device='cuda:0')
# test_ll_mc = tensor(-2.9831, device='cuda:0')
#
# 100 test runs...
# rmse_mc = tensor(3.9603, device='cuda:0')
# rmse_non_mc = tensor(4.0075, device='cuda:0')
# test_ll_mc = tensor(-2.9635, device='cuda:0')
#
# 1000 test runs...
# rmse_mc = tensor(4.0743, device='cuda:0')
# rmse_non_mc = tensor(4.0075, device='cuda:0')
# test_ll_mc = tensor(-2.9679, device='cuda:0')
#
# 3000 test runs...
# rmse_mc = tensor(4.0064, device='cuda:0')
# rmse_non_mc = tensor(4.0075, device='cuda:0')
# test_ll_mc = tensor(-2.9643, device='cuda:0')
#
# 5000 test runs...
# rmse_mc = tensor(4.0449, device='cuda:0')
# rmse_non_mc = tensor(4.0075, device='cuda:0')
# test_ll_mc = tensor(-2.9665, device='cuda:0')
#
# 7000 test runs...
# rmse_mc = tensor(4.0600, device='cuda:0')
# rmse_non_mc = tensor(4.0075, device='cuda:0')
# test_ll_mc = tensor(-2.9670, device='cuda:0')
#
# 10000 test runs...
# rmse_mc = tensor(4.0354, device='cuda:0')
# rmse_non_mc = tensor(4.0075, device='cuda:0')
# test_ll_mc = tensor(-2.9662, device='cuda:0')
#
# training time = 2.3821613788604736 seconds
# testing time (last run) = 2.8916127681732178 seconds
#
# Using downloaded and verified file: ./datasets_files/yacht/yacht_hydrodynamics.data
# subset size = (123, 6)
# training set size = 98
# test set size = 25
# FCNetMCDropout(
#   (input): Sequential(
#     (0): Linear(in_features=6, out_features=25, bias=True)
#     (1): Dropout(p=0.05, inplace=False)
#   )
#   (hidden_layers): ModuleList(
#     (0): Sequential(
#       (0): Linear(in_features=25, out_features=25, bias=True)
#       (1): Dropout(p=0.05, inplace=False)
#     )
#     (1): Sequential(
#       (0): Linear(in_features=25, out_features=25, bias=True)
#       (1): Dropout(p=0.05, inplace=False)
#     )
#     (2): Sequential(
#       (0): Linear(in_features=25, out_features=25, bias=True)
#       (1): Dropout(p=0.05, inplace=False)
#     )
#   )
#   (output): Linear(in_features=25, out_features=1, bias=True)
# )
#
# Starting subset 0.400000, n_hidden 3, hidden_dim 25, dropout_rate 0.050000, reg_strength 0.050000
# final loss = 13.124315
# 10 test runs...
# rmse_mc = tensor(3.1961, device='cuda:0')
# rmse_non_mc = tensor(3.0231, device='cuda:0')
# test_ll_mc = tensor(-2.6482, device='cuda:0')
#
# 100 test runs...
# rmse_mc = tensor(3.1737, device='cuda:0')
# rmse_non_mc = tensor(3.0231, device='cuda:0')
# test_ll_mc = tensor(-2.6577, device='cuda:0')
#
# 1000 test runs...
# rmse_mc = tensor(3.0353, device='cuda:0')
# rmse_non_mc = tensor(3.0231, device='cuda:0')
# test_ll_mc = tensor(-2.6499, device='cuda:0')
#
# 3000 test runs...
# rmse_mc = tensor(3.0487, device='cuda:0')
# rmse_non_mc = tensor(3.0231, device='cuda:0')
# test_ll_mc = tensor(-2.6527, device='cuda:0')
#
# 5000 test runs...
# rmse_mc = tensor(3.0518, device='cuda:0')
# rmse_non_mc = tensor(3.0231, device='cuda:0')
# test_ll_mc = tensor(-2.6526, device='cuda:0')
#
# 7000 test runs...
# rmse_mc = tensor(3.0631, device='cuda:0')
# rmse_non_mc = tensor(3.0231, device='cuda:0')
# test_ll_mc = tensor(-2.6534, device='cuda:0')
#
# 10000 test runs...
# rmse_mc = tensor(3.0554, device='cuda:0')
# rmse_non_mc = tensor(3.0231, device='cuda:0')
# test_ll_mc = tensor(-2.6520, device='cuda:0')
#
# training time = 2.3914873600006104 seconds
# testing time (last run) = 2.8818564414978027 seconds
#
# Using downloaded and verified file: ./datasets_files/yacht/yacht_hydrodynamics.data
# subset size = (123, 6)
# training set size = 98
# test set size = 25
# FCNetMCDropout(
#   (input): Sequential(
#     (0): Linear(in_features=6, out_features=25, bias=True)
#     (1): Dropout(p=0.05, inplace=False)
#   )
#   (hidden_layers): ModuleList(
#     (0): Sequential(
#       (0): Linear(in_features=25, out_features=25, bias=True)
#       (1): Dropout(p=0.05, inplace=False)
#     )
#     (1): Sequential(
#       (0): Linear(in_features=25, out_features=25, bias=True)
#       (1): Dropout(p=0.05, inplace=False)
#     )
#     (2): Sequential(
#       (0): Linear(in_features=25, out_features=25, bias=True)
#       (1): Dropout(p=0.05, inplace=False)
#     )
#   )
#   (output): Linear(in_features=25, out_features=1, bias=True)
# )
#
# Starting subset 0.400000, n_hidden 3, hidden_dim 25, dropout_rate 0.050000, reg_strength 0.075000
# final loss = 10.443907
# 10 test runs...
# rmse_mc = tensor(4.7271, device='cuda:0')
# rmse_non_mc = tensor(4.7869, device='cuda:0')
# test_ll_mc = tensor(-2.6995, device='cuda:0')
#
# 100 test runs...
# rmse_mc = tensor(4.7935, device='cuda:0')
# rmse_non_mc = tensor(4.7869, device='cuda:0')
# test_ll_mc = tensor(-2.7107, device='cuda:0')
#
# 1000 test runs...
# rmse_mc = tensor(4.7510, device='cuda:0')
# rmse_non_mc = tensor(4.7869, device='cuda:0')
# test_ll_mc = tensor(-2.7080, device='cuda:0')
#
# 3000 test runs...
# rmse_mc = tensor(4.7541, device='cuda:0')
# rmse_non_mc = tensor(4.7869, device='cuda:0')
# test_ll_mc = tensor(-2.7073, device='cuda:0')
#
# 5000 test runs...
# rmse_mc = tensor(4.7671, device='cuda:0')
# rmse_non_mc = tensor(4.7869, device='cuda:0')
# test_ll_mc = tensor(-2.7084, device='cuda:0')
#
# 7000 test runs...
# rmse_mc = tensor(4.7684, device='cuda:0')
# rmse_non_mc = tensor(4.7869, device='cuda:0')
# test_ll_mc = tensor(-2.7101, device='cuda:0')
#
# 10000 test runs...
# rmse_mc = tensor(4.7916, device='cuda:0')
# rmse_non_mc = tensor(4.7869, device='cuda:0')
# test_ll_mc = tensor(-2.7135, device='cuda:0')
#
# training time = 2.3503003120422363 seconds
# testing time (last run) = 2.8059680461883545 seconds
#
# Using downloaded and verified file: ./datasets_files/yacht/yacht_hydrodynamics.data
# subset size = (123, 6)
# training set size = 98
# test set size = 25
# FCNetMCDropout(
#   (input): Sequential(
#     (0): Linear(in_features=6, out_features=25, bias=True)
#     (1): Dropout(p=0.1, inplace=False)
#   )
#   (hidden_layers): ModuleList(
#     (0): Sequential(
#       (0): Linear(in_features=25, out_features=25, bias=True)
#       (1): Dropout(p=0.1, inplace=False)
#     )
#     (1): Sequential(
#       (0): Linear(in_features=25, out_features=25, bias=True)
#       (1): Dropout(p=0.1, inplace=False)
#     )
#     (2): Sequential(
#       (0): Linear(in_features=25, out_features=25, bias=True)
#       (1): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (output): Linear(in_features=25, out_features=1, bias=True)
# )
#
# Starting subset 0.400000, n_hidden 3, hidden_dim 25, dropout_rate 0.100000, reg_strength 0.025000
# final loss = 22.803566
# 10 test runs...
# rmse_mc = tensor(4.3827, device='cuda:0')
# rmse_non_mc = tensor(4.7837, device='cuda:0')
# test_ll_mc = tensor(-3.0408, device='cuda:0')
#
# 100 test runs...
# rmse_mc = tensor(4.6303, device='cuda:0')
# rmse_non_mc = tensor(4.7837, device='cuda:0')
# test_ll_mc = tensor(-3.0741, device='cuda:0')
#
# 1000 test runs...
# rmse_mc = tensor(4.6439, device='cuda:0')
# rmse_non_mc = tensor(4.7837, device='cuda:0')
# test_ll_mc = tensor(-3.0761, device='cuda:0')
#
# 3000 test runs...
# rmse_mc = tensor(4.6751, device='cuda:0')
# rmse_non_mc = tensor(4.7837, device='cuda:0')
# test_ll_mc = tensor(-3.0764, device='cuda:0')
#
# 5000 test runs...
# rmse_mc = tensor(4.7379, device='cuda:0')
# rmse_non_mc = tensor(4.7837, device='cuda:0')
# test_ll_mc = tensor(-3.0802, device='cuda:0')
#
# 7000 test runs...
# rmse_mc = tensor(4.6811, device='cuda:0')
# rmse_non_mc = tensor(4.7837, device='cuda:0')
# test_ll_mc = tensor(-3.0752, device='cuda:0')
#
# 10000 test runs...
# rmse_mc = tensor(4.7092, device='cuda:0')
# rmse_non_mc = tensor(4.7837, device='cuda:0')
# test_ll_mc = tensor(-3.0783, device='cuda:0')
#
# training time = 2.3378827571868896 seconds
# testing time (last run) = 2.8359994888305664 seconds
#
# Using downloaded and verified file: ./datasets_files/yacht/yacht_hydrodynamics.data
# subset size = (123, 6)
# training set size = 98
# test set size = 25
# FCNetMCDropout(
#   (input): Sequential(
#     (0): Linear(in_features=6, out_features=25, bias=True)
#     (1): Dropout(p=0.1, inplace=False)
#   )
#   (hidden_layers): ModuleList(
#     (0): Sequential(
#       (0): Linear(in_features=25, out_features=25, bias=True)
#       (1): Dropout(p=0.1, inplace=False)
#     )
#     (1): Sequential(
#       (0): Linear(in_features=25, out_features=25, bias=True)
#       (1): Dropout(p=0.1, inplace=False)
#     )
#     (2): Sequential(
#       (0): Linear(in_features=25, out_features=25, bias=True)
#       (1): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (output): Linear(in_features=25, out_features=1, bias=True)
# )
#
# Starting subset 0.400000, n_hidden 3, hidden_dim 25, dropout_rate 0.100000, reg_strength 0.050000
# final loss = 56.292595
# 10 test runs...
# rmse_mc = tensor(2.8635, device='cuda:0')
# rmse_non_mc = tensor(2.6970, device='cuda:0')
# test_ll_mc = tensor(-2.6164, device='cuda:0')
#
# 100 test runs...
# rmse_mc = tensor(2.5157, device='cuda:0')
# rmse_non_mc = tensor(2.6970, device='cuda:0')
# test_ll_mc = tensor(-2.6178, device='cuda:0')
#
# 1000 test runs...
# rmse_mc = tensor(2.7924, device='cuda:0')
# rmse_non_mc = tensor(2.6970, device='cuda:0')
# test_ll_mc = tensor(-2.6265, device='cuda:0')
#
# 3000 test runs...
# rmse_mc = tensor(2.7435, device='cuda:0')
# rmse_non_mc = tensor(2.6970, device='cuda:0')
# test_ll_mc = tensor(-2.6220, device='cuda:0')
#
# 5000 test runs...
# rmse_mc = tensor(2.7667, device='cuda:0')
# rmse_non_mc = tensor(2.6970, device='cuda:0')
# test_ll_mc = tensor(-2.6245, device='cuda:0')
#
# 7000 test runs...
# rmse_mc = tensor(2.7410, device='cuda:0')
# rmse_non_mc = tensor(2.6970, device='cuda:0')
# test_ll_mc = tensor(-2.6233, device='cuda:0')
#
# 10000 test runs...
# rmse_mc = tensor(2.7631, device='cuda:0')
# rmse_non_mc = tensor(2.6970, device='cuda:0')
# test_ll_mc = tensor(-2.6257, device='cuda:0')
#
# training time = 2.3621253967285156 seconds
# testing time (last run) = 2.808084487915039 seconds
#
# Using downloaded and verified file: ./datasets_files/yacht/yacht_hydrodynamics.data
# subset size = (123, 6)
# training set size = 98
# test set size = 25
# FCNetMCDropout(
#   (input): Sequential(
#     (0): Linear(in_features=6, out_features=25, bias=True)
#     (1): Dropout(p=0.1, inplace=False)
#   )
#   (hidden_layers): ModuleList(
#     (0): Sequential(
#       (0): Linear(in_features=25, out_features=25, bias=True)
#       (1): Dropout(p=0.1, inplace=False)
#     )
#     (1): Sequential(
#       (0): Linear(in_features=25, out_features=25, bias=True)
#       (1): Dropout(p=0.1, inplace=False)
#     )
#     (2): Sequential(
#       (0): Linear(in_features=25, out_features=25, bias=True)
#       (1): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (output): Linear(in_features=25, out_features=1, bias=True)
# )
#
# Starting subset 0.400000, n_hidden 3, hidden_dim 25, dropout_rate 0.100000, reg_strength 0.075000
# final loss = 33.313755
# 10 test runs...
# rmse_mc = tensor(3.6591, device='cuda:0')
# rmse_non_mc = tensor(3.0286, device='cuda:0')
# test_ll_mc = tensor(-2.4675, device='cuda:0')
#
# 100 test runs...
# rmse_mc = tensor(3.0963, device='cuda:0')
# rmse_non_mc = tensor(3.0286, device='cuda:0')
# test_ll_mc = tensor(-2.4491, device='cuda:0')
#
# 1000 test runs...
# rmse_mc = tensor(2.9851, device='cuda:0')
# rmse_non_mc = tensor(3.0286, device='cuda:0')
# test_ll_mc = tensor(-2.4443, device='cuda:0')
#
# 3000 test runs...
# rmse_mc = tensor(2.9999, device='cuda:0')
# rmse_non_mc = tensor(3.0286, device='cuda:0')
# test_ll_mc = tensor(-2.4466, device='cuda:0')
#
# 5000 test runs...
# rmse_mc = tensor(2.9420, device='cuda:0')
# rmse_non_mc = tensor(3.0286, device='cuda:0')
# test_ll_mc = tensor(-2.4435, device='cuda:0')
#
# 7000 test runs...
# rmse_mc = tensor(3.0224, device='cuda:0')
# rmse_non_mc = tensor(3.0286, device='cuda:0')
# test_ll_mc = tensor(-2.4493, device='cuda:0')
#
# 10000 test runs...
# rmse_mc = tensor(2.9876, device='cuda:0')
# rmse_non_mc = tensor(3.0286, device='cuda:0')
# test_ll_mc = tensor(-2.4459, device='cuda:0')
#
# training time = 2.353233814239502 seconds
# testing time (last run) = 2.799896240234375 seconds
#
# Using downloaded and verified file: ./datasets_files/yacht/yacht_hydrodynamics.data
# subset size = (123, 6)
# training set size = 98
# test set size = 25
# FCNetMCDropout(
#   (input): Sequential(
#     (0): Linear(in_features=6, out_features=25, bias=True)
#     (1): Dropout(p=0.005, inplace=False)
#   )
#   (hidden_layers): ModuleList(
#     (0): Sequential(
#       (0): Linear(in_features=25, out_features=25, bias=True)
#       (1): Dropout(p=0.005, inplace=False)
#     )
#     (1): Sequential(
#       (0): Linear(in_features=25, out_features=25, bias=True)
#       (1): Dropout(p=0.005, inplace=False)
#     )
#     (2): Sequential(
#       (0): Linear(in_features=25, out_features=25, bias=True)
#       (1): Dropout(p=0.005, inplace=False)
#     )
#     (3): Sequential(
#       (0): Linear(in_features=25, out_features=25, bias=True)
#       (1): Dropout(p=0.005, inplace=False)
#     )
#     (4): Sequential(
#       (0): Linear(in_features=25, out_features=25, bias=True)
#       (1): Dropout(p=0.005, inplace=False)
#     )
#   )
#   (output): Linear(in_features=25, out_features=1, bias=True)
# )
#
# Starting subset 0.400000, n_hidden 5, hidden_dim 25, dropout_rate 0.005000, reg_strength 0.025000
# final loss = 10.584254
# 10 test runs...
# rmse_mc = tensor(5.7023, device='cuda:0')
# rmse_non_mc = tensor(5.0376, device='cuda:0')
# test_ll_mc = tensor(-3.1052, device='cuda:0')
#
# 100 test runs...
# rmse_mc = tensor(5.2032, device='cuda:0')
# rmse_non_mc = tensor(5.0376, device='cuda:0')
# ...
#     )
#     (1): Sequential(
#       (0): Linear(in_features=100, out_features=100, bias=True)
#       (1): Dropout(p=0.01, inplace=False)
#     )
#     (2): Sequential(
#       (0): Linear(in_features=100, out_features=100, bias=True)
#       (1): Dropout(p=0.01, inplace=False)
#     )
#     (3): Sequential(
#       (0): Linear(in_features=100, out_features=100, bias=True)
#       (1): Dropout(p=0.01, inplace=False)
#     )
#     (4): Sequential(
#       (0): Linear(in_features=100, out_features=100, bias=True)
#       (1): Dropout(p=0.01, inplace=False)
#     )
#   )
#   (output): Linear(in_features=100, out_features=1, bias=True)
# )
#
# Starting subset 1.000000, n_hidden 5, hidden_dim 100, dropout_rate 0.010000, reg_strength 0.075000
# final loss = 26.109564
# 10 test runs...
# rmse_mc = tensor(37.3276, device='cuda:0')
# rmse_non_mc = tensor(37.3273, device='cuda:0')
# test_ll_mc = tensor(-54.4647, device='cuda:0')
#
# 100 test runs...
# rmse_mc = tensor(37.3278, device='cuda:0')
# rmse_non_mc = tensor(37.3273, device='cuda:0')
# test_ll_mc = tensor(-54.4651, device='cuda:0')
#
# 1000 test runs...
# rmse_mc = tensor(37.3278, device='cuda:0')
# rmse_non_mc = tensor(37.3273, device='cuda:0')
# test_ll_mc = tensor(-54.4651, device='cuda:0')
#
# 3000 test runs...
# rmse_mc = tensor(37.3277, device='cuda:0')
# rmse_non_mc = tensor(37.3273, device='cuda:0')
# test_ll_mc = tensor(-54.4649, device='cuda:0')
#
# 5000 test runs...
# rmse_mc = tensor(37.3278, device='cuda:0')
# rmse_non_mc = tensor(37.3273, device='cuda:0')
# test_ll_mc = tensor(-54.4652, device='cuda:0')
#
# 7000 test runs...
# rmse_mc = tensor(37.3278, device='cuda:0')
# rmse_non_mc = tensor(37.3273, device='cuda:0')
# test_ll_mc = tensor(-54.4651, device='cuda:0')
#
# 10000 test runs...
# rmse_mc = tensor(37.3278, device='cuda:0')
# rmse_non_mc = tensor(37.3273, device='cuda:0')
# test_ll_mc = tensor(-54.4651, device='cuda:0')
#
# training time = 0.003856182098388672 seconds
# testing time (last run) = 4.194974422454834 seconds
#
# Using downloaded and verified file: ./datasets_files/yacht/yacht_hydrodynamics.data
# subset size = (1, 6)
# training set size = 0
# test set size = 1
# FCNetMCDropout(
#   (input): Sequential(
#     (0): Linear(in_features=6, out_features=100, bias=True)
#     (1): Dropout(p=0.05, inplace=False)
#   )
#   (hidden_layers): ModuleList(
#     (0): Sequential(
#       (0): Linear(in_features=100, out_features=100, bias=True)
#       (1): Dropout(p=0.05, inplace=False)
#     )
#     (1): Sequential(
#       (0): Linear(in_features=100, out_features=100, bias=True)
#       (1): Dropout(p=0.05, inplace=False)
#     )
#     (2): Sequential(
#       (0): Linear(in_features=100, out_features=100, bias=True)
#       (1): Dropout(p=0.05, inplace=False)
#     )
#     (3): Sequential(
#       (0): Linear(in_features=100, out_features=100, bias=True)
#       (1): Dropout(p=0.05, inplace=False)
#     )
#     (4): Sequential(
#       (0): Linear(in_features=100, out_features=100, bias=True)
#       (1): Dropout(p=0.05, inplace=False)
#     )
#   )
#   (output): Linear(in_features=100, out_features=1, bias=True)
# )
#
# Starting subset 1.000000, n_hidden 5, hidden_dim 100, dropout_rate 0.050000, reg_strength 0.025000
# final loss = 26.109564
# 10 test runs...
# rmse_mc = tensor(2.5627, device='cuda:0')
# rmse_non_mc = tensor(2.5663, device='cuda:0')
# test_ll_mc = tensor(-2.8455, device='cuda:0')
#
# 100 test runs...
# rmse_mc = tensor(2.5670, device='cuda:0')
# rmse_non_mc = tensor(2.5663, device='cuda:0')
# test_ll_mc = tensor(-2.8457, device='cuda:0')
#
# 1000 test runs...
# rmse_mc = tensor(2.5673, device='cuda:0')
# rmse_non_mc = tensor(2.5663, device='cuda:0')
# test_ll_mc = tensor(-2.8458, device='cuda:0')
#
# 3000 test runs...
# rmse_mc = tensor(2.5674, device='cuda:0')
# rmse_non_mc = tensor(2.5663, device='cuda:0')
# test_ll_mc = tensor(-2.8458, device='cuda:0')
#
# 5000 test runs...
# rmse_mc = tensor(2.5672, device='cuda:0')
# rmse_non_mc = tensor(2.5663, device='cuda:0')
# test_ll_mc = tensor(-2.8458, device='cuda:0')
#
# 7000 test runs...
# rmse_mc = tensor(2.5675, device='cuda:0')
# rmse_non_mc = tensor(2.5663, device='cuda:0')
# test_ll_mc = tensor(-2.8458, device='cuda:0')
#
# 10000 test runs...
# rmse_mc = tensor(2.5671, device='cuda:0')
# rmse_non_mc = tensor(2.5663, device='cuda:0')
# test_ll_mc = tensor(-2.8458, device='cuda:0')
#
# training time = 0.003695964813232422 seconds
# testing time (last run) = 4.307667970657349 seconds
#
# Using downloaded and verified file: ./datasets_files/yacht/yacht_hydrodynamics.data
# subset size = (1, 6)
# training set size = 0
# test set size = 1
# FCNetMCDropout(
#   (input): Sequential(
#     (0): Linear(in_features=6, out_features=100, bias=True)
#     (1): Dropout(p=0.05, inplace=False)
#   )
#   (hidden_layers): ModuleList(
#     (0): Sequential(
#       (0): Linear(in_features=100, out_features=100, bias=True)
#       (1): Dropout(p=0.05, inplace=False)
#     )
#     (1): Sequential(
#       (0): Linear(in_features=100, out_features=100, bias=True)
#       (1): Dropout(p=0.05, inplace=False)
#     )
#     (2): Sequential(
#       (0): Linear(in_features=100, out_features=100, bias=True)
#       (1): Dropout(p=0.05, inplace=False)
#     )
#     (3): Sequential(
#       (0): Linear(in_features=100, out_features=100, bias=True)
#       (1): Dropout(p=0.05, inplace=False)
#     )
#     (4): Sequential(
#       (0): Linear(in_features=100, out_features=100, bias=True)
#       (1): Dropout(p=0.05, inplace=False)
#     )
#   )
#   (output): Linear(in_features=100, out_features=1, bias=True)
# )
#
# Starting subset 1.000000, n_hidden 5, hidden_dim 100, dropout_rate 0.050000, reg_strength 0.050000
# final loss = 26.109564
# 10 test runs...
# rmse_mc = tensor(50.1837, device='cuda:0')
# rmse_non_mc = tensor(50.1800, device='cuda:0')
# test_ll_mc = tensor(-65.3766, device='cuda:0')
#
# 100 test runs...
# rmse_mc = tensor(50.1799, device='cuda:0')
# rmse_non_mc = tensor(50.1800, device='cuda:0')
# test_ll_mc = tensor(-65.3669, device='cuda:0')
#
# 1000 test runs...
# rmse_mc = tensor(50.1805, device='cuda:0')
# rmse_non_mc = tensor(50.1800, device='cuda:0')
# test_ll_mc = tensor(-65.3685, device='cuda:0')
#
# 3000 test runs...
# rmse_mc = tensor(50.1804, device='cuda:0')
# rmse_non_mc = tensor(50.1800, device='cuda:0')
# test_ll_mc = tensor(-65.3682, device='cuda:0')
#
# 5000 test runs...
# rmse_mc = tensor(50.1803, device='cuda:0')
# rmse_non_mc = tensor(50.1800, device='cuda:0')
# test_ll_mc = tensor(-65.3679, device='cuda:0')
#
# 7000 test runs...
# rmse_mc = tensor(50.1807, device='cuda:0')
# rmse_non_mc = tensor(50.1800, device='cuda:0')
# test_ll_mc = tensor(-65.3691, device='cuda:0')
#
# 10000 test runs...
# rmse_mc = tensor(50.1804, device='cuda:0')
# rmse_non_mc = tensor(50.1800, device='cuda:0')
# test_ll_mc = tensor(-65.3684, device='cuda:0')
#
# training time = 0.005126953125 seconds
# testing time (last run) = 4.19706654548645 seconds
#
# Using downloaded and verified file: ./datasets_files/yacht/yacht_hydrodynamics.data
# subset size = (1, 6)
# training set size = 0
# test set size = 1
# FCNetMCDropout(
#   (input): Sequential(
#     (0): Linear(in_features=6, out_features=100, bias=True)
#     (1): Dropout(p=0.05, inplace=False)
#   )
#   (hidden_layers): ModuleList(
#     (0): Sequential(
#       (0): Linear(in_features=100, out_features=100, bias=True)
#       (1): Dropout(p=0.05, inplace=False)
#     )
#     (1): Sequential(
#       (0): Linear(in_features=100, out_features=100, bias=True)
#       (1): Dropout(p=0.05, inplace=False)
#     )
#     (2): Sequential(
#       (0): Linear(in_features=100, out_features=100, bias=True)
#       (1): Dropout(p=0.05, inplace=False)
#     )
#     (3): Sequential(
#       (0): Linear(in_features=100, out_features=100, bias=True)
#       (1): Dropout(p=0.05, inplace=False)
#     )
#     (4): Sequential(
#       (0): Linear(in_features=100, out_features=100, bias=True)
#       (1): Dropout(p=0.05, inplace=False)
#     )
#   )
#   (output): Linear(in_features=100, out_features=1, bias=True)
# )
#
# Starting subset 1.000000, n_hidden 5, hidden_dim 100, dropout_rate 0.050000, reg_strength 0.075000
# final loss = 26.109564
# 10 test runs...
# rmse_mc = tensor(4.0188, device='cuda:0')
# rmse_non_mc = tensor(4.0184, device='cuda:0')
# test_ll_mc = tensor(-2.8197, device='cuda:0')
#
# 100 test runs...
# rmse_mc = tensor(4.0185, device='cuda:0')
# rmse_non_mc = tensor(4.0184, device='cuda:0')
# test_ll_mc = tensor(-2.8196, device='cuda:0')
#
# 1000 test runs...
# rmse_mc = tensor(4.0189, device='cuda:0')
# rmse_non_mc = tensor(4.0184, device='cuda:0')
# test_ll_mc = tensor(-2.8198, device='cuda:0')
#
# 3000 test runs...
# rmse_mc = tensor(4.0190, device='cuda:0')
# rmse_non_mc = tensor(4.0184, device='cuda:0')
# test_ll_mc = tensor(-2.8198, device='cuda:0')
#
# 5000 test runs...
# rmse_mc = tensor(4.0188, device='cuda:0')
# rmse_non_mc = tensor(4.0184, device='cuda:0')
# test_ll_mc = tensor(-2.8197, device='cuda:0')
#
# 7000 test runs...
# rmse_mc = tensor(4.0189, device='cuda:0')
# rmse_non_mc = tensor(4.0184, device='cuda:0')
# test_ll_mc = tensor(-2.8197, device='cuda:0')
#
# 10000 test runs...
# rmse_mc = tensor(4.0188, device='cuda:0')
# rmse_non_mc = tensor(4.0184, device='cuda:0')
# test_ll_mc = tensor(-2.8197, device='cuda:0')
#
# training time = 0.003888368606567383 seconds
# testing time (last run) = 4.333186149597168 seconds
#
# Using downloaded and verified file: ./datasets_files/yacht/yacht_hydrodynamics.data
# subset size = (1, 6)
# training set size = 0
# test set size = 1
# FCNetMCDropout(
#   (input): Sequential(
#     (0): Linear(in_features=6, out_features=100, bias=True)
#     (1): Dropout(p=0.1, inplace=False)
#   )
#   (hidden_layers): ModuleList(
#     (0): Sequential(
#       (0): Linear(in_features=100, out_features=100, bias=True)
#       (1): Dropout(p=0.1, inplace=False)
#     )
#     (1): Sequential(
#       (0): Linear(in_features=100, out_features=100, bias=True)
#       (1): Dropout(p=0.1, inplace=False)
#     )
#     (2): Sequential(
#       (0): Linear(in_features=100, out_features=100, bias=True)
#       (1): Dropout(p=0.1, inplace=False)
#     )
#     (3): Sequential(
#       (0): Linear(in_features=100, out_features=100, bias=True)
#       (1): Dropout(p=0.1, inplace=False)
#     )
#     (4): Sequential(
#       (0): Linear(in_features=100, out_features=100, bias=True)
#       (1): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (output): Linear(in_features=100, out_features=1, bias=True)
# )
#
# Starting subset 1.000000, n_hidden 5, hidden_dim 100, dropout_rate 0.100000, reg_strength 0.025000
# final loss = 26.109564
# 10 test runs...
# rmse_mc = tensor(0.1122, device='cuda:0')
# rmse_non_mc = tensor(0.1111, device='cuda:0')
# test_ll_mc = tensor(-2.7635, device='cuda:0')
#
# 100 test runs...
# rmse_mc = tensor(0.1076, device='cuda:0')
# rmse_non_mc = tensor(0.1111, device='cuda:0')
# test_ll_mc = tensor(-2.7635, device='cuda:0')
#
# 1000 test runs...
# rmse_mc = tensor(0.1084, device='cuda:0')
# rmse_non_mc = tensor(0.1111, device='cuda:0')
# test_ll_mc = tensor(-2.7635, device='cuda:0')
#
# 3000 test runs...
# rmse_mc = tensor(0.1082, device='cuda:0')
# rmse_non_mc = tensor(0.1111, device='cuda:0')
# test_ll_mc = tensor(-2.7635, device='cuda:0')
#
# 5000 test runs...
# rmse_mc = tensor(0.1085, device='cuda:0')
# rmse_non_mc = tensor(0.1111, device='cuda:0')
# test_ll_mc = tensor(-2.7635, device='cuda:0')
#
# 7000 test runs...
# rmse_mc = tensor(0.1085, device='cuda:0')
# rmse_non_mc = tensor(0.1111, device='cuda:0')
# test_ll_mc = tensor(-2.7635, device='cuda:0')
#
# 10000 test runs...
# rmse_mc = tensor(0.1083, device='cuda:0')
# rmse_non_mc = tensor(0.1111, device='cuda:0')
# test_ll_mc = tensor(-2.7635, device='cuda:0')
#
# training time = 0.003606557846069336 seconds
# testing time (last run) = 4.257765531539917 seconds
#
# Using downloaded and verified file: ./datasets_files/yacht/yacht_hydrodynamics.data
# subset size = (1, 6)
# training set size = 0
# test set size = 1
# FCNetMCDropout(
#   (input): Sequential(
#     (0): Linear(in_features=6, out_features=100, bias=True)
#     (1): Dropout(p=0.1, inplace=False)
#   )
#   (hidden_layers): ModuleList(
#     (0): Sequential(
#       (0): Linear(in_features=100, out_features=100, bias=True)
#       (1): Dropout(p=0.1, inplace=False)
#     )
#     (1): Sequential(
#       (0): Linear(in_features=100, out_features=100, bias=True)
#       (1): Dropout(p=0.1, inplace=False)
#     )
#     (2): Sequential(
#       (0): Linear(in_features=100, out_features=100, bias=True)
#       (1): Dropout(p=0.1, inplace=False)
#     )
#     (3): Sequential(
#       (0): Linear(in_features=100, out_features=100, bias=True)
#       (1): Dropout(p=0.1, inplace=False)
#     )
#     (4): Sequential(
#       (0): Linear(in_features=100, out_features=100, bias=True)
#       (1): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (output): Linear(in_features=100, out_features=1, bias=True)
# )
#
# Starting subset 1.000000, n_hidden 5, hidden_dim 100, dropout_rate 0.100000, reg_strength 0.050000
# final loss = 26.109564
# 10 test runs...
# rmse_mc = tensor(0.8705, device='cuda:0')
# rmse_non_mc = tensor(0.8606, device='cuda:0')
# test_ll_mc = tensor(-2.4358, device='cuda:0')
#
# 100 test runs...
# rmse_mc = tensor(0.8622, device='cuda:0')
# rmse_non_mc = tensor(0.8606, device='cuda:0')
# test_ll_mc = tensor(-2.4354, device='cuda:0')
#
# 1000 test runs...
# rmse_mc = tensor(0.8616, device='cuda:0')
# rmse_non_mc = tensor(0.8606, device='cuda:0')
# test_ll_mc = tensor(-2.4354, device='cuda:0')
#
# 3000 test runs...
# rmse_mc = tensor(0.8613, device='cuda:0')
# rmse_non_mc = tensor(0.8606, device='cuda:0')
# test_ll_mc = tensor(-2.4354, device='cuda:0')
#
# 5000 test runs...
# rmse_mc = tensor(0.8614, device='cuda:0')
# rmse_non_mc = tensor(0.8606, device='cuda:0')
# test_ll_mc = tensor(-2.4354, device='cuda:0')
#
# 7000 test runs...
# rmse_mc = tensor(0.8614, device='cuda:0')
# rmse_non_mc = tensor(0.8606, device='cuda:0')
# test_ll_mc = tensor(-2.4354, device='cuda:0')
#
# 10000 test runs...
# rmse_mc = tensor(0.8616, device='cuda:0')
# rmse_non_mc = tensor(0.8606, device='cuda:0')
# test_ll_mc = tensor(-2.4354, device='cuda:0')
#
# training time = 0.003854513168334961 seconds
# testing time (last run) = 4.223736763000488 seconds
#
# Using downloaded and verified file: ./datasets_files/yacht/yacht_hydrodynamics.data
# subset size = (1, 6)
# training set size = 0
# test set size = 1
# FCNetMCDropout(
#   (input): Sequential(
#     (0): Linear(in_features=6, out_features=100, bias=True)
#     (1): Dropout(p=0.1, inplace=False)
#   )
#   (hidden_layers): ModuleList(
#     (0): Sequential(
#       (0): Linear(in_features=100, out_features=100, bias=True)
#       (1): Dropout(p=0.1, inplace=False)
#     )
#     (1): Sequential(
#       (0): Linear(in_features=100, out_features=100, bias=True)
#       (1): Dropout(p=0.1, inplace=False)
#     )
#     (2): Sequential(
#       (0): Linear(in_features=100, out_features=100, bias=True)
#       (1): Dropout(p=0.1, inplace=False)
#     )
#     (3): Sequential(
#       (0): Linear(in_features=100, out_features=100, bias=True)
#       (1): Dropout(p=0.1, inplace=False)
#     )
#     (4): Sequential(
#       (0): Linear(in_features=100, out_features=100, bias=True)
#       (1): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (output): Linear(in_features=100, out_features=1, bias=True)
# )
#
# Starting subset 1.000000, n_hidden 5, hidden_dim 100, dropout_rate 0.100000, reg_strength 0.075000
# final loss = 26.109564
# 10 test runs...
# rmse_mc = tensor(51.7992, device='cuda:0')
# rmse_non_mc = tensor(51.7988, device='cuda:0')
# test_ll_mc = tensor(-102.8314, device='cuda:0')
#
# 100 test runs...
# rmse_mc = tensor(51.7972, device='cuda:0')
# rmse_non_mc = tensor(51.7988, device='cuda:0')
# test_ll_mc = tensor(-102.8236, device='cuda:0')
#
# 1000 test runs...
# rmse_mc = tensor(51.7953, device='cuda:0')
# rmse_non_mc = tensor(51.7988, device='cuda:0')
# test_ll_mc = tensor(-102.8161, device='cuda:0')
#
# 3000 test runs...
# rmse_mc = tensor(51.7956, device='cuda:0')
# rmse_non_mc = tensor(51.7988, device='cuda:0')
# test_ll_mc = tensor(-102.8171, device='cuda:0')
#
# 5000 test runs...
# rmse_mc = tensor(51.7956, device='cuda:0')
# rmse_non_mc = tensor(51.7988, device='cuda:0')
# test_ll_mc = tensor(-102.8172, device='cuda:0')
#
# 7000 test runs...
# rmse_mc = tensor(51.7957, device='cuda:0')
# rmse_non_mc = tensor(51.7988, device='cuda:0')
# test_ll_mc = tensor(-102.8176, device='cuda:0')
#
# 10000 test runs...
# rmse_mc = tensor(51.7956, device='cuda:0')
# rmse_non_mc = tensor(51.7988, device='cuda:0')
# test_ll_mc = tensor(-102.8173, device='cuda:0')
#
# training time = 0.00394439697265625 seconds
# testing time (last run) = 4.204565763473511 seconds
