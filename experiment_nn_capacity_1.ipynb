# %%
# Google Colab-only setup. No need to run this cell in other environments.
use_colab = True

if use_colab:
    # Mount my Google Drive root folder
    from google.colab import drive
    drive.mount('/content/drive')

    # cd to bayesian-dl-experiments directory
    # %cd 'drive/My Drive/Colab Notebooks/bayesian-dl-experiments'
    # !ls
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/Colab Notebooks/bayesian-dl-experiments
# datasets_files	experiments.ipynb  LICENSE  README.md  ronald_bdl

# %% [markdown]
# ## Experiment Setup

# %% [markdown]
# ### Random seed / PyTorch / CUDA related

# %%
import torch
import numpy as np

# IPython reloading magic
# %load_ext autoreload
# %autoreload 2

# Random seeds
# Based on https://pytorch.org/docs/stable/notes/randomness.html
torch.manual_seed(682)
np.random.seed(682)

# torch.device / CUDA Setup
use_cuda = True

if use_cuda and torch.cuda.is_available():
    torch_device = torch.device('cuda')
    torch.backends.cudnn.deterministic = True
    # Note: https://discuss.pytorch.org/t/what-does-torch-backends-cudnn-benchmark-do/5936
    torch.backends.cudnn.benchmark = False
    use_pin_memory=True # Faster Host to GPU copies with page-locked memory
else:
    torch_device = torch.device('cpu')
    use_pin_memory=False

# %% [markdown]
# ### Variable settings

# %%
# Dataset to use
dataset_name = 'yacht' #@param ["yacht"]

# Training set size
dataset_train_size = 0.8 #@param {type:"slider", min:0.1, max:0.9, step:0.05}

# L2 regularization strength
reg_strength = 0.01 #@param {type:"slider", min:0, max:1.0, step:0.05}

# Epochs
n_epochs = 4000 #@param {type:"integer"}

# Number of different data splits to try
n_splits = 20 #@param {type:"integer"}

# Data batch sizes
n_training_batch = 128 #@param {type:"integer"}

# Number of test predictions (for each data point)
n_predictions = 10000 #@param {type:"integer"}

# %% [markdown]
# ## Prepare data

# %% [markdown]
# ### Get the data as a torch Dataset object

# %%
from torch.utils.data import random_split, DataLoader
from ronald_bdl import datasets

if dataset_name == 'MNIST':
    dataset = datasets.MNIST(root_dir='./datasets_files', transform=None, download=True)
else:
    dataset = datasets.UCIDatasets(dataset_name, root_dir='./datasets_files', transform=None, download=True)

# Set the training/test set sizes
train_size = int(dataset_train_size * len(dataset))
test_size = len(dataset) - train_size
    
# Print the size of the dataset
print("dataset size = " + str(dataset.data.shape))
print("training set size = " + str(train_size))
print("testing set size = " + str(test_size))
# Out:
# Using downloaded and verified file: ./datasets_files/yacht/yacht_hydrodynamics.data
# dataset size = torch.Size([308, 7])
# training set size = 246
# testing set size = 62

# %% [markdown]
# ## Define network

# %%
from ronald_bdl import models

network = models.FCNetMCDropout(
    input_dim=dataset.n_features, 
    output_dim=dataset.n_targets,
    hidden_dim=100,
    n_hidden=2,
    dropout_rate=0.01,
    dropout_type='bernoulli',
)

# Send the whole model to the selected torch.device
network.to(torch_device)

# Print the network structure
print(network)
# Out:
# FCNetMCDropout(
#   (input): Linear(in_features=6, out_features=100, bias=True)
#   (hidden_layers): ModuleList(
#     (0): Linear(in_features=100, out_features=100, bias=True)
#     (1): Linear(in_features=100, out_features=100, bias=True)
#   )
#   (output): Linear(in_features=100, out_features=1, bias=True)
# )

# %% [markdown]
# ## Train the network

# %% [markdown]
# ### Setup

# %%
from torch import nn, optim

# Model to train mode
network.train()

# Mean Squared Error for loss function to minimize
objective = nn.MSELoss()

rmse_non_mc, rmse_mc, test_lls_mc = [], [], []

# %% [markdown]
# ### Train/test the model

# %%
import time

for s in range(n_splits):

    # Prepare new train-test split
    train, test = random_split(dataset, lengths=[train_size, test_size])
    train_loader = DataLoader(train, batch_size=n_training_batch, pin_memory=use_pin_memory)
    if use_pin_memory: test.dataset.data.pin_memory()
    
    # Adam optimizer
    # https://pytorch.org/docs/stable/optim.html?highlight=adam#torch.optim.Adam
    # NOTE: Need to set L2 regularization from here
    optimizer = optim.Adam(
        network.parameters(),
        lr=0.01,
        weight_decay=reg_strength, # L2 regularization
    )
    
    """
    Training
    """

    print("Starting split " + str(s))

    # Record training start time (for this split)
    tic = time.time()

    for epoch in range(n_epochs): # loop over the dataset multiple times

        for i, data in enumerate(train_loader):
            # get the inputs; data is a list of [inputs, labels]
            inputs, targets = data

            # Store the batch to torch_device's memory
            inputs = inputs.to(torch_device)
            targets = targets.to(torch_device)

            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            outputs = network(inputs)

            loss = objective(outputs, targets)
            loss.backward()

            optimizer.step()
            
    # Record training end time
    toc = time.time()

    # Report the final loss
    print("Split " + str(s) + ", final loss = " + str(loss.item()))            

    """
    Testing
    """
    # Model to eval mode
    network.eval()

    # Get the test data
    inputs, targets = test.dataset[test.indices]

    # Store the batch to torch_device's memory
    inputs = inputs.to(torch_device)
    targets = targets.to(torch_device)

    # Record testing start time (for this split)
    tic_testing = time.time()    
    
    predictions, mean, var, metrics = network.mc_predict(inputs, n_predictions,
                                                         y_test=targets, reg_strength=reg_strength)

    # Record testing end time
    toc_testing = time.time()    
    
    """
    Print results
    """
    print()
    print("Running split " + str(s) + " test:")
    print("Mean = " + str(mean))
    print("Variance = " + str(var))

    # Print and store additional metrics
    if len(metrics) > 0:
        for key, value in metrics.items():
            print(str(key) + " = " + str(value))

            if key == 'rmse_mc': rmse_mc.append(value.item())
            elif key == 'rmse_non_mc': rmse_non_mc.append(value.item())
            elif key == 'test_ll_mc': test_lls_mc.append(value.item())

    # Report the total training time
    print("Split " + str(s) + " training time = " + str(toc - tic) + " seconds")
    
    # Report the total testing time
    print("Split " + str(s) + " testing time = " + str(toc_testing - tic_testing) + " seconds")
    print()
# Out:
# Starting split 0
# Split 0, final loss = 1.2929242849349976
#
# Running split 0 test:
# Mean = tensor([[ 3.7662],
#         [ 0.2160],
#         [ 0.2102],
#         [ 0.2984],
#         [ 7.6292],
#         [ 0.3596],
#         [ 2.7033],
#         [ 0.5420],
#         [ 0.3064],
#         [ 0.2022],
#         [ 1.6286],
#         [ 2.8885],
#         [18.2819],
#         [ 2.2185],
#         [20.0438],
#         [23.0287],
#         [ 1.6056],
#         [21.5009],
#         [13.1144],
#         [ 2.4326],
#         [ 3.9472],
#         [ 2.8268],
#         [ 0.3939],
#         [11.6170],
#         [ 4.1587],
#         [ 0.8955],
#         [36.6978],
#         [ 5.8919],
#         [ 2.6917],
#         [ 1.6887],
#         [31.2514],
#         [ 3.7952],
#         [ 4.2255],
#         [ 1.5819],
#         [ 5.3006],
#         [ 2.9615],
#         [ 0.2152],
#         [13.1000],
#         [13.3590],
#         [ 4.0009],
#         [46.5743],
#         [ 4.5793],
#         [ 0.6652],
#         [ 1.6325],
#         [ 3.8925],
#         [ 0.7528],
#         [ 4.2052],
#         [11.5656],
#         [ 0.4672],
#         [ 3.4833],
#         [ 4.8961],
#         [ 1.4851],
#         [ 1.2549],
#         [39.6791],
#         [ 0.9008],
#         [ 0.6647],
#         [ 5.5584],
#         [13.4242],
#         [ 8.1451],
#         [ 1.9776],
#         [ 0.2030],
#         [42.8177]], device='cuda:0')
# Variance = tensor([[0.0955],
#         [0.0090],
#         [0.0179],
#         [0.0175],
#         [0.4802],
#         [0.0139],
#         [0.0594],
#         [0.0176],
#         [0.0130],
#         [0.0089],
#         [0.0554],
#         [0.0660],
#         [0.6728],
#         [0.0481],
#         [1.2054],
#         [0.9272],
#         [0.0321],
#         [1.5756],
#         [0.7760],
#         [0.0768],
#         [0.1401],
#         [0.0811],
#         [0.0191],
#         [0.8111],
#         [0.1482],
#         [0.0293],
#         [3.8737],
#         [0.1742],
#         [0.1081],
#         [0.0358],
#         [1.4873],
#         [0.1069],
#         [0.1397],
#         [0.0314],
#         [0.1481],
#         [0.0797],
#         [0.0101],
#         [0.8282],
#         [0.7945],
#         [0.1653],
#         [4.1722],
#         [0.1753],
#         [0.0360],
#         [0.0490],
#         [0.1476],
#         [0.0186],
#         [0.0990],
#         [0.4325],
#         [0.0139],
#         [0.1445],
#         [0.1357],
#         [0.0333],
#         [0.0147],
#         [2.4996],
#         [0.0255],
#         [0.0221],
#         [0.1630],
#         [0.6579],
#         [0.4210],
#         [0.0355],
#         [0.0111],
#         [4.4561]], device='cuda:0')
# rmse_mc = tensor(0.9291, device='cuda:0')
# rmse_non_mc = tensor(0.9142, device='cuda:0')
# test_ll_mc = tensor(-3.2280, device='cuda:0')
# Split 0 training time = 79.78368997573853 seconds
# Split 0 testing time = 3.7622406482696533 seconds
#
# Starting split 1
# Split 1, final loss = 0.9249016642570496
#
# Running split 1 test:
# Mean = tensor([[12.7109],
#         [ 0.7705],
#         [ 4.0714],
#         [51.5164],
#         [ 0.5170],
#         [ 0.2662],
#         [24.7013],
#         [ 9.8860],
#         [ 1.2147],
#         [ 5.0710],
#         [ 7.8324],
#         [ 2.9329],
#         [ 0.5893],
#         [ 0.2406],
#         [ 1.6570],
#         [ 1.1711],
#         [49.8068],
#         [ 1.9041],
#         [60.8094],
#         [ 0.1553],
#         [ 3.0458],
#         [ 4.4993],
#         [24.3871],
#         [14.5815],
#         [ 0.1453],
#         [ 1.0833],
#         [12.6709],
#         [ 1.5693],
#         [ 0.3607],
#         [ 5.4670],
#         [ 6.8686],
#         [ 9.7055],
#         [40.1624],
#         [ 1.8053],
#         [ 5.9460],
#         [ 5.7471],
#         [ 4.0213],
#         [ 1.3486],
#         [23.0781],
#         [ 0.2748],
#         [45.8263],
#         [51.4945],
#         [ 0.2065],
#         [34.1046],
#         [ 1.1919],
#         [14.0472],
#         [20.1647],
#         [ 0.4285],
#         [ 3.9462],
#         [ 0.2341],
#         [16.1980],
#         [ 0.9182],
#         [ 0.1691],
#         [24.7236],
#         [ 0.4510],
#         [37.4435],
#         [20.7980],
#         [ 2.1265],
#         [57.1162],
#         [ 0.9863],
#         [ 0.2070],
#         [ 3.2089]], device='cuda:0')
# Variance = tensor([[0.6146],
#         [0.0477],
#         [0.1150],
#         [2.4284],
#         [0.0302],
#         [0.0190],
#         [1.1187],
#         [0.5189],
#         [0.0555],
#         [0.1509],
#         [0.2390],
#         [0.1052],
#         [0.0339],
#         [0.0175],
#         [0.0560],
#         [0.0362],
#         [2.7363],
#         [0.0608],
#         [4.8260],
#         [0.0070],
#         [0.1404],
#         [0.1974],
#         [0.7690],
#         [0.6347],
#         [0.0099],
#         [0.0375],
#         [0.3790],
#         [0.0637],
#         [0.0254],
#         [0.1362],
#         [0.3119],
#         [0.5876],
#         [1.2762],
#         [0.0523],
#         [0.1689],
#         [0.1602],
#         [0.1610],
#         [0.0509],
#         [0.9016],
#         [0.0205],
#         [1.7754],
#         [2.0049],
#         [0.0217],
#         [1.1885],
#         [0.0472],
#         [0.5481],
#         [0.4411],
#         [0.0244],
#         [0.1399],
#         [0.0192],
#         [0.5632],
#         [0.0363],
#         [0.0069],
#         [0.8661],
#         [0.0265],
#         [1.3813],
#         [0.9242],
#         [0.0681],
#         [3.0664],
#         [0.0454],
#         [0.0116],
#         [0.0704]], device='cuda:0')
# rmse_mc = tensor(1.0462, device='cuda:0')
# rmse_non_mc = tensor(1.1830, device='cuda:0')
# test_ll_mc = tensor(-3.2294, device='cuda:0')
# Split 1 training time = 80.41686868667603 seconds
# Split 1 testing time = 3.7586095333099365 seconds
#
# Starting split 2
# Split 2, final loss = 0.5520274639129639
#
# Running split 2 test:
# Mean = tensor([[ 0.1763],
#         [ 3.8705],
#         [35.5324],
#         [ 1.7215],
#         [ 0.8330],
#         [ 9.3862],
#         [ 3.5410],
#         [ 4.0691],
#         [ 8.0286],
#         [51.5230],
#         [13.5644],
#         [ 8.1081],
#         [37.9822],
#         [ 0.3357],
#         [ 0.1479],
#         [ 6.6176],
#         [ 4.6644],
#         [ 0.1444],
#         [ 1.8360],
#         [22.5382],
#         [13.5582],
#         [ 6.1228],
#         [20.9847],
#         [48.6502],
#         [ 0.2107],
#         [ 0.4904],
#         [ 2.5533],
#         [ 4.4276],
#         [ 1.1933],
#         [ 0.3128],
#         [ 5.2264],
#         [ 3.6724],
#         [22.4377],
#         [ 0.4964],
#         [ 0.3027],
#         [56.1359],
#         [ 0.3017],
#         [ 0.2941],
#         [ 5.3307],
#         [ 1.1565],
#         [ 0.8028],
#         [32.7967],
#         [37.9719],
#         [50.3082],
#         [ 0.2844],
#         [ 8.4932],
#         [ 3.8658],
#         [53.0029],
#         [ 2.6594],
#         [ 1.3990],
#         [ 2.1373],
#         [45.2731],
#         [ 4.2969],
#         [ 1.7272],
#         [ 2.6368],
#         [ 3.0044],
#         [ 0.7302],
#         [ 0.2005],
#         [ 5.5292],
#         [ 5.4875],
#         [ 2.7331],
#         [ 8.0348]], device='cuda:0')
# Variance = tensor([[0.0095],
#         [0.1548],
#         [1.1315],
#         [0.0761],
#         [0.0430],
#         [0.3733],
#         [0.1272],
#         [0.1641],
#         [0.4632],
#         [2.0663],
#         [0.8231],
#         [0.4554],
#         [1.6820],
#         [0.0196],
#         [0.0090],
#         [0.4625],
#         [0.2013],
#         [0.0076],
#         [0.0794],
#         [0.7701],
#         [0.7735],
#         [0.3727],
#         [0.7641],
#         [1.7928],
#         [0.0100],
#         [0.0288],
#         [0.0887],
#         [0.2134],
#         [0.0624],
#         [0.0177],
#         [0.2412],
#         [0.1151],
#         [0.7397],
#         [0.0298],
#         [0.0186],
#         [2.5664],
#         [0.0196],
#         [0.0171],
#         [0.2625],
#         [0.0652],
#         [0.0496],
#         [1.0576],
#         [1.4406],
#         [1.9547],
#         [0.0165],
#         [0.6055],
#         [0.1520],
#         [2.5145],
#         [0.0922],
#         [0.0616],
#         [0.0887],
#         [2.4643],
#         [0.2249],
#         [0.0747],
#         [0.1105],
#         [0.0977],
#         [0.0463],
#         [0.0108],
#         [0.2201],
#         [0.2625],
#         [0.1141],
#         [0.4193]], device='cuda:0')
# rmse_mc = tensor(1.0863, device='cuda:0')
# rmse_non_mc = tensor(1.5827, device='cuda:0')
# test_ll_mc = tensor(-3.2297, device='cuda:0')
# Split 2 training time = 82.73501300811768 seconds
# Split 2 testing time = 3.764570474624634 seconds
#
# Starting split 3
# Split 3, final loss = 1.96542227268219
#
# Running split 3 test:
# Mean = tensor([[ 0.1551],
#         [ 0.8092],
#         [12.4777],
#         [32.4438],
#         [ 1.6312],
#         [ 5.7021],
#         [ 6.3159],
#         [ 3.0255],
#         [14.6793],
#         [ 2.6513],
#         [ 0.1833],
#         [ 1.8191],
#         [ 0.2708],
#         [55.7978],
#         [ 4.0313],
#         [ 0.3068],
#         [ 1.3067],
#         [ 0.8304],
#         [35.2504],
#         [10.5108],
#         [ 3.8248],
#         [ 0.2673],
#         [10.2134],
#         [ 4.6514],
#         [42.0349],
#         [52.3004],
#         [ 0.7635],
#         [ 0.2365],
#         [ 1.1439],
#         [43.3743],
#         [ 0.1880],
#         [ 2.7250],
#         [33.2845],
#         [ 6.3285],
#         [ 4.5465],
#         [ 1.1625],
#         [27.6290],
#         [ 3.9171],
#         [ 0.3008],
#         [ 0.1918],
#         [ 2.7320],
#         [49.3886],
#         [33.5779],
#         [ 2.4092],
#         [ 0.2567],
#         [19.6252],
#         [ 3.9529],
#         [20.2763],
#         [ 0.4896],
#         [ 3.6505],
#         [ 8.0346],
#         [14.2696],
#         [ 1.9356],
#         [ 1.5858],
#         [24.6224],
#         [ 2.4888],
#         [ 1.0409],
#         [ 3.5790],
#         [12.4417],
#         [ 0.2030],
#         [ 1.2498],
#         [ 0.4945]], device='cuda:0')
# Variance = tensor([[0.0064],
#         [0.0441],
#         [0.4968],
#         [0.8422],
#         [0.0628],
#         [0.2019],
#         [0.3724],
#         [0.1454],
#         [0.6412],
#         [0.1476],
#         [0.0081],
#         [0.0731],
#         [0.0176],
#         [2.6512],
#         [0.1262],
#         [0.0195],
#         [0.0640],
#         [0.0401],
#         [1.1130],
#         [0.4558],
#         [0.1103],
#         [0.0157],
#         [0.7405],
#         [0.1772],
#         [1.9174],
#         [2.3318],
#         [0.0376],
#         [0.0115],
#         [0.0536],
#         [2.1512],
#         [0.0085],
#         [0.1527],
#         [0.8810],
#         [0.3285],
#         [0.1701],
#         [0.0544],
#         [1.1761],
#         [0.1240],
#         [0.0189],
#         [0.0085],
#         [0.1248],
#         [1.9719],
#         [1.0078],
#         [0.0931],
#         [0.0142],
#         [0.5129],
#         [0.1309],
#         [0.7430],
#         [0.0234],
#         [0.1162],
#         [0.4226],
#         [0.6798],
#         [0.0712],
#         [0.0651],
#         [1.0157],
#         [0.0915],
#         [0.0464],
#         [0.1167],
#         [0.4710],
#         [0.0103],
#         [0.0600],
#         [0.0244]], device='cuda:0')
# rmse_mc = tensor(0.6099, device='cuda:0')
# rmse_non_mc = tensor(0.6985, device='cuda:0')
# test_ll_mc = tensor(-3.2254, device='cuda:0')
# Split 3 training time = 83.77133345603943 seconds
# Split 3 testing time = 3.9038453102111816 seconds
#
# Starting split 4
# Split 4, final loss = 0.5249825716018677
#
# Running split 4 test:
# Mean = tensor([[ 0.9088],
#         [32.6571],
#         [32.6154],
#         [ 2.6795],
#         [ 0.8508],
#         [ 2.7611],
#         [47.4681],
#         [ 4.2013],
#         [ 0.3481],
#         [ 3.6009],
#         [ 0.3352],
#         [ 3.7388],
#         [ 0.4115],
#         [12.6687],
#         [ 2.6988],
#         [ 0.3189],
#         [ 0.2944],
#         [ 4.8304],
#         [33.7865],
#         [51.0296],
#         [ 0.2393],
#         [ 7.9855],
#         [ 3.0600],
#         [ 0.5480],
#         [ 1.0064],
#         [12.1463],
#         [ 7.5405],
#         [ 1.7608],
#         [ 4.7372],
#         [ 0.3375],
#         [ 3.6048],
#         [39.2594],
#         [52.7160],
#         [36.5245],
#         [ 2.0537],
#         [ 5.1262],
#         [ 0.2364],
#         [ 5.4038],
#         [ 4.9373],
#         [ 1.8245],
#         [21.4019],
#         [ 7.3470],
#         [ 0.5450],
#         [12.0708],
#         [ 3.9587],
#         [ 9.8010],
#         [ 0.6151],
#         [ 1.0997],
#         [59.2243],
#         [ 2.0361],
#         [39.1792],
#         [ 4.4853],
#         [10.9745],
#         [56.9625],
#         [ 0.3417],
#         [ 1.4181],
#         [ 0.6741],
#         [43.4564],
#         [17.7524],
#         [34.4645],
#         [ 0.2787],
#         [ 0.8328]], device='cuda:0')
# Variance = tensor([[0.0471],
#         [1.0973],
#         [1.1684],
#         [0.0897],
#         [0.0444],
#         [0.0891],
#         [2.3897],
#         [0.1214],
#         [0.0301],
#         [0.0926],
#         [0.0290],
#         [0.1519],
#         [0.0326],
#         [0.5407],
#         [0.1230],
#         [0.0271],
#         [0.0255],
#         [0.2228],
#         [1.2329],
#         [2.3701],
#         [0.0148],
#         [0.3947],
#         [0.0951],
#         [0.0378],
#         [0.0463],
#         [0.3691],
#         [0.2456],
#         [0.0791],
#         [0.2156],
#         [0.0291],
#         [0.0851],
#         [2.4046],
#         [3.3171],
#         [1.5521],
#         [0.0982],
#         [0.2784],
#         [0.0149],
#         [0.3216],
#         [0.2339],
#         [0.0815],
#         [0.8151],
#         [0.2418],
#         [0.0359],
#         [0.7108],
#         [0.1166],
#         [0.5262],
#         [0.0369],
#         [0.0581],
#         [4.3753],
#         [0.1070],
#         [1.9810],
#         [0.2053],
#         [0.3717],
#         [3.9203],
#         [0.0291],
#         [0.0717],
#         [0.0394],
#         [1.9452],
#         [0.5645],
#         [1.2356],
#         [0.0211],
#         [0.0424]], device='cuda:0')
# rmse_mc = tensor(1.1733, device='cuda:0')
# rmse_non_mc = tensor(1.0555, device='cuda:0')
# test_ll_mc = tensor(-3.2311, device='cuda:0')
# Split 4 training time = 81.77906775474548 seconds
# Split 4 testing time = 3.8243472576141357 seconds
#
# Starting split 5
# Split 5, final loss = 0.7077428698539734
#
# Running split 5 test:
# Mean = tensor([[20.0912],
#         [ 5.4559],
#         [ 0.4329],
#         [ 0.3399],
#         [13.5765],
#         [ 1.8115],
#         [ 6.0896],
#         [ 1.4552],
#         [ 1.2887],
#         [ 1.9235],
#         [ 0.2930],
#         [ 0.3015],
#         [ 1.8613],
#         [ 2.2732],
#         [ 1.1832],
#         [ 3.9231],
#         [ 1.8787],
#         [ 8.9425],
#         [31.3109],
#         [19.9346],
#         [ 3.7866],
#         [ 0.8495],
#         [22.6498],
#         [ 0.8425],
#         [34.5547],
#         [ 0.4891],
#         [ 5.5055],
#         [19.5956],
#         [ 4.7111],
#         [51.5192],
#         [ 1.2549],
#         [ 2.8275],
#         [ 1.2838],
#         [ 3.3307],
#         [ 0.1704],
#         [34.9683],
#         [56.1374],
#         [38.0234],
#         [24.8368],
#         [ 4.0307],
#         [14.6921],
#         [13.6258],
#         [ 0.2422],
#         [ 4.8266],
#         [ 5.4170],
#         [ 4.2830],
#         [ 3.6200],
#         [ 0.3044],
#         [ 5.6781],
#         [ 5.6173],
#         [20.6374],
#         [ 5.4992],
#         [37.1838],
#         [ 1.3736],
#         [ 2.4936],
#         [ 0.8289],
#         [ 0.5860],
#         [ 0.8428],
#         [36.1466],
#         [ 0.1764],
#         [ 0.7916],
#         [49.9667]], device='cuda:0')
# Variance = tensor([[0.5646],
#         [0.2412],
#         [0.0186],
#         [0.0197],
#         [0.8379],
#         [0.0737],
#         [0.2505],
#         [0.0585],
#         [0.0483],
#         [0.0837],
#         [0.0178],
#         [0.0187],
#         [0.0782],
#         [0.1094],
#         [0.0405],
#         [0.1104],
#         [0.0777],
#         [0.8208],
#         [0.8709],
#         [0.5611],
#         [0.1101],
#         [0.0353],
#         [0.8365],
#         [0.0318],
#         [1.1411],
#         [0.0185],
#         [0.1995],
#         [0.5811],
#         [0.1753],
#         [2.2826],
#         [0.0462],
#         [0.0914],
#         [0.0464],
#         [0.1404],
#         [0.0137],
#         [1.0656],
#         [2.9028],
#         [1.5165],
#         [1.0139],
#         [0.1157],
#         [0.7814],
#         [0.6396],
#         [0.0143],
#         [0.1676],
#         [0.4274],
#         [0.2225],
#         [0.1923],
#         [0.0188],
#         [0.2144],
#         [0.1997],
#         [0.5856],
#         [0.2037],
#         [1.3327],
#         [0.0626],
#         [0.1333],
#         [0.0357],
#         [0.0261],
#         [0.0321],
#         [1.3051],
#         [0.0112],
#         [0.0321],
#         [1.7635]], device='cuda:0')
# rmse_mc = tensor(0.4496, device='cuda:0')
# rmse_non_mc = tensor(0.8437, device='cuda:0')
# test_ll_mc = tensor(-3.2245, device='cuda:0')
# Split 5 training time = 82.14096188545227 seconds
# Split 5 testing time = 4.137859582901001 seconds
#
# Starting split 6
# Split 6, final loss = 0.616902232170105
#
# Running split 6 test:
# Mean = tensor([[ 0.7536],
#         [ 3.9906],
#         [20.1939],
#         [ 0.2146],
#         [38.0173],
#         [ 2.3129],
#         [ 0.7676],
#         [ 0.2036],
#         [ 3.9220],
#         [ 0.4332],
#         [ 0.6386],
#         [13.8879],
#         [ 0.4781],
#         [ 2.7781],
#         [ 0.2085],
#         [ 0.2800],
#         [ 5.7410],
#         [38.4974],
#         [49.4523],
#         [ 2.7143],
#         [47.4115],
#         [ 5.4636],
#         [ 1.6289],
#         [ 5.5466],
#         [53.1117],
#         [34.6010],
#         [ 3.5593],
#         [ 1.2312],
#         [34.6546],
#         [ 9.9389],
#         [24.5437],
#         [ 0.4610],
#         [ 0.7926],
#         [ 0.7254],
#         [22.9900],
#         [ 0.7114],
#         [12.9846],
#         [51.4788],
#         [12.4587],
#         [25.3275],
#         [33.4339],
#         [ 2.5433],
#         [13.0074],
#         [ 2.4290],
#         [15.2714],
#         [ 5.9016],
#         [ 6.4634],
#         [ 2.6488],
#         [32.0147],
#         [ 1.6522],
#         [ 1.1877],
#         [ 1.0923],
#         [ 0.2222],
#         [ 2.0377],
#         [ 8.6704],
#         [ 0.7050],
#         [ 8.3863],
#         [ 1.2710],
#         [ 1.8111],
#         [ 0.2819],
#         [ 1.1567],
#         [ 2.6751]], device='cuda:0')
# Variance = tensor([[0.0299],
#         [0.0821],
#         [0.4927],
#         [0.0074],
#         [1.6300],
#         [0.0719],
#         [0.0309],
#         [0.0077],
#         [0.0872],
#         [0.0137],
#         [0.0287],
#         [0.5679],
#         [0.0174],
#         [0.0673],
#         [0.0084],
#         [0.0095],
#         [0.1905],
#         [1.5302],
#         [1.7502],
#         [0.0814],
#         [1.4064],
#         [0.1728],
#         [0.0582],
#         [0.1632],
#         [2.1677],
#         [0.9391],
#         [0.1273],
#         [0.0381],
#         [1.0888],
#         [0.4808],
#         [0.9396],
#         [0.0170],
#         [0.0276],
#         [0.0313],
#         [0.9044],
#         [0.0314],
#         [0.5246],
#         [1.8708],
#         [0.4654],
#         [0.9439],
#         [0.8434],
#         [0.0767],
#         [0.9469],
#         [0.0804],
#         [0.4505],
#         [0.2140],
#         [0.2454],
#         [0.0758],
#         [0.8243],
#         [0.0521],
#         [0.0388],
#         [0.0314],
#         [0.0081],
#         [0.0621],
#         [0.4206],
#         [0.0299],
#         [0.2871],
#         [0.0394],
#         [0.0575],
#         [0.0102],
#         [0.0299],
#         [0.0633]], device='cuda:0')
# rmse_mc = tensor(0.8737, device='cuda:0')
# rmse_non_mc = tensor(0.9959, device='cuda:0')
# test_ll_mc = tensor(-3.2272, device='cuda:0')
# Split 6 training time = 81.43147563934326 seconds
# Split 6 testing time = 3.8619909286499023 seconds
#
# Starting split 7
# Split 7, final loss = 0.5341978669166565
#
# Running split 7 test:
# Mean = tensor([[ 4.4803],
#         [ 4.8381],
#         [ 0.2223],
#         [ 0.4894],
#         [21.7952],
#         [51.1734],
#         [ 2.8442],
#         [ 0.9223],
#         [ 0.2070],
#         [ 0.8291],
#         [ 0.6819],
#         [ 4.1014],
#         [ 0.2815],
#         [ 0.2038],
#         [ 0.2774],
#         [ 0.6259],
#         [41.4622],
#         [ 0.2956],
#         [52.5843],
#         [ 0.8111],
#         [ 5.8147],
#         [10.7154],
#         [ 0.3850],
#         [ 8.3781],
#         [ 7.7041],
#         [ 0.1999],
#         [ 8.7289],
#         [14.1380],
#         [ 0.6414],
#         [33.0649],
#         [13.6828],
#         [ 0.5246],
#         [ 2.9933],
#         [ 0.8718],
#         [ 4.3049],
#         [ 1.0668],
#         [52.9685],
#         [ 6.0132],
#         [48.2481],
#         [ 2.3786],
#         [51.2010],
#         [ 1.9725],
#         [ 4.3175],
#         [13.2203],
#         [20.9658],
#         [ 0.2769],
#         [ 0.3831],
#         [36.0254],
#         [ 0.2767],
#         [ 4.2287],
#         [22.4961],
#         [ 3.3733],
#         [ 1.5731],
#         [ 0.6340],
#         [ 2.1071],
#         [ 0.1872],
#         [ 2.9030],
#         [ 0.8722],
#         [ 5.8643],
#         [47.3313],
#         [ 5.9989],
#         [ 4.8741]], device='cuda:0')
# Variance = tensor([[0.1079],
#         [0.1588],
#         [0.0135],
#         [0.0235],
#         [0.6109],
#         [1.5873],
#         [0.0809],
#         [0.0452],
#         [0.0097],
#         [0.0387],
#         [0.0344],
#         [0.1072],
#         [0.0158],
#         [0.0093],
#         [0.0135],
#         [0.0313],
#         [1.7225],
#         [0.0173],
#         [2.0268],
#         [0.0405],
#         [0.1552],
#         [0.3544],
#         [0.0195],
#         [0.2497],
#         [0.5676],
#         [0.0086],
#         [0.2161],
#         [0.5971],
#         [0.0295],
#         [0.8487],
#         [0.4957],
#         [0.0250],
#         [0.0772],
#         [0.0376],
#         [0.0937],
#         [0.0439],
#         [1.7891],
#         [0.1522],
#         [1.5370],
#         [0.0767],
#         [2.3208],
#         [0.0611],
#         [0.1040],
#         [0.6109],
#         [0.5957],
#         [0.0158],
#         [0.0174],
#         [1.7219],
#         [0.0162],
#         [0.1019],
#         [0.8429],
#         [0.1006],
#         [0.0567],
#         [0.0301],
#         [0.0604],
#         [0.0080],
#         [0.0819],
#         [0.0375],
#         [0.1420],
#         [1.5569],
#         [0.1546],
#         [0.1446]], device='cuda:0')
# rmse_mc = tensor(1.0948, device='cuda:0')
# rmse_non_mc = tensor(1.1180, device='cuda:0')
# test_ll_mc = tensor(-3.2292, device='cuda:0')
# Split 7 training time = 82.52888345718384 seconds
# Split 7 testing time = 3.84346342086792 seconds
#
# Starting split 8
# Split 8, final loss = 0.7770636081695557
#
# Running split 8 test:
# Mean = tensor([[ 8.2802],
#         [12.4431],
#         [ 5.8584],
#         [ 8.4083],
#         [ 4.5481],
#         [ 1.4063],
#         [35.5175],
#         [ 0.2782],
#         [21.8003],
#         [13.6821],
#         [ 2.6986],
#         [14.1318],
#         [ 0.9076],
#         [ 0.6012],
#         [ 0.6614],
#         [ 2.5933],
#         [ 0.4194],
#         [ 0.2841],
#         [ 0.3503],
#         [50.9738],
#         [ 0.3928],
#         [ 8.5569],
#         [36.7242],
#         [ 2.0704],
#         [ 0.9525],
#         [40.4341],
#         [24.6364],
#         [ 5.8572],
#         [ 2.8735],
#         [13.6933],
#         [34.9345],
#         [ 9.5986],
#         [ 0.2865],
#         [24.3460],
#         [40.4354],
#         [ 9.4157],
#         [ 1.6176],
#         [ 2.5370],
#         [ 1.0058],
#         [ 1.3852],
#         [ 5.4094],
#         [ 1.9924],
#         [ 3.1524],
#         [ 0.6191],
#         [ 3.4624],
#         [ 0.4131],
#         [ 1.3544],
#         [ 0.9585],
#         [ 0.6420],
#         [36.4586],
#         [ 0.2757],
#         [ 2.4043],
#         [ 0.3755],
#         [ 2.6591],
#         [ 2.7133],
#         [ 1.3580],
#         [ 0.3693],
#         [ 4.0796],
#         [37.2697],
#         [ 5.4380],
#         [19.9750],
#         [ 0.4126]], device='cuda:0')
# Variance = tensor([[0.2808],
#         [0.4496],
#         [0.1797],
#         [0.2321],
#         [0.1172],
#         [0.0311],
#         [2.0919],
#         [0.0088],
#         [0.7147],
#         [0.6472],
#         [0.0639],
#         [0.4934],
#         [0.0267],
#         [0.0169],
#         [0.0225],
#         [0.0567],
#         [0.0117],
#         [0.0083],
#         [0.0106],
#         [1.8779],
#         [0.0101],
#         [0.2039],
#         [2.3839],
#         [0.0336],
#         [0.0217],
#         [1.8568],
#         [1.0714],
#         [0.1698],
#         [0.0682],
#         [0.6812],
#         [1.1250],
#         [0.3356],
#         [0.0082],
#         [1.0680],
#         [1.5541],
#         [0.2952],
#         [0.0372],
#         [0.0630],
#         [0.0278],
#         [0.0286],
#         [0.1158],
#         [0.0322],
#         [0.0820],
#         [0.0154],
#         [0.0724],
#         [0.0142],
#         [0.0321],
#         [0.0259],
#         [0.0172],
#         [1.6889],
#         [0.0080],
#         [0.0536],
#         [0.0109],
#         [0.0541],
#         [0.0549],
#         [0.0247],
#         [0.0110],
#         [0.0765],
#         [1.5658],
#         [0.1407],
#         [0.6964],
#         [0.0098]], device='cuda:0')
# rmse_mc = tensor(0.8664, device='cuda:0')
# rmse_non_mc = tensor(1.4430, device='cuda:0')
# test_ll_mc = tensor(-3.2269, device='cuda:0')
# Split 8 training time = 81.15324783325195 seconds
# Split 8 testing time = 3.6839847564697266 seconds
#
# Starting split 9
# Split 9, final loss = 0.6193010807037354
#
# Running split 9 test:
# Mean = tensor([[21.3595],
#         [ 0.6301],
#         [ 4.7895],
#         [ 0.2891],
#         [12.9214],
#         [ 2.3946],
#         [11.9297],
#         [35.8009],
#         [34.2318],
#         [12.5611],
#         [ 0.1677],
#         [19.0898],
#         [ 0.5555],
#         [ 0.2334],
#         [ 0.6788],
#         [ 0.4186],
#         [ 0.2347],
#         [37.2399],
#         [ 0.5107],
#         [ 0.7547],
#         [ 2.1696],
#         [ 7.6783],
#         [59.0360],
#         [ 0.6956],
#         [19.3356],
#         [ 1.0643],
#         [30.7281],
#         [ 7.2326],
#         [ 1.6437],
#         [49.4269],
#         [ 3.5467],
#         [35.8552],
#         [ 0.1849],
#         [ 0.4145],
#         [ 2.3807],
#         [ 3.4475],
#         [48.9434],
#         [51.5237],
#         [33.2910],
#         [ 3.5228],
#         [ 0.1701],
#         [ 0.1859],
#         [ 1.6738],
#         [35.4247],
#         [ 4.5963],
#         [ 0.6962],
#         [ 1.7638],
#         [20.5565],
#         [10.9715],
#         [ 0.2457],
#         [ 1.6364],
#         [ 8.5431],
#         [ 1.5947],
#         [ 2.3271],
#         [ 0.2630],
#         [ 4.6865],
#         [11.5975],
#         [ 1.6369],
#         [ 0.1603],
#         [47.6803],
#         [ 1.0117],
#         [ 1.5069]], device='cuda:0')
# Variance = tensor([[1.1456],
#         [0.0258],
#         [0.2121],
#         [0.0175],
#         [1.1059],
#         [0.0735],
#         [0.5343],
#         [1.4403],
#         [1.2108],
#         [1.4239],
#         [0.0065],
#         [0.9732],
#         [0.0192],
#         [0.0080],
#         [0.0253],
#         [0.0177],
#         [0.0122],
#         [1.6731],
#         [0.0164],
#         [0.0243],
#         [0.0678],
#         [0.2246],
#         [2.2466],
#         [0.0252],
#         [0.8872],
#         [0.0417],
#         [1.0275],
#         [0.6857],
#         [0.0477],
#         [2.6705],
#         [0.0825],
#         [1.5938],
#         [0.0076],
#         [0.0207],
#         [0.0627],
#         [0.0701],
#         [1.9053],
#         [1.9091],
#         [2.0146],
#         [0.0912],
#         [0.0053],
#         [0.0088],
#         [0.0556],
#         [1.3165],
#         [0.2913],
#         [0.0216],
#         [0.0612],
#         [1.3874],
#         [0.8588],
#         [0.0101],
#         [0.0512],
#         [0.3853],
#         [0.0493],
#         [0.0623],
#         [0.0141],
#         [0.1156],
#         [1.1108],
#         [0.0451],
#         [0.0092],
#         [2.1373],
#         [0.0321],
#         [0.0510]], device='cuda:0')
# rmse_mc = tensor(0.9051, device='cuda:0')
# rmse_non_mc = tensor(1.2646, device='cuda:0')
# test_ll_mc = tensor(-3.2282, device='cuda:0')
# Split 9 training time = 83.28208255767822 seconds
# Split 9 testing time = 4.140536785125732 seconds
#
# Starting split 10
# Split 10, final loss = 1.9775028228759766
#
# Running split 10 test:
# Mean = tensor([[ 8.2472],
#         [21.4650],
#         [12.6614],
#         [ 3.8341],
#         [ 2.2389],
#         [ 0.6443],
#         [22.1163],
#         [38.7685],
#         [ 2.5366],
#         [ 5.0738],
#         [13.9251],
#         [22.4914],
#         [ 3.8542],
#         [55.2298],
#         [ 7.9322],
#         [21.8072],
#         [ 1.0820],
#         [22.6159],
#         [ 3.2784],
#         [24.4932],
#         [20.1568],
#         [39.0849],
#         [ 2.5247],
#         [ 1.2941],
#         [ 8.1449],
#         [ 8.7822],
#         [22.0198],
#         [ 0.3129],
#         [ 1.0062],
#         [ 0.3650],
#         [ 1.7873],
#         [13.0525],
#         [52.9408],
#         [24.6564],
#         [22.6135],
#         [49.9527],
#         [22.3429],
#         [ 0.3970],
#         [ 8.1599],
#         [30.7597],
#         [27.2676],
#         [33.1214],
#         [ 5.8497],
#         [ 3.7348],
#         [ 0.6125],
#         [ 0.3938],
#         [ 0.6712],
#         [ 0.2428],
#         [48.0531],
#         [ 5.5303],
#         [ 1.6103],
#         [25.2838],
#         [34.3747],
#         [ 7.4653],
#         [ 3.0223],
#         [ 0.3332],
#         [48.7938],
#         [ 3.3270],
#         [ 4.3135],
#         [ 3.7424],
#         [ 3.5504],
#         [ 5.2570]], device='cuda:0')
# Variance = tensor([[0.1742],
#         [0.5560],
#         [0.1457],
#         [0.1277],
#         [0.0918],
#         [0.0291],
#         [0.8397],
#         [1.9751],
#         [0.0834],
#         [0.2462],
#         [1.0563],
#         [0.7386],
#         [0.1193],
#         [2.0439],
#         [0.2178],
#         [0.6030],
#         [0.0374],
#         [1.1061],
#         [0.1168],
#         [1.3680],
#         [0.6001],
#         [2.6998],
#         [0.0762],
#         [0.0554],
#         [0.1857],
#         [0.1590],
#         [0.6676],
#         [0.0138],
#         [0.0359],
#         [0.0195],
#         [0.0531],
#         [0.3013],
#         [2.1423],
#         [1.1996],
#         [0.6352],
#         [2.4087],
#         [1.1768],
#         [0.0154],
#         [0.1453],
#         [1.3566],
#         [1.6390],
#         [1.4028],
#         [0.2126],
#         [0.1058],
#         [0.0291],
#         [0.0159],
#         [0.0294],
#         [0.0056],
#         [2.6437],
#         [0.1685],
#         [0.0472],
#         [1.3265],
#         [1.4250],
#         [0.2099],
#         [0.0998],
#         [0.0124],
#         [2.4627],
#         [0.1200],
#         [0.1467],
#         [0.0996],
#         [0.1019],
#         [0.1240]], device='cuda:0')
# rmse_mc = tensor(0.9034, device='cuda:0')
# rmse_non_mc = tensor(0.9675, device='cuda:0')
# test_ll_mc = tensor(-3.2283, device='cuda:0')
# Split 10 training time = 82.95701098442078 seconds
# Split 10 testing time = 4.051174640655518 seconds
#
# Starting split 11
# Split 11, final loss = 1.2951910495758057
#
# Running split 11 test:
# Mean = tensor([[ 5.1983],
#         [ 0.5003],
#         [ 1.3226],
#         [ 0.8104],
#         [ 1.6275],
#         [ 3.5332],
#         [ 0.2762],
#         [ 1.9538],
#         [ 1.2604],
#         [ 0.7664],
#         [ 0.4631],
#         [ 1.2299],
#         [22.5136],
#         [ 0.2942],
#         [ 8.5622],
#         [ 3.9498],
#         [56.1095],
#         [ 2.1970],
#         [14.4015],
#         [ 3.8434],
#         [ 0.2835],
#         [32.6399],
#         [25.0216],
#         [ 3.2256],
#         [46.1089],
#         [ 1.7276],
#         [ 0.1694],
#         [ 4.8854],
#         [ 0.2702],
#         [ 1.8195],
#         [ 0.5091],
#         [ 0.2723],
#         [ 2.6995],
#         [ 0.8549],
#         [ 3.4949],
#         [50.1275],
#         [ 0.8114],
#         [ 0.2874],
#         [ 5.1943],
#         [33.7542],
#         [ 1.2116],
#         [ 1.2495],
#         [ 5.3752],
#         [ 3.6583],
#         [55.1702],
#         [ 0.1693],
#         [41.4219],
#         [12.2393],
#         [ 0.1758],
#         [30.8784],
#         [35.3907],
#         [ 3.5779],
#         [ 9.4869],
#         [ 1.9122],
#         [22.6983],
#         [ 1.2952],
#         [ 0.1910],
#         [32.3038],
#         [ 9.2148],
#         [ 0.4762],
#         [ 1.3362],
#         [21.4890]], device='cuda:0')
# Variance = tensor([[0.1765],
#         [0.0845],
#         [0.0787],
#         [0.0933],
#         [0.1136],
#         [0.1688],
#         [0.0463],
#         [0.1310],
#         [0.0357],
#         [0.0616],
#         [0.0206],
#         [0.1219],
#         [0.8861],
#         [0.0780],
#         [0.5816],
#         [0.1737],
#         [1.9223],
#         [0.2141],
#         [0.7587],
#         [0.2443],
#         [0.0677],
#         [1.3185],
#         [1.2317],
#         [0.0776],
#         [2.1021],
#         [0.0405],
#         [0.0094],
#         [0.3757],
#         [0.0423],
#         [0.0925],
#         [0.0517],
#         [0.0412],
#         [0.1259],
#         [0.1011],
#         [0.0867],
#         [2.0313],
#         [0.0887],
#         [0.0429],
#         [0.1568],
#         [1.4378],
#         [0.0374],
#         [0.0744],
#         [0.1531],
#         [0.3384],
#         [1.8809],
#         [0.0100],
#         [1.6919],
#         [0.1621],
#         [0.0344],
#         [2.3899],
#         [1.8144],
#         [0.1851],
#         [0.3952],
#         [0.0521],
#         [0.8918],
#         [0.0830],
#         [0.0381],
#         [1.7447],
#         [0.2636],
#         [0.0529],
#         [0.0446],
#         [0.6608]], device='cuda:0')
# rmse_mc = tensor(0.8732, device='cuda:0')
# rmse_non_mc = tensor(1.0698, device='cuda:0')
# test_ll_mc = tensor(-3.2273, device='cuda:0')
# Split 11 training time = 81.29036068916321 seconds
# Split 11 testing time = 3.9707725048065186 seconds
#
# Starting split 12
# Split 12, final loss = 1.061654806137085
#
# Running split 12 test:
# Mean = tensor([[19.4855],
#         [18.4520],
#         [11.7798],
#         [22.6132],
#         [20.5629],
#         [32.2353],
#         [ 0.8913],
#         [ 3.7199],
#         [ 0.8910],
#         [ 5.3243],
#         [ 5.4936],
#         [ 0.2290],
#         [ 2.7766],
#         [12.0079],
#         [ 0.3213],
#         [ 0.6047],
#         [ 0.8935],
#         [ 1.9343],
#         [ 1.8635],
#         [ 2.5520],
#         [ 0.8893],
#         [ 1.2455],
#         [ 4.9251],
#         [ 0.8847],
#         [ 1.3024],
#         [19.6360],
#         [37.6851],
#         [ 2.0462],
#         [ 1.3267],
#         [21.4327],
#         [ 0.2278],
#         [57.5129],
#         [11.9592],
#         [54.4059],
#         [ 0.5642],
#         [ 4.6040],
#         [ 0.3569],
#         [11.5834],
#         [46.5066],
#         [ 7.4764],
#         [ 0.2306],
#         [ 1.8834],
#         [ 2.9811],
#         [ 2.6628],
#         [51.8055],
#         [ 0.3399],
#         [ 0.2254],
#         [ 5.0928],
#         [ 1.2973],
#         [ 2.8172],
#         [ 7.0042],
#         [12.8939],
#         [ 1.7644],
#         [ 4.2044],
#         [ 0.2369],
#         [ 0.3232],
#         [ 0.2328],
#         [ 3.4868],
#         [ 0.5567],
#         [ 4.0670],
#         [15.0719],
#         [ 7.4956]], device='cuda:0')
# Variance = tensor([[0.7138],
#         [0.6179],
#         [0.3863],
#         [1.4918],
#         [0.8339],
#         [1.5939],
#         [0.0232],
#         [0.0750],
#         [0.0241],
#         [0.3277],
#         [0.1250],
#         [0.0078],
#         [0.1141],
#         [0.2511],
#         [0.0155],
#         [0.0180],
#         [0.3777],
#         [0.0512],
#         [0.0504],
#         [0.0572],
#         [0.0911],
#         [0.0806],
#         [0.2856],
#         [0.0290],
#         [0.1101],
#         [0.6553],
#         [1.7153],
#         [0.0824],
#         [0.0647],
#         [0.8863],
#         [0.0433],
#         [2.5763],
#         [0.1665],
#         [2.4016],
#         [0.0771],
#         [0.3535],
#         [0.0745],
#         [0.4552],
#         [2.1912],
#         [0.3660],
#         [0.0077],
#         [0.3889],
#         [0.1457],
#         [0.0569],
#         [1.9328],
#         [0.0138],
#         [0.0229],
#         [0.2668],
#         [0.0331],
#         [0.0697],
#         [0.1811],
#         [0.9021],
#         [0.0409],
#         [0.2256],
#         [0.0080],
#         [0.0394],
#         [0.0226],
#         [0.1394],
#         [0.0775],
#         [0.1424],
#         [0.7124],
#         [0.2451]], device='cuda:0')
# rmse_mc = tensor(0.6862, device='cuda:0')
# rmse_non_mc = tensor(0.6417, device='cuda:0')
# test_ll_mc = tensor(-3.2256, device='cuda:0')
# Split 12 training time = 82.60874533653259 seconds
# Split 12 testing time = 4.123624086380005 seconds
#
# Starting split 13
# Split 13, final loss = 0.46880728006362915
#
# Running split 13 test:
# Mean = tensor([[ 0.3351],
#         [ 1.7207],
#         [ 4.7163],
#         [ 3.2594],
#         [35.2817],
#         [ 0.3030],
#         [ 4.5769],
#         [ 0.5432],
#         [ 7.6948],
#         [24.5007],
#         [ 0.2248],
#         [ 7.2884],
#         [ 1.7159],
#         [ 2.5608],
#         [ 0.3199],
#         [ 8.7163],
#         [22.1480],
#         [ 0.3264],
#         [ 1.3535],
#         [ 3.6980],
#         [ 7.9618],
#         [ 2.3749],
#         [ 2.4208],
#         [ 1.4491],
#         [12.4964],
#         [13.6610],
#         [ 1.8201],
#         [50.8996],
#         [ 3.8366],
#         [ 3.9334],
#         [ 2.0131],
#         [ 0.3231],
#         [ 0.2229],
#         [ 0.2244],
#         [ 0.8171],
#         [46.0127],
#         [ 4.7498],
#         [12.6335],
#         [ 1.7833],
#         [ 8.6465],
#         [29.4613],
#         [ 0.8050],
#         [ 3.4187],
#         [ 0.5165],
#         [14.2014],
#         [ 2.5718],
#         [ 0.8170],
#         [ 0.7867],
#         [ 2.5895],
#         [ 0.3319],
#         [ 3.2984],
#         [ 1.1919],
#         [ 2.4960],
#         [ 0.8489],
#         [ 5.6599],
#         [ 1.8862],
#         [33.5567],
#         [ 8.1459],
#         [ 0.5384],
#         [ 0.2285],
#         [ 4.0579],
#         [24.1176]], device='cuda:0')
# Variance = tensor([[0.0416],
#         [0.1586],
#         [0.1085],
#         [0.1392],
#         [1.9359],
#         [0.0115],
#         [0.1478],
#         [0.0684],
#         [0.3349],
#         [1.3270],
#         [0.0100],
#         [0.2316],
#         [0.0951],
#         [0.1154],
#         [0.0319],
#         [0.5588],
#         [0.7595],
#         [0.0637],
#         [0.1201],
#         [0.1966],
#         [0.2689],
#         [0.0601],
#         [0.1964],
#         [0.0739],
#         [0.2625],
#         [0.4932],
#         [0.0812],
#         [1.8550],
#         [0.1762],
#         [0.1530],
#         [0.0692],
#         [0.0755],
#         [0.0085],
#         [0.0247],
#         [0.0952],
#         [2.3872],
#         [0.1470],
#         [0.2561],
#         [0.0425],
#         [0.2925],
#         [1.1192],
#         [0.0205],
#         [0.0846],
#         [0.0370],
#         [0.4493],
#         [0.1728],
#         [0.0483],
#         [0.0210],
#         [0.1880],
#         [0.0111],
#         [0.0799],
#         [0.0289],
#         [0.1314],
#         [0.1364],
#         [0.2918],
#         [0.0431],
#         [1.1774],
#         [0.2689],
#         [0.1199],
#         [0.0302],
#         [0.1824],
#         [1.0073]], device='cuda:0')
# rmse_mc = tensor(0.8298, device='cuda:0')
# rmse_non_mc = tensor(0.9487, device='cuda:0')
# test_ll_mc = tensor(-3.2263, device='cuda:0')
# Split 13 training time = 81.67731142044067 seconds
# Split 13 testing time = 4.048149585723877 seconds
#
# Starting split 14
# Split 14, final loss = 0.4464828670024872
#
# Running split 14 test:
# Mean = tensor([[ 0.3455],
#         [ 0.5852],
#         [ 7.6108],
#         [34.5140],
#         [ 0.9907],
#         [ 1.0371],
#         [ 0.6344],
#         [ 0.6002],
#         [ 0.1486],
#         [ 0.5428],
#         [ 4.7007],
#         [ 0.3250],
#         [ 0.1474],
#         [ 5.4267],
#         [ 2.2319],
#         [ 2.1289],
#         [12.4634],
#         [56.7886],
#         [ 0.9297],
#         [ 4.6643],
#         [54.0627],
#         [ 3.5083],
#         [33.1507],
#         [ 1.4544],
#         [19.5287],
#         [ 3.0329],
#         [ 0.3028],
#         [ 2.6422],
#         [32.3985],
#         [ 0.2219],
#         [ 7.0704],
#         [ 6.5713],
#         [ 2.9590],
#         [ 4.3232],
#         [34.6383],
#         [11.8604],
#         [20.7883],
#         [ 0.1412],
#         [ 0.3008],
#         [ 1.5127],
#         [54.0672],
#         [ 0.1399],
#         [ 0.8880],
#         [50.4585],
#         [ 0.5400],
#         [48.8827],
#         [ 0.3208],
#         [20.4025],
#         [ 0.1532],
#         [ 3.3223],
#         [ 0.3612],
#         [ 2.1749],
#         [ 0.9281],
#         [ 6.8445],
#         [ 3.2598],
#         [ 0.5562],
#         [30.3237],
#         [ 0.9419],
#         [ 4.3871],
#         [51.1426],
#         [ 2.1960],
#         [20.7901]], device='cuda:0')
# Variance = tensor([[0.0506],
#         [0.0228],
#         [0.3819],
#         [1.5586],
#         [0.0419],
#         [0.0333],
#         [0.0266],
#         [0.0639],
#         [0.0118],
#         [0.0173],
#         [0.1684],
#         [0.0279],
#         [0.0059],
#         [0.1931],
#         [0.0912],
#         [0.0869],
#         [0.3255],
#         [2.0838],
#         [0.0624],
#         [0.1223],
#         [1.6528],
#         [0.1287],
#         [1.0237],
#         [0.0771],
#         [0.5256],
#         [0.1860],
#         [0.0121],
#         [0.1267],
#         [1.0339],
#         [0.0292],
#         [0.1402],
#         [0.3232],
#         [0.1284],
#         [0.3341],
#         [1.7668],
#         [0.7875],
#         [1.1654],
#         [0.0111],
#         [0.0258],
#         [0.0593],
#         [1.6494],
#         [0.0059],
#         [0.0284],
#         [1.5280],
#         [0.0177],
#         [1.5196],
#         [0.0239],
#         [0.6844],
#         [0.0111],
#         [0.1567],
#         [0.0199],
#         [0.2047],
#         [0.0523],
#         [0.3822],
#         [0.1271],
#         [0.0370],
#         [0.8199],
#         [0.1082],
#         [0.0946],
#         [1.5048],
#         [0.1166],
#         [1.5808]], device='cuda:0')
# rmse_mc = tensor(1.8519, device='cuda:0')
# rmse_non_mc = tensor(2.3874, device='cuda:0')
# test_ll_mc = tensor(-3.2404, device='cuda:0')
# Split 14 training time = 83.75701856613159 seconds
# Split 14 testing time = 3.7876346111297607 seconds
#
# Starting split 15
# Split 15, final loss = 0.7008237242698669
#
# Running split 15 test:
# Mean = tensor([[24.0646],
#         [53.4782],
#         [ 0.2098],
#         [ 7.5614],
#         [13.4168],
#         [20.8063],
#         [ 3.1645],
#         [21.7990],
#         [ 7.7525],
#         [ 0.8544],
#         [ 0.3243],
#         [ 0.5446],
#         [47.2924],
#         [ 0.9517],
#         [34.3086],
#         [ 3.4357],
#         [ 0.2873],
#         [ 1.9884],
#         [21.6793],
#         [ 0.9404],
#         [ 0.2108],
#         [49.5420],
#         [ 0.1433],
#         [12.4105],
#         [53.7639],
#         [53.7811],
#         [ 0.1491],
#         [ 1.6268],
#         [13.3789],
#         [ 0.5479],
#         [ 3.2108],
#         [ 7.4204],
#         [34.5601],
#         [ 9.0565],
#         [ 3.3103],
#         [21.4005],
#         [ 0.1403],
#         [ 2.3017],
#         [22.6995],
#         [ 0.1467],
#         [34.4052],
#         [ 0.3254],
#         [ 3.1760],
#         [ 1.4193],
#         [57.6146],
#         [ 2.1223],
#         [ 0.3073],
#         [ 3.2791],
#         [ 2.1675],
#         [23.4745],
#         [ 0.5982],
#         [ 3.4765],
#         [ 2.4910],
#         [26.5192],
#         [ 4.9225],
#         [16.1413],
#         [ 2.3023],
#         [ 2.1733],
#         [ 1.3808],
#         [53.7582],
#         [ 4.5839],
#         [38.9171]], device='cuda:0')
# Variance = tensor([[2.5065],
#         [1.6025],
#         [0.0163],
#         [0.2564],
#         [0.6364],
#         [0.7414],
#         [0.1572],
#         [1.6114],
#         [0.5525],
#         [0.0581],
#         [0.0217],
#         [0.0203],
#         [1.6057],
#         [0.0510],
#         [1.9520],
#         [0.1241],
#         [0.0292],
#         [0.0742],
#         [1.1932],
#         [0.0655],
#         [0.0091],
#         [1.8570],
#         [0.0078],
#         [0.3341],
#         [1.7150],
#         [1.6613],
#         [0.0115],
#         [0.0628],
#         [0.7237],
#         [0.0225],
#         [0.1458],
#         [0.3126],
#         [1.4400],
#         [0.2012],
#         [0.4074],
#         [1.0082],
#         [0.0114],
#         [0.1377],
#         [1.0768],
#         [0.0077],
#         [1.5608],
#         [0.0163],
#         [0.1418],
#         [0.1167],
#         [2.1315],
#         [0.2448],
#         [0.0221],
#         [0.1444],
#         [0.0758],
#         [1.1423],
#         [0.0250],
#         [0.1218],
#         [0.0739],
#         [1.4925],
#         [0.3209],
#         [1.1593],
#         [0.4401],
#         [0.1007],
#         [0.0456],
#         [1.7104],
#         [0.2866],
#         [1.6928]], device='cuda:0')
# rmse_mc = tensor(1.4346, device='cuda:0')
# rmse_non_mc = tensor(1.6168, device='cuda:0')
# test_ll_mc = tensor(-3.2343, device='cuda:0')
# Split 15 training time = 82.28446578979492 seconds
# Split 15 testing time = 3.6532256603240967 seconds
#
# Starting split 16
# Split 16, final loss = 0.8611387014389038
#
# Running split 16 test:
# Mean = tensor([[50.0661],
#         [29.0052],
#         [ 1.6492],
#         [ 5.8701],
#         [ 7.8923],
#         [ 8.1886],
#         [57.2219],
#         [15.1640],
#         [32.5379],
#         [ 7.4878],
#         [19.9851],
#         [49.8090],
#         [ 9.6825],
#         [ 4.4981],
#         [ 5.0494],
#         [ 4.6349],
#         [ 5.4233],
#         [ 0.6993],
#         [32.8321],
#         [32.4017],
#         [ 2.1763],
#         [ 5.5449],
#         [ 1.3673],
#         [ 2.0744],
#         [ 0.6837],
#         [ 4.3401],
#         [ 0.2934],
#         [ 1.1004],
#         [ 0.3877],
#         [38.1064],
#         [ 2.1991],
#         [23.4122],
#         [ 0.4189],
#         [ 2.9743],
#         [ 2.3978],
#         [21.3847],
#         [ 0.6549],
#         [ 0.9560],
#         [11.7294],
#         [49.9699],
#         [ 3.2639],
#         [ 1.1027],
#         [33.7531],
#         [ 5.0373],
#         [ 5.8093],
#         [ 2.0220],
#         [18.4334],
#         [ 1.6060],
#         [21.8148],
#         [ 0.6301],
#         [ 2.8798],
#         [ 0.3992],
#         [54.3537],
#         [ 5.9528],
#         [ 0.9603],
#         [22.1085],
#         [29.8457],
#         [ 3.2083],
#         [50.8303],
#         [ 2.9732],
#         [12.9153],
#         [13.1107]], device='cuda:0')
# Variance = tensor([[1.6291],
#         [1.4896],
#         [0.0705],
#         [0.1762],
#         [0.2787],
#         [0.3316],
#         [2.1568],
#         [0.5581],
#         [1.7549],
#         [0.4195],
#         [1.2334],
#         [2.6826],
#         [0.4076],
#         [0.1492],
#         [0.3868],
#         [0.1661],
#         [0.1698],
#         [0.0192],
#         [2.4465],
#         [2.4479],
#         [0.0738],
#         [0.2059],
#         [0.0569],
#         [0.0715],
#         [0.0279],
#         [0.1573],
#         [0.0129],
#         [0.0658],
#         [0.0132],
#         [2.6186],
#         [0.0912],
#         [2.0127],
#         [0.0265],
#         [0.1467],
#         [0.0856],
#         [1.6241],
#         [0.0183],
#         [0.0310],
#         [0.5838],
#         [1.6133],
#         [0.0736],
#         [0.0409],
#         [2.1792],
#         [0.1967],
#         [0.2175],
#         [0.1142],
#         [0.5872],
#         [0.0580],
#         [1.9566],
#         [0.0222],
#         [0.0953],
#         [0.0127],
#         [1.7722],
#         [0.1732],
#         [0.0270],
#         [2.0795],
#         [1.6669],
#         [0.0866],
#         [1.7094],
#         [0.1029],
#         [0.4294],
#         [0.6611]], device='cuda:0')
# rmse_mc = tensor(1.2199, device='cuda:0')
# rmse_non_mc = tensor(1.2711, device='cuda:0')
# test_ll_mc = tensor(-3.2321, device='cuda:0')
# Split 16 training time = 82.45795893669128 seconds
# Split 16 testing time = 3.943063497543335 seconds
#
# Starting split 17
# Split 17, final loss = 0.38456594944000244
#
# Running split 17 test:
# Mean = tensor([[ 1.3692],
#         [ 5.8919],
#         [ 0.9421],
#         [ 5.5404],
#         [ 0.2066],
#         [ 8.1632],
#         [ 4.4362],
#         [59.2730],
#         [ 3.0308],
#         [ 3.0901],
#         [ 1.4939],
#         [ 0.5724],
#         [ 2.6810],
#         [25.6621],
#         [39.8594],
#         [ 1.4772],
#         [21.2798],
#         [ 1.0094],
#         [24.8693],
#         [ 3.9055],
#         [ 2.0141],
#         [ 5.3970],
#         [58.8363],
#         [47.8238],
#         [ 0.5828],
#         [ 8.0773],
#         [58.9770],
#         [22.0367],
#         [ 0.9333],
#         [21.7793],
#         [47.5143],
#         [ 0.5726],
#         [23.2857],
#         [46.7626],
#         [20.4901],
#         [ 2.1568],
#         [ 1.9673],
#         [ 0.2036],
#         [ 0.3174],
#         [ 0.2142],
#         [ 0.2200],
#         [ 0.2134],
#         [ 0.5697],
#         [ 3.5125],
#         [24.9247],
#         [ 1.4317],
#         [ 0.6732],
#         [ 3.9453],
#         [ 2.7921],
#         [25.0653],
#         [ 0.2128],
#         [59.4779],
#         [13.9140],
#         [27.1186],
#         [ 1.3583],
#         [ 0.2811],
#         [ 1.8477],
#         [35.1533],
#         [42.4374],
#         [34.8563],
#         [35.1982],
#         [56.3070]], device='cuda:0')
# Variance = tensor([[0.0724],
#         [0.2332],
#         [0.0447],
#         [0.1924],
#         [0.0145],
#         [0.2515],
#         [0.1510],
#         [2.0540],
#         [0.1007],
#         [0.0668],
#         [0.0384],
#         [0.0181],
#         [0.1008],
#         [1.1882],
#         [1.6700],
#         [0.0571],
#         [0.5323],
#         [0.0406],
#         [1.3058],
#         [0.0673],
#         [0.0549],
#         [0.1646],
#         [1.9582],
#         [2.0484],
#         [0.0187],
#         [0.2472],
#         [2.1281],
#         [0.8350],
#         [0.0366],
#         [0.5292],
#         [2.3821],
#         [0.0413],
#         [0.8684],
#         [2.4870],
#         [0.4214],
#         [0.0771],
#         [0.0499],
#         [0.0270],
#         [0.0134],
#         [0.0068],
#         [0.0223],
#         [0.0160],
#         [0.0612],
#         [0.0832],
#         [0.9589],
#         [0.0510],
#         [0.0299],
#         [0.0816],
#         [0.0662],
#         [1.1323],
#         [0.0065],
#         [2.0128],
#         [0.3491],
#         [0.7803],
#         [0.0582],
#         [0.0352],
#         [0.0705],
#         [1.2777],
#         [1.4819],
#         [1.2477],
#         [1.2490],
#         [1.8514]], device='cuda:0')
# rmse_mc = tensor(1.1885, device='cuda:0')
# rmse_non_mc = tensor(1.4608, device='cuda:0')
# test_ll_mc = tensor(-3.2311, device='cuda:0')
# Split 17 training time = 83.85762453079224 seconds
# Split 17 testing time = 3.6912014484405518 seconds
#
# Starting split 18
# Split 18, final loss = 1.1676753759384155
#
# Running split 18 test:
# Mean = tensor([[ 3.4633],
#         [38.0020],
#         [37.5228],
#         [ 2.6331],
#         [ 0.2043],
#         [ 3.7349],
#         [ 0.7497],
#         [ 4.9305],
#         [ 4.9991],
#         [ 3.9123],
#         [ 0.2838],
#         [19.0806],
#         [ 0.2010],
#         [13.3467],
#         [ 0.2777],
#         [ 0.2765],
#         [ 0.4461],
#         [ 1.2241],
#         [ 2.7657],
#         [30.4970],
#         [ 0.7629],
#         [36.6469],
#         [ 4.8093],
#         [31.4963],
#         [ 2.6165],
#         [ 7.5195],
#         [ 0.2877],
#         [ 0.4678],
#         [ 0.7508],
#         [ 0.2785],
#         [ 0.4687],
#         [ 3.4763],
#         [20.6460],
#         [ 1.1345],
#         [ 7.3718],
#         [ 0.2098],
#         [26.0497],
#         [ 2.6570],
#         [20.3516],
#         [ 0.2010],
#         [ 1.8359],
#         [47.2902],
#         [ 6.2451],
#         [12.4355],
#         [ 0.7449],
#         [ 1.2592],
#         [ 0.2048],
#         [ 1.1864],
#         [ 2.6408],
#         [ 1.6965],
#         [56.6024],
#         [ 0.7616],
#         [ 2.4310],
#         [ 7.1470],
#         [ 1.8822],
#         [12.3215],
#         [ 2.6303],
#         [ 1.7411],
#         [ 8.7436],
#         [ 0.4611],
#         [ 1.8075],
#         [ 0.2055]], device='cuda:0')
# Variance = tensor([[0.1131],
#         [1.6759],
#         [1.3332],
#         [0.0958],
#         [0.0149],
#         [0.1253],
#         [0.0428],
#         [0.1690],
#         [0.1742],
#         [0.1646],
#         [0.0167],
#         [0.4433],
#         [0.0176],
#         [0.3504],
#         [0.0223],
#         [0.0205],
#         [0.0301],
#         [0.0580],
#         [0.0963],
#         [0.7049],
#         [0.0419],
#         [1.1130],
#         [0.1906],
#         [0.7820],
#         [0.0966],
#         [0.4545],
#         [0.0201],
#         [0.0251],
#         [0.0396],
#         [0.0228],
#         [0.0269],
#         [0.0987],
#         [0.4195],
#         [0.0513],
#         [0.1901],
#         [0.0134],
#         [0.8669],
#         [0.1043],
#         [0.4185],
#         [0.0145],
#         [0.0770],
#         [2.0271],
#         [0.2529],
#         [0.3344],
#         [0.0506],
#         [0.0770],
#         [0.0161],
#         [0.0553],
#         [0.0961],
#         [0.0768],
#         [2.4346],
#         [0.0411],
#         [0.1103],
#         [0.2375],
#         [0.0693],
#         [0.2705],
#         [0.1023],
#         [0.0750],
#         [0.2359],
#         [0.0316],
#         [0.0740],
#         [0.0179]], device='cuda:0')
# rmse_mc = tensor(0.6014, device='cuda:0')
# rmse_non_mc = tensor(0.7148, device='cuda:0')
# test_ll_mc = tensor(-3.2246, device='cuda:0')
# Split 18 training time = 83.85636878013611 seconds
# Split 18 testing time = 4.2371087074279785 seconds
#
# Starting split 19
# Split 19, final loss = 0.742700457572937
#
# Running split 19 test:
# Mean = tensor([[ 0.8130],
#         [13.1976],
#         [ 8.8433],
#         [ 1.2483],
#         [ 1.2530],
#         [ 1.2576],
#         [ 0.3670],
#         [50.0234],
#         [11.9417],
#         [ 0.7985],
#         [ 0.7773],
#         [ 5.3366],
#         [ 0.5542],
#         [49.9170],
#         [43.0303],
#         [51.6303],
#         [ 0.7928],
#         [ 0.2990],
#         [ 1.2922],
#         [ 0.2963],
#         [13.5652],
#         [ 7.4053],
#         [ 0.5437],
#         [19.3306],
#         [ 0.3658],
#         [ 1.7717],
#         [ 0.5371],
#         [22.4142],
#         [ 0.3038],
#         [ 0.9106],
#         [ 0.3000],
#         [ 1.4051],
#         [ 7.6224],
#         [ 1.8994],
#         [ 1.8758],
#         [ 7.6521],
#         [ 1.9022],
#         [ 4.9148],
#         [ 5.0079],
#         [33.1367],
#         [ 4.9183],
#         [ 2.0797],
#         [ 1.8573],
#         [ 3.6573],
#         [ 1.8721],
#         [45.8959],
#         [ 0.3690],
#         [12.8138],
#         [20.1736],
#         [ 5.1229],
#         [ 3.9522],
#         [ 3.5528],
#         [34.5607],
#         [ 0.8363],
#         [ 0.8142],
#         [30.9632],
#         [ 8.0614],
#         [44.8141],
#         [ 1.1920],
#         [ 5.5706],
#         [ 1.8197],
#         [12.7621]], device='cuda:0')
# Variance = tensor([[0.0414],
#         [0.3260],
#         [0.3091],
#         [0.0563],
#         [0.0673],
#         [0.0633],
#         [0.0188],
#         [1.4134],
#         [0.2206],
#         [0.0390],
#         [0.0359],
#         [0.2422],
#         [0.0309],
#         [1.5228],
#         [1.4757],
#         [1.5470],
#         [0.0369],
#         [0.0156],
#         [0.0539],
#         [0.0133],
#         [0.4925],
#         [0.3125],
#         [0.0262],
#         [0.3415],
#         [0.0157],
#         [0.0792],
#         [0.0284],
#         [0.6458],
#         [0.0128],
#         [0.0519],
#         [0.0129],
#         [0.0644],
#         [0.1876],
#         [0.0694],
#         [0.0669],
#         [0.2677],
#         [0.0749],
#         [0.2347],
#         [0.1899],
#         [0.6834],
#         [0.2143],
#         [0.0821],
#         [0.0739],
#         [0.1001],
#         [0.0752],
#         [1.4560],
#         [0.0187],
#         [0.2465],
#         [0.2966],
#         [0.2296],
#         [0.0950],
#         [0.0765],
#         [0.9356],
#         [0.0428],
#         [0.0443],
#         [0.5680],
#         [0.2824],
#         [1.6626],
#         [0.0540],
#         [0.2100],
#         [0.0945],
#         [0.3588]], device='cuda:0')
# rmse_mc = tensor(1.0535, device='cuda:0')
# rmse_non_mc = tensor(1.0747, device='cuda:0')
# test_ll_mc = tensor(-3.2284, device='cuda:0')
# Split 19 training time = 83.05607986450195 seconds
# Split 19 testing time = 4.002697706222534 seconds

# %% [markdown]
# ### Print statistics

# %%
# Copied from DropoutUncertaintyExps repo
print('non-MC RMSE %f +- %f (stddev) +- %f (std error), median %f 25p %f 75p %f \n' % (
        np.mean(rmse_non_mc), np.std(rmse_non_mc), np.std(rmse_non_mc)/np.sqrt(n_splits),
        np.percentile(rmse_non_mc, 50), np.percentile(rmse_non_mc, 25), np.percentile(rmse_non_mc, 75)))

print('MC RMSE %f +- %f (stddev) +- %f (std error), median %f 25p %f 75p %f \n' % (
        np.mean(rmse_mc), np.std(rmse_mc), np.std(rmse_mc)/np.sqrt(n_splits),
        np.percentile(rmse_mc, 50), np.percentile(rmse_mc, 25), np.percentile(rmse_mc, 75)))

print('MC Test Log-likelihood %f +- %f (stddev) +- %f (std error), median %f 25p %f 75p %f \n' % (
        np.mean(test_lls_mc), np.std(test_lls_mc), np.std(test_lls_mc)/np.sqrt(n_splits), 
        np.percentile(test_lls_mc, 50), np.percentile(test_lls_mc, 25), np.percentile(test_lls_mc, 75)))
# Out:
# non-MC RMSE 1.162614 +- 0.391484 (stddev) +- 0.087538 (std error), median 1.072226 25p 0.940104 75p 1.314062
#
# MC RMSE 0.983838 +- 0.304928 (stddev) +- 0.068184 (std error), median 0.917059 25p 0.857203 75p 1.114455
#
# MC Test Log-likelihood -3.228905 +- 0.003604 (stddev) +- 0.000806 (std error), median -3.228244 25p -3.230041 75p -3.226764
