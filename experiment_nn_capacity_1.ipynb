# %% [markdown]
# ## Experiment Setup

# %% [markdown]
# ### Random seed / PyTorch / CUDA related

# %%
import torch
import numpy as np

# Google Colab-only setup. No need to run this cell in other environments.
use_colab = False

if use_colab:
    # Mount my Google Drive root folder
    from google.colab import drive
    drive.mount('/content/drive')

    # cd to bayesian-dl-experiments directory
    # %cd 'drive/My Drive/Colab Notebooks/bayesian-dl-experiments'
    # !ls

# IPython reloading magic
# %load_ext autoreload
# %autoreload 2

# Random seeds
# Based on https://pytorch.org/docs/stable/notes/randomness.html
torch.manual_seed(682)
np.random.seed(682)

# torch.device / CUDA Setup
use_cuda = True

if use_cuda and torch.cuda.is_available():
    torch_device = torch.device('cuda')
    torch.backends.cudnn.deterministic = True
    # Note: https://discuss.pytorch.org/t/what-does-torch-backends-cudnn-benchmark-do/5936
    torch.backends.cudnn.benchmark = False
    use_pin_memory=True # Faster Host to GPU copies with page-locked memory
else:
    torch_device = torch.device('cpu')
    use_pin_memory=False

# %% [markdown]
# ### Variable settings

# %%
# Dataset to use
dataset_name = 'naval-propulsion-plant' #@param ["yacht", "naval-propulsion-plant"]

# Training set size
dataset_train_size = 0.8 #@param {type:"slider", min:0.1, max:0.9, step:0.05}

# L2 regularization strength
reg_strength = 0.01 #@param {type:"slider", min:0, max:1.0, step:0.05}

# Epochs
n_epochs = 4000 #@param {type:"integer"}

# Number of different data splits to try
n_splits = 20 #@param {type:"integer"}

# Data batch sizes
n_training_batch = 128 #@param {type:"integer"}

# Number of test predictions (for each data point)
n_predictions = 10000 #@param {type:"integer"}

# %% [markdown]
# ### Training setup

# %%
import time
from itertools import product

from torch import nn, optim
from torch.utils.data import random_split, DataLoader, RandomSampler
from ronald_bdl import models, datasets

# Set the training/test set sizes
subset_proportions = np.arange(0.1, 1.1, 0.1)

# NN hyperparameters
network_hidden_dim_candidates = np.arange(10, 100+10, 10)
network_hidden_layer_candidates = np.arange(1, 5+1, 1)

# Mean Squared Error for loss function to minimize
objective = nn.MSELoss()

rmse_non_mc, rmse_mc, test_lls_mc = [], [], []

# %% [markdown]
# ## Train the network

# %%
for subset_prop, hidden_dim, n_hidden, dropout_rate, reg_strength in product(
    subset_proportions,
    network_hidden_dims, network_hidden_layers, network_dropout_rates,
    regularization_strengths,
):
    
    # Create directory to store results for the current test configuration
    test_results_path = os.path.join(
        './test_results',
        'nn_capacity_1',
        dataset_name,
        test_start_time,
        str(subset_prop) + '_' + str(hidden_dim) + '_' + str(n_hidden) + '_' + str(dropout_rate) + '_' + str(reg_strength),
    )
    
    os.makedirs(test_results_path)
    
    test_results_rmse_mc_path = os.path.join(
        test_results_path,
        "rmse_mc.txt"
    )
    
    test_results_lls_mc_path = os.path.join(
        test_results_path,
        "lls_mc.txt"
    )
    
    test_results_times_mc_path = os.path.join(
        test_results_path,
        "times_mc.txt"
    )

    # Prepare new subset of the original dataset
    subset = datasets.UCIDatasets(
        dataset_name, root_dir='./datasets_files', 
        limit_size=subset_prop, transform=None, download=True, pin_memory=use_pin_memory)

    # Determine sizes of training and testing set
    train_size = int(dataset_train_size * len(subset))
    test_size = len(subset) - train_size
    
    # Print the size of the subset
    print("subset size = " + str((len(subset), subset.n_features)))
    print("training set size = %d" % train_size)
    print("test set size = %d" % test_size)
    
    train, test = random_split(subset, lengths=[train_size, test_size])
    train_loader = DataLoader(train, batch_size=n_training_batch, pin_memory=use_pin_memory)

    # Prepare network
    network = models.FCNetMCDropout(
        input_dim=subset.n_features, 
        output_dim=subset.n_targets,
        hidden_dim=hidden_dim,
        n_hidden=n_hidden,
        dropout_rate=0.01,
        dropout_type='bernoulli'
    )
    
    # Send the whole model to the selected torch.device
    network.to(torch_device)

    # Print the network structure
    print(network)
    
    # Model to train mode
    network.train()
    
    # Adam optimizer
    # https://pytorch.org/docs/stable/optim.html?highlight=adam#torch.optim.Adam
    # NOTE: Need to set L2 regularization from here
    optimizer = optim.Adam(
        network.parameters(),
        lr=0.01,
        weight_decay=reg_strength, # L2 regularization
    )
    
    """
    Training
    """

    print("Starting subset %f, n_hidden %d, hidden_dim %d" % (subset_prop, n_hidden, hidden_dim))

    # Record training start time (for this split)
    tic = time.time()

    for epoch in range(n_epochs): # loop over the dataset multiple times

        for i, data in enumerate(train_loader):
            # get the inputs; data is a list of [inputs, labels]
            inputs, targets = data

            # Store the batch to torch_device's memory
            inputs = inputs.to(torch_device)
            targets = targets.to(torch_device)

            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            outputs = network(inputs)

            loss = objective(outputs, targets)
            loss.backward()

            optimizer.step()
            
    # Record training end time
    toc = time.time()

    # Report the final loss
    print("Finished subset %f, n_hidden %d, hidden_dim %d: final loss = %f" % (subset_prop, n_hidden, hidden_dim, loss.item()))

    """
    Testing
    """

    # Model to eval mode
    network.eval()

    # Get the test data
    inputs, targets = test.dataset[test.indices]

    # Store the batch to torch_device's memory
    inputs = inputs.to(torch_device)
    targets = targets.to(torch_device)

    # Record testing start time (for this split)
    tic_testing = time.time()    
    
    predictions, mean, var, metrics = network.mc_predict(inputs, n_predictions,
                                                         y_test=targets, reg_strength=reg_strength)

    # Record testing end time
    toc_testing = time.time()    
    
    """
    Print results
    """
    print()
    print("Running split subset %f, n_hidden %d, hidden_dim %d test: "% (subset_prop, n_hidden, hidden_dim))
    print("Mean = " + str(mean))
    print("Variance = " + str(var))

    # Print and store additional metrics
    if len(metrics) > 0:
        for key, value in metrics.items():
            print(str(key) + " = " + str(value))

            if key == 'rmse_mc': rmse_mc.append(value.item())
            elif key == 'rmse_non_mc': rmse_non_mc.append(value.item())
            elif key == 'test_ll_mc': test_lls_mc.append(value.item())

    # Report the total training time
    print("training time = " + str(toc - tic) + " seconds")
    
    # Report the total testing time
    print("testing time = " + str(toc_testing - tic_testing) + " seconds")
    print()
# Out:
# Using downloaded and verified file: ./datasets_files/yacht/yacht_hydrodynamics.data
# subset size = (61, 6)
# training set size = 48
# test set size = 13
# FCNetMCDropout(
#   (input): Linear(in_features=6, out_features=50, bias=True)
#   (hidden_layers): ModuleList(
#     (0): Linear(in_features=50, out_features=50, bias=True)
#   )
#   (output): Linear(in_features=50, out_features=1, bias=True)
# )
# Starting subset 0.200000, n_hidden 1, hidden_dim 50, dropout_rate 0.100000, reg_strength 0.025000
# final loss = 5.160277
# 10 test runs...
# rmse_mc = tensor(3.9749, device='cuda:0')
# rmse_non_mc = tensor(3.6697, device='cuda:0')
# test_ll_mc = tensor(-2.9571, device='cuda:0')
#
# 100 test runs...
# rmse_mc = tensor(3.8110, device='cuda:0')
# rmse_non_mc = tensor(4.1376, device='cuda:0')
# test_ll_mc = tensor(-2.9603, device='cuda:0')
#
# 1000 test runs...
# rmse_mc = tensor(3.8419, device='cuda:0')
# rmse_non_mc = tensor(3.9257, device='cuda:0')
# test_ll_mc = tensor(-2.9587, device='cuda:0')
#
# 3000 test runs...
# rmse_mc = tensor(3.8367, device='cuda:0')
# rmse_non_mc = tensor(4.2048, device='cuda:0')
# test_ll_mc = tensor(-2.9584, device='cuda:0')
#
# 5000 test runs...
# rmse_mc = tensor(3.8377, device='cuda:0')
# rmse_non_mc = tensor(5.1013, device='cuda:0')
# test_ll_mc = tensor(-2.9586, device='cuda:0')
#
# 7000 test runs...
# rmse_mc = tensor(3.8260, device='cuda:0')
# rmse_non_mc = tensor(4.1050, device='cuda:0')
# test_ll_mc = tensor(-2.9588, device='cuda:0')
#
# 10000 test runs...
# rmse_mc = tensor(3.8351, device='cuda:0')
# rmse_non_mc = tensor(4.6680, device='cuda:0')
# test_ll_mc = tensor(-2.9585, device='cuda:0')
#
# training time = 14.348586797714233 seconds
# testing time (last set) = 2.0509824752807617 seconds
#
# Using downloaded and verified file: ./datasets_files/yacht/yacht_hydrodynamics.data
# subset size = (61, 6)
# training set size = 48
# test set size = 13
# FCNetMCDropout(
#   (input): Linear(in_features=6, out_features=50, bias=True)
#   (hidden_layers): ModuleList(
#     (0): Linear(in_features=50, out_features=50, bias=True)
#   )
#   (output): Linear(in_features=50, out_features=1, bias=True)
# )
# Starting subset 0.200000, n_hidden 1, hidden_dim 50, dropout_rate 0.100000, reg_strength 0.050000
# final loss = 2.567935
# 10 test runs...
# rmse_mc = tensor(1.8657, device='cuda:0')
# rmse_non_mc = tensor(1.7964, device='cuda:0')
# test_ll_mc = tensor(-2.5219, device='cuda:0')
#
# 100 test runs...
# rmse_mc = tensor(1.8952, device='cuda:0')
# rmse_non_mc = tensor(2.0039, device='cuda:0')
# test_ll_mc = tensor(-2.5266, device='cuda:0')
#
# 1000 test runs...
# rmse_mc = tensor(1.8442, device='cuda:0')
# rmse_non_mc = tensor(1.2596, device='cuda:0')
# test_ll_mc = tensor(-2.5202, device='cuda:0')
#
# 3000 test runs...
# rmse_mc = tensor(1.8421, device='cuda:0')
# rmse_non_mc = tensor(1.7823, device='cuda:0')
# test_ll_mc = tensor(-2.5204, device='cuda:0')
#
# 5000 test runs...
# rmse_mc = tensor(1.8488, device='cuda:0')
# rmse_non_mc = tensor(2.2960, device='cuda:0')
# test_ll_mc = tensor(-2.5209, device='cuda:0')
#
# 7000 test runs...
# rmse_mc = tensor(1.8440, device='cuda:0')
# rmse_non_mc = tensor(1.7765, device='cuda:0')
# test_ll_mc = tensor(-2.5208, device='cuda:0')
#
# 10000 test runs...
# rmse_mc = tensor(1.8452, device='cuda:0')
# rmse_non_mc = tensor(1.7661, device='cuda:0')
# test_ll_mc = tensor(-2.5209, device='cuda:0')
#
# training time = 14.32326602935791 seconds
# testing time (last set) = 2.0337376594543457 seconds
#
# Using downloaded and verified file: ./datasets_files/yacht/yacht_hydrodynamics.data
# subset size = (61, 6)
# training set size = 48
# test set size = 13
# FCNetMCDropout(
#   (input): Linear(in_features=6, out_features=50, bias=True)
#   (hidden_layers): ModuleList(
#     (0): Linear(in_features=50, out_features=50, bias=True)
#   )
#   (output): Linear(in_features=50, out_features=1, bias=True)
# )
# Starting subset 0.200000, n_hidden 1, hidden_dim 50, dropout_rate 0.100000, reg_strength 0.075000
# final loss = 7.968966
# 10 test runs...
# rmse_mc = tensor(2.7538, device='cuda:0')
# rmse_non_mc = tensor(2.9767, device='cuda:0')
# test_ll_mc = tensor(-2.4960, device='cuda:0')
#
# 100 test runs...
# rmse_mc = tensor(2.7879, device='cuda:0')
# rmse_non_mc = tensor(2.4267, device='cuda:0')
# test_ll_mc = tensor(-2.5179, device='cuda:0')
#
# 1000 test runs...
# rmse_mc = tensor(2.7107, device='cuda:0')
# rmse_non_mc = tensor(3.0194, device='cuda:0')
# test_ll_mc = tensor(-2.5067, device='cuda:0')
#
# 3000 test runs...
# rmse_mc = tensor(2.7227, device='cuda:0')
# rmse_non_mc = tensor(2.9610, device='cuda:0')
# test_ll_mc = tensor(-2.5154, device='cuda:0')
#
# 5000 test runs...
# rmse_mc = tensor(2.7427, device='cuda:0')
# rmse_non_mc = tensor(2.8179, device='cuda:0')
# test_ll_mc = tensor(-2.5152, device='cuda:0')
#
# 7000 test runs...
# rmse_mc = tensor(2.7387, device='cuda:0')
# rmse_non_mc = tensor(4.5109, device='cuda:0')
# test_ll_mc = tensor(-2.5173, device='cuda:0')
#
# 10000 test runs...
# rmse_mc = tensor(2.7316, device='cuda:0')
# rmse_non_mc = tensor(3.9165, device='cuda:0')
# test_ll_mc = tensor(-2.5159, device='cuda:0')
#
# training time = 14.68925666809082 seconds
# testing time (last set) = 2.046987533569336 seconds
#
# Using downloaded and verified file: ./datasets_files/yacht/yacht_hydrodynamics.data
# subset size = (61, 6)
# training set size = 48
# test set size = 13
# FCNetMCDropout(
#   (input): Linear(in_features=6, out_features=50, bias=True)
#   (hidden_layers): ModuleList(
#     (0): Linear(in_features=50, out_features=50, bias=True)
#   )
#   (output): Linear(in_features=50, out_features=1, bias=True)
# )
# Starting subset 0.200000, n_hidden 1, hidden_dim 50, dropout_rate 0.300000, reg_strength 0.025000
# final loss = 14.263050
# 10 test runs...
# rmse_mc = tensor(10.3288, device='cuda:0')
# rmse_non_mc = tensor(9.9030, device='cuda:0')
# test_ll_mc = tensor(-4.0559, device='cuda:0')
#
# 100 test runs...
# rmse_mc = tensor(10.4378, device='cuda:0')
# rmse_non_mc = tensor(11.1960, device='cuda:0')
# test_ll_mc = tensor(-3.5728, device='cuda:0')
#
# 1000 test runs...
# rmse_mc = tensor(10.3546, device='cuda:0')
# rmse_non_mc = tensor(11.2782, device='cuda:0')
# test_ll_mc = tensor(-3.5471, device='cuda:0')
#
# 3000 test runs...
# rmse_mc = tensor(10.3665, device='cuda:0')
# rmse_non_mc = tensor(9.8079, device='cuda:0')
# test_ll_mc = tensor(-3.5422, device='cuda:0')
#
# 5000 test runs...
# rmse_mc = tensor(10.3715, device='cuda:0')
# rmse_non_mc = tensor(10.3778, device='cuda:0')
# test_ll_mc = tensor(-3.5418, device='cuda:0')
#
# 7000 test runs...
# rmse_mc = tensor(10.3829, device='cuda:0')
# rmse_non_mc = tensor(11.4820, device='cuda:0')
# test_ll_mc = tensor(-3.5472, device='cuda:0')
#
# 10000 test runs...
# rmse_mc = tensor(10.3804, device='cuda:0')
# rmse_non_mc = tensor(11.1346, device='cuda:0')
# test_ll_mc = tensor(-3.5469, device='cuda:0')
#
# training time = 14.618565559387207 seconds
# testing time (last set) = 2.085956335067749 seconds
#
# Using downloaded and verified file: ./datasets_files/yacht/yacht_hydrodynamics.data
# subset size = (61, 6)
# training set size = 48
# test set size = 13
# FCNetMCDropout(
#   (input): Linear(in_features=6, out_features=50, bias=True)
#   (hidden_layers): ModuleList(
#     (0): Linear(in_features=50, out_features=50, bias=True)
#   )
#   (output): Linear(in_features=50, out_features=1, bias=True)
# )
# Starting subset 0.200000, n_hidden 1, hidden_dim 50, dropout_rate 0.300000, reg_strength 0.050000
# final loss = 30.684845
# 10 test runs...
# rmse_mc = tensor(6.9958, device='cuda:0')
# rmse_non_mc = tensor(7.3386, device='cuda:0')
# test_ll_mc = tensor(-2.9116, device='cuda:0')
#
# 100 test runs...
# rmse_mc = tensor(6.6482, device='cuda:0')
# rmse_non_mc = tensor(6.2005, device='cuda:0')
# test_ll_mc = tensor(-2.9042, device='cuda:0')
#
# 1000 test runs...
# rmse_mc = tensor(6.6846, device='cuda:0')
# rmse_non_mc = tensor(6.1262, device='cuda:0')
# test_ll_mc = tensor(-2.8916, device='cuda:0')
#
# 3000 test runs...
# rmse_mc = tensor(6.6929, device='cuda:0')
# rmse_non_mc = tensor(7.2452, device='cuda:0')
# test_ll_mc = tensor(-2.8953, device='cuda:0')
#
# 5000 test runs...
# rmse_mc = tensor(6.7208, device='cuda:0')
# rmse_non_mc = tensor(7.4067, device='cuda:0')
# test_ll_mc = tensor(-2.8883, device='cuda:0')
#
# 7000 test runs...
# rmse_mc = tensor(6.6958, device='cuda:0')
# rmse_non_mc = tensor(8.9346, device='cuda:0')
# test_ll_mc = tensor(-2.8885, device='cuda:0')
#
# 10000 test runs...
# rmse_mc = tensor(6.6912, device='cuda:0')
# rmse_non_mc = tensor(11.0664, device='cuda:0')
# test_ll_mc = tensor(-2.8914, device='cuda:0')
#
# training time = 14.469874382019043 seconds
# testing time (last set) = 2.143785238265991 seconds
#
# Using downloaded and verified file: ./datasets_files/yacht/yacht_hydrodynamics.data
# subset size = (61, 6)
# training set size = 48
# test set size = 13
# FCNetMCDropout(
#   (input): Linear(in_features=6, out_features=50, bias=True)
#   (hidden_layers): ModuleList(
#     (0): Linear(in_features=50, out_features=50, bias=True)
#   )
#   (output): Linear(in_features=50, out_features=1, bias=True)
# )
# Starting subset 0.200000, n_hidden 1, hidden_dim 50, dropout_rate 0.300000, reg_strength 0.075000
# final loss = 18.730274
# 10 test runs...
# rmse_mc = tensor(2.0777, device='cuda:0')
# rmse_non_mc = tensor(2.5278, device='cuda:0')
# test_ll_mc = tensor(-2.4349, device='cuda:0')
#
# 100 test runs...
# rmse_mc = tensor(1.8159, device='cuda:0')
# rmse_non_mc = tensor(2.7963, device='cuda:0')
# test_ll_mc = tensor(-2.4081, device='cuda:0')
#
# 1000 test runs...
# rmse_mc = tensor(1.6839, device='cuda:0')
# rmse_non_mc = tensor(3.5800, device='cuda:0')
# test_ll_mc = tensor(-2.4157, device='cuda:0')
#
# 3000 test runs...
# rmse_mc = tensor(1.6361, device='cuda:0')
# rmse_non_mc = tensor(1.9630, device='cuda:0')
# test_ll_mc = tensor(-2.4138, device='cuda:0')
#
# 5000 test runs...
# rmse_mc = tensor(1.6629, device='cuda:0')
# rmse_non_mc = tensor(2.1265, device='cuda:0')
# test_ll_mc = tensor(-2.4140, device='cuda:0')
#
# 7000 test runs...
# rmse_mc = tensor(1.6134, device='cuda:0')
# rmse_non_mc = tensor(3.5262, device='cuda:0')
# test_ll_mc = tensor(-2.4120, device='cuda:0')
#
# 10000 test runs...
# rmse_mc = tensor(1.6571, device='cuda:0')
# rmse_non_mc = tensor(1.6984, device='cuda:0')
# test_ll_mc = tensor(-2.4132, device='cuda:0')
#
# training time = 14.561481952667236 seconds
# testing time (last set) = 2.1492855548858643 seconds
#
# Using downloaded and verified file: ./datasets_files/yacht/yacht_hydrodynamics.data
# subset size = (61, 6)
# training set size = 48
# test set size = 13
# FCNetMCDropout(
#   (input): Linear(in_features=6, out_features=50, bias=True)
#   (hidden_layers): ModuleList(
#     (0): Linear(in_features=50, out_features=50, bias=True)
#   )
#   (output): Linear(in_features=50, out_features=1, bias=True)
# )
# Starting subset 0.200000, n_hidden 1, hidden_dim 50, dropout_rate 0.500000, reg_strength 0.025000
# final loss = 51.877605
# 10 test runs...
# rmse_mc = tensor(3.7798, device='cuda:0')
# rmse_non_mc = tensor(6.3531, device='cuda:0')
# test_ll_mc = tensor(-3.0728, device='cuda:0')
#
# 100 test runs...
# rmse_mc = tensor(3.2904, device='cuda:0')
# rmse_non_mc = tensor(6.0557, device='cuda:0')
# test_ll_mc = tensor(-3.0926, device='cuda:0')
#
# 1000 test runs...
# rmse_mc = tensor(3.2216, device='cuda:0')
# rmse_non_mc = tensor(6.6799, device='cuda:0')
# test_ll_mc = tensor(-3.0790, device='cuda:0')
#
# 3000 test runs...
# rmse_mc = tensor(3.1440, device='cuda:0')
# rmse_non_mc = tensor(6.7775, device='cuda:0')
# test_ll_mc = tensor(-3.0768, device='cuda:0')
#
# 5000 test runs...
# rmse_mc = tensor(3.1704, device='cuda:0')
# rmse_non_mc = tensor(4.4125, device='cuda:0')
# test_ll_mc = tensor(-3.0762, device='cuda:0')
#
# 7000 test runs...
# rmse_mc = tensor(3.1712, device='cuda:0')
# rmse_non_mc = tensor(4.4217, device='cuda:0')
# test_ll_mc = tensor(-3.0777, device='cuda:0')
#
# 10000 test runs...
# rmse_mc = tensor(3.1650, device='cuda:0')
# rmse_non_mc = tensor(5.0556, device='cuda:0')
# test_ll_mc = tensor(-3.0773, device='cuda:0')
#
# training time = 14.53996992111206 seconds
# testing time (last set) = 2.096423864364624 seconds
#
# Using downloaded and verified file: ./datasets_files/yacht/yacht_hydrodynamics.data
# subset size = (61, 6)
# training set size = 48
# test set size = 13
# FCNetMCDropout(
#   (input): Linear(in_features=6, out_features=50, bias=True)
#   (hidden_layers): ModuleList(
#     (0): Linear(in_features=50, out_features=50, bias=True)
#   )
#   (output): Linear(in_features=50, out_features=1, bias=True)
# )
# Starting subset 0.200000, n_hidden 1, hidden_dim 50, dropout_rate 0.500000, reg_strength 0.050000
# final loss = 13.277191
# 10 test runs...
# rmse_mc = tensor(7.9148, device='cuda:0')
# rmse_non_mc = tensor(7.2767, device='cuda:0')
# test_ll_mc = tensor(-2.9691, device='cuda:0')
#
# 100 test runs...
# rmse_mc = tensor(6.5500, device='cuda:0')
# rmse_non_mc = tensor(10.2973, device='cuda:0')
# test_ll_mc = tensor(-2.8260, device='cuda:0')
#
# 1000 test runs...
# rmse_mc = tensor(6.6454, device='cuda:0')
# rmse_non_mc = tensor(4.4933, device='cuda:0')
# test_ll_mc = tensor(-2.8515, device='cuda:0')
#
# 3000 test runs...
# rmse_mc = tensor(6.9623, device='cuda:0')
# rmse_non_mc = tensor(7.0297, device='cuda:0')
# test_ll_mc = tensor(-2.8449, device='cuda:0')
#
# 5000 test runs...
# rmse_mc = tensor(6.9364, device='cuda:0')
# rmse_non_mc = tensor(9.7632, device='cuda:0')
# test_ll_mc = tensor(-2.8523, device='cuda:0')
#
# 7000 test runs...
# rmse_mc = tensor(6.9848, device='cuda:0')
# rmse_non_mc = tensor(12.8295, device='cuda:0')
# test_ll_mc = tensor(-2.8518, device='cuda:0')
#
# 10000 test runs...
# rmse_mc = tensor(6.9074, device='cuda:0')
# rmse_non_mc = tensor(7.4941, device='cuda:0')
# test_ll_mc = tensor(-2.8535, device='cuda:0')
#
# training time = 14.569151878356934 seconds
# testing time (last set) = 2.1107494831085205 seconds
#
# Using downloaded and verified file: ./datasets_files/yacht/yacht_hydrodynamics.data
# subset size = (61, 6)
# training set size = 48
# test set size = 13
# FCNetMCDropout(
#   (input): Linear(in_features=6, out_features=50, bias=True)
#   (hidden_layers): ModuleList(
#     (0): Linear(in_features=50, out_features=50, bias=True)
#   )
#   (output): Linear(in_features=50, out_features=1, bias=True)
# )
# Starting subset 0.200000, n_hidden 1, hidden_dim 50, dropout_rate 0.500000, reg_strength 0.075000
# final loss = 65.768227
# 10 test runs...
# rmse_mc = tensor(4.4788, device='cuda:0')
# rmse_non_mc = tensor(7.0551, device='cuda:0')
# test_ll_mc = tensor(-2.7159, device='cuda:0')
#
# 100 test runs...
# rmse_mc = tensor(4.3790, device='cuda:0')
# rmse_non_mc = tensor(8.1092, device='cuda:0')
# test_ll_mc = tensor(-2.7590, device='cuda:0')
#
# 1000 test runs...
# rmse_mc = tensor(3.9913, device='cuda:0')
# rmse_non_mc = tensor(6.8970, device='cuda:0')
# test_ll_mc = tensor(-2.7282, device='cuda:0')
#
# 3000 test runs...
# rmse_mc = tensor(3.9960, device='cuda:0')
# rmse_non_mc = tensor(7.2682, device='cuda:0')
# test_ll_mc = tensor(-2.7248, device='cuda:0')
#
# 5000 test runs...
# rmse_mc = tensor(4.0176, device='cuda:0')
# rmse_non_mc = tensor(4.2497, device='cuda:0')
# test_ll_mc = tensor(-2.7260, device='cuda:0')
#
# 7000 test runs...
# rmse_mc = tensor(4.0243, device='cuda:0')
# rmse_non_mc = tensor(10.5968, device='cuda:0')
# test_ll_mc = tensor(-2.7230, device='cuda:0')
#
# 10000 test runs...
# rmse_mc = tensor(4.0070, device='cuda:0')
# rmse_non_mc = tensor(6.8934, device='cuda:0')
# test_ll_mc = tensor(-2.7220, device='cuda:0')
#
# training time = 14.458415269851685 seconds
# testing time (last set) = 2.1295812129974365 seconds
#
# Using downloaded and verified file: ./datasets_files/yacht/yacht_hydrodynamics.data
# subset size = (61, 6)
# training set size = 48
# test set size = 13
# FCNetMCDropout(
#   (input): Linear(in_features=6, out_features=50, bias=True)
#   (hidden_layers): ModuleList(
#     (0): Linear(in_features=50, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=50, bias=True)
#   )
#   (output): Linear(in_features=50, out_features=1, bias=True)
# )
# Starting subset 0.200000, n_hidden 2, hidden_dim 50, dropout_rate 0.100000, reg_strength 0.025000
# final loss = 9.209355
# 10 test runs...
# rmse_mc = tensor(2.1630, device='cuda:0')
# rmse_non_mc = tensor(3.2990, device='cuda:0')
# test_ll_mc = tensor(-2.8385, device='cuda:0')
#
# 100 test runs...
# rmse_mc = tensor(2.3742, device='cuda:0')
# rmse_non_mc = tensor(2.1881, device='cuda:0')
# test_ll_mc = tensor(-2.8404, device='cuda:0')
#
# 1000 test runs...
# rmse_mc = tensor(2.3229, device='cuda:0')
# rmse_non_mc = tensor(2.9368, device='cuda:0')
# test_ll_mc = tensor(-2.8399, device='cuda:0')
#
# 3000 test runs...
# rmse_mc = tensor(2.2659, device='cuda:0')
# rmse_non_mc = tensor(2.5142, device='cuda:0')
# test_ll_mc = tensor(-2.8377, device='cuda:0')
#
# 5000 test runs...
# rmse_mc = tensor(2.2825, device='cuda:0')
# rmse_non_mc = tensor(3.7461, device='cuda:0')
# test_ll_mc = tensor(-2.8379, device='cuda:0')
#
# 7000 test runs...
# rmse_mc = tensor(2.2846, device='cuda:0')
# rmse_non_mc = tensor(2.6948, device='cuda:0')
# test_ll_mc = tensor(-2.8381, device='cuda:0')
#
# 10000 test runs...
# rmse_mc = tensor(2.2936, device='cuda:0')
# rmse_non_mc = tensor(2.9861, device='cuda:0')
# test_ll_mc = tensor(-2.8387, device='cuda:0')
#
# training time = 16.457755088806152 seconds
# testing time (last set) = 2.8692002296447754 seconds
#
# Using downloaded and verified file: ./datasets_files/yacht/yacht_hydrodynamics.data
# subset size = (61, 6)
# training set size = 48
# test set size = 13
# FCNetMCDropout(
#   (input): Linear(in_features=6, out_features=50, bias=True)
#   (hidden_layers): ModuleList(
#     (0): Linear(in_features=50, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=50, bias=True)
#   )
#   (output): Linear(in_features=50, out_features=1, bias=True)
# )
# Starting subset 0.200000, n_hidden 2, hidden_dim 50, dropout_rate 0.100000, reg_strength 0.050000
# final loss = 6.448081
# 10 test runs...
# rmse_mc = tensor(4.1879, device='cuda:0')
# rmse_non_mc = tensor(4.5671, device='cuda:0')
# test_ll_mc = tensor(-2.7133, device='cuda:0')
#
# 100 test runs...
# rmse_mc = tensor(3.4940, device='cuda:0')
# rmse_non_mc = tensor(4.1865, device='cuda:0')
# test_ll_mc = tensor(-2.6909, device='cuda:0')
#
# 1000 test runs...
# rmse_mc = tensor(3.6706, device='cuda:0')
# rmse_non_mc = tensor(4.7466, device='cuda:0')
# test_ll_mc = tensor(-2.7027, device='cuda:0')
#
# 3000 test runs...
# rmse_mc = tensor(3.6168, device='cuda:0')
# rmse_non_mc = tensor(3.6389, device='cuda:0')
# test_ll_mc = tensor(-2.6981, device='cuda:0')
#
# 5000 test runs...
# rmse_mc = tensor(3.6399, device='cuda:0')
# rmse_non_mc = tensor(5.9645, device='cuda:0')
# test_ll_mc = tensor(-2.6984, device='cuda:0')
#
# 7000 test runs...
# rmse_mc = tensor(3.6593, device='cuda:0')
# rmse_non_mc = tensor(5.5587, device='cuda:0')
# test_ll_mc = tensor(-2.7019, device='cuda:0')
#
# 10000 test runs...
# rmse_mc = tensor(3.6368, device='cuda:0')
# rmse_non_mc = tensor(4.8953, device='cuda:0')
# test_ll_mc = tensor(-2.6993, device='cuda:0')
#
# training time = 16.55372667312622 seconds
# testing time (last set) = 2.936631202697754 seconds
#
# Using downloaded and verified file: ./datasets_files/yacht/yacht_hydrodynamics.data
# subset size = (61, 6)
# training set size = 48
# test set size = 13
# FCNetMCDropout(
#   (input): Linear(in_features=6, out_features=50, bias=True)
#   (hidden_layers): ModuleList(
#     (0): Linear(in_features=50, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=50, bias=True)
#   )
#   (output): Linear(in_features=50, out_features=1, bias=True)
# )
# Starting subset 0.200000, n_hidden 2, hidden_dim 50, dropout_rate 0.100000, reg_strength 0.075000
# final loss = 7.980785
# 10 test runs...
# rmse_mc = tensor(2.6960, device='cuda:0')
# rmse_non_mc = tensor(3.5808, device='cuda:0')
# test_ll_mc = tensor(-2.4613, device='cuda:0')
#
# 100 test runs...
# rmse_mc = tensor(3.0448, device='cuda:0')
# rmse_non_mc = tensor(3.3181, device='cuda:0')
# test_ll_mc = tensor(-2.5082, device='cuda:0')
#
# 1000 test runs...
# rmse_mc = tensor(3.0546, device='cuda:0')
# rmse_non_mc = tensor(2.6285, device='cuda:0')
# test_ll_mc = tensor(-2.5166, device='cuda:0')
#
# 3000 test runs...
# rmse_mc = tensor(3.0152, device='cuda:0')
# rmse_non_mc = tensor(3.6378, device='cuda:0')
# test_ll_mc = tensor(-2.5084, device='cuda:0')
#
# 5000 test runs...
# rmse_mc = tensor(3.0371, device='cuda:0')
# rmse_non_mc = tensor(5.3040, device='cuda:0')
# test_ll_mc = tensor(-2.5129, device='cuda:0')
#
# 7000 test runs...
# rmse_mc = tensor(3.0266, device='cuda:0')
# rmse_non_mc = tensor(3.3194, device='cuda:0')
# test_ll_mc = tensor(-2.5105, device='cuda:0')
#
# 10000 test runs...
# rmse_mc = tensor(3.0212, device='cuda:0')
# rmse_non_mc = tensor(3.1784, device='cuda:0')
# test_ll_mc = tensor(-2.5097, device='cuda:0')
#
# training time = 16.797505378723145 seconds
# testing time (last set) = 2.915421485900879 seconds
#
# Using downloaded and verified file: ./datasets_files/yacht/yacht_hydrodynamics.data
# subset size = (61, 6)
# training set size = 48
# test set size = 13
# FCNetMCDropout(
#   (input): Linear(in_features=6, out_features=50, bias=True)
#   (hidden_layers): ModuleList(
#     (0): Linear(in_features=50, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=50, bias=True)
#   )
#   (output): Linear(in_features=50, out_features=1, bias=True)
# )
# Starting subset 0.200000, n_hidden 2, hidden_dim 50, dropout_rate 0.300000, reg_strength 0.025000
# final loss = 20.243963
# 10 test runs...
# rmse_mc = tensor(1.8351, device='cuda:0')
# rmse_non_mc = tensor(4.4144, device='cuda:0')
# test_ll_mc = tensor(-2.8843, device='cuda:0')
#
# 100 test runs...
# rmse_mc = tensor(3.9234, device='cuda:0')
# rmse_non_mc = tensor(2.4545, device='cuda:0')
# test_ll_mc = tensor(-2.9243, device='cuda:0')
#
# 1000 test runs...
# rmse_mc = tensor(3.3901, device='cuda:0')
# rmse_non_mc = tensor(2.6763, device='cuda:0')
# test_ll_mc = tensor(-2.9130, device='cuda:0')
#
# 3000 test runs...
# rmse_mc = tensor(3.3666, device='cuda:0')
# rmse_non_mc = tensor(4.5719, device='cuda:0')
# test_ll_mc = tensor(-2.9130, device='cuda:0')
#
# 5000 test runs...
# rmse_mc = tensor(3.3419, device='cuda:0')
# rmse_non_mc = tensor(3.4293, device='cuda:0')
# test_ll_mc = tensor(-2.9122, device='cuda:0')
#
# 7000 test runs...
# rmse_mc = tensor(3.2710, device='cuda:0')
# rmse_non_mc = tensor(3.4804, device='cuda:0')
# test_ll_mc = tensor(-2.9111, device='cuda:0')
#
# 10000 test runs...
# rmse_mc = tensor(3.2904, device='cuda:0')
# rmse_non_mc = tensor(2.8378, device='cuda:0')
# test_ll_mc = tensor(-2.9113, device='cuda:0')
#
# training time = 16.481667280197144 seconds
# testing time (last set) = 2.914257764816284 seconds
#
# Using downloaded and verified file: ./datasets_files/yacht/yacht_hydrodynamics.data
# subset size = (61, 6)
# training set size = 48
# test set size = 13
# FCNetMCDropout(
#   (input): Linear(in_features=6, out_features=50, bias=True)
#   (hidden_layers): ModuleList(
#     (0): Linear(in_features=50, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=50, bias=True)
#   )
#   (output): Linear(in_features=50, out_features=1, bias=True)
# )
# Starting subset 0.200000, n_hidden 2, hidden_dim 50, dropout_rate 0.300000, reg_strength 0.050000
# final loss = 127.399422
# 10 test runs...
# rmse_mc = tensor(4.3737, device='cuda:0')
# rmse_non_mc = tensor(9.9053, device='cuda:0')
# test_ll_mc = tensor(-2.7311, device='cuda:0')
#
# 100 test runs...
# rmse_mc = tensor(5.5209, device='cuda:0')
# rmse_non_mc = tensor(8.7062, device='cuda:0')
# test_ll_mc = tensor(-2.7674, device='cuda:0')
#
# 1000 test runs...
# rmse_mc = tensor(5.3195, device='cuda:0')
# rmse_non_mc = tensor(4.7721, device='cuda:0')
# test_ll_mc = tensor(-2.7661, device='cuda:0')
#
# 3000 test runs...
# rmse_mc = tensor(5.3079, device='cuda:0')
# rmse_non_mc = tensor(3.8109, device='cuda:0')
# test_ll_mc = tensor(-2.7679, device='cuda:0')
#
# 5000 test runs...
# rmse_mc = tensor(5.3345, device='cuda:0')
# rmse_non_mc = tensor(7.0080, device='cuda:0')
# test_ll_mc = tensor(-2.7695, device='cuda:0')
#
# 7000 test runs...
# rmse_mc = tensor(5.3566, device='cuda:0')
# rmse_non_mc = tensor(11.8257, device='cuda:0')
# test_ll_mc = tensor(-2.7668, device='cuda:0')
#
# 10000 test runs...
# rmse_mc = tensor(5.3134, device='cuda:0')
# rmse_non_mc = tensor(14.8584, device='cuda:0')
# test_ll_mc = tensor(-2.7678, device='cuda:0')
#
# training time = 16.746094703674316 seconds
# testing time (last set) = 2.9360806941986084 seconds
#
# Using downloaded and verified file: ./datasets_files/yacht/yacht_hydrodynamics.data
# subset size = (61, 6)
# training set size = 48
# test set size = 13
# FCNetMCDropout(
#   (input): Linear(in_features=6, out_features=50, bias=True)
#   (hidden_layers): ModuleList(
#     (0): Linear(in_features=50, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=50, bias=True)
#   )
#   (output): Linear(in_features=50, out_features=1, bias=True)
# )
# Starting subset 0.200000, n_hidden 2, hidden_dim 50, dropout_rate 0.300000, reg_strength 0.075000
# final loss = 24.863691
# 10 test runs...
# rmse_mc = tensor(7.2919, device='cuda:0')
# rmse_non_mc = tensor(12.4034, device='cuda:0')
# test_ll_mc = tensor(-3.6134, device='cuda:0')
#
# 100 test runs...
# rmse_mc = tensor(6.6454, device='cuda:0')
# rmse_non_mc = tensor(6.2190, device='cuda:0')
# test_ll_mc = tensor(-3.2789, device='cuda:0')
#
# 1000 test runs...
# rmse_mc = tensor(6.7405, device='cuda:0')
# rmse_non_mc = tensor(7.8372, device='cuda:0')
# test_ll_mc = tensor(-3.2294, device='cuda:0')
#
# 3000 test runs...
# rmse_mc = tensor(6.7730, device='cuda:0')
# rmse_non_mc = tensor(7.3012, device='cuda:0')
# test_ll_mc = tensor(-3.2029, device='cuda:0')
#
# 5000 test runs...
# rmse_mc = tensor(6.7678, device='cuda:0')
# rmse_non_mc = tensor(5.7009, device='cuda:0')
# test_ll_mc = tensor(-3.1928, device='cuda:0')
#
# 7000 test runs...
# rmse_mc = tensor(6.7829, device='cuda:0')
# rmse_non_mc = tensor(9.6076, device='cuda:0')
# test_ll_mc = tensor(-3.1987, device='cuda:0')
#
# 10000 test runs...
# rmse_mc = tensor(6.7787, device='cuda:0')
# rmse_non_mc = tensor(13.2792, device='cuda:0')
# test_ll_mc = tensor(-3.2247, device='cuda:0')
#
# training time = 16.825455904006958 seconds
# testing time (last set) = 2.927395820617676 seconds
#
# Using downloaded and verified file: ./datasets_files/yacht/yacht_hydrodynamics.data
# subset size = (61, 6)
# training set size = 48
# test set size = 13
# FCNetMCDropout(
#   (input): Linear(in_features=6, out_features=50, bias=True)
#   (hidden_layers): ModuleList(
#     (0): Linear(in_features=50, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=50, bias=True)
#   )
#   (output): Linear(in_features=50, out_features=1, bias=True)
# )
# Starting subset 0.200000, n_hidden 2, hidden_dim 50, dropout_rate 0.500000, reg_strength 0.025000
# final loss = 52.750202
# 10 test runs...
# rmse_mc = tensor(3.6540, device='cuda:0')
# rmse_non_mc = tensor(7.1914, device='cuda:0')
# test_ll_mc = tensor(-2.9851, device='cuda:0')
#
# 100 test runs...
# rmse_mc = tensor(4.4656, device='cuda:0')
# rmse_non_mc = tensor(9.8174, device='cuda:0')
# test_ll_mc = tensor(-2.9962, device='cuda:0')
#
# 1000 test runs...
# rmse_mc = tensor(4.6743, device='cuda:0')
# rmse_non_mc = tensor(8.0046, device='cuda:0')
# test_ll_mc = tensor(-3.0216, device='cuda:0')
#
# 3000 test runs...
# rmse_mc = tensor(4.4996, device='cuda:0')
# rmse_non_mc = tensor(5.5067, device='cuda:0')
# test_ll_mc = tensor(-3.0149, device='cuda:0')
#
# 5000 test runs...
# rmse_mc = tensor(4.6281, device='cuda:0')
# rmse_non_mc = tensor(4.1810, device='cuda:0')
# test_ll_mc = tensor(-3.0194, device='cuda:0')
#
# 7000 test runs...
# rmse_mc = tensor(4.5848, device='cuda:0')
# rmse_non_mc = tensor(3.9237, device='cuda:0')
# test_ll_mc = tensor(-3.0158, device='cuda:0')
#
# 10000 test runs...
# rmse_mc = tensor(4.6045, device='cuda:0')
# rmse_non_mc = tensor(9.3687, device='cuda:0')
# test_ll_mc = tensor(-3.0178, device='cuda:0')
#
# training time = 16.93478488922119 seconds
# testing time (last set) = 3.062645196914673 seconds
#
# Using downloaded and verified file: ./datasets_files/yacht/yacht_hydrodynamics.data
# subset size = (61, 6)
# training set size = 48
# test set size = 13
# FCNetMCDropout(
#   (input): Linear(in_features=6, out_features=50, bias=True)
#   (hidden_layers): ModuleList(
#     (0): Linear(in_features=50, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=50, bias=True)
#   )
#   (output): Linear(in_features=50, out_features=1, bias=True)
# )
# Starting subset 0.200000, n_hidden 2, hidden_dim 50, dropout_rate 0.500000, reg_strength 0.050000
# final loss = 154.972397
# 10 test runs...
# rmse_mc = tensor(5.3257, device='cuda:0')
# rmse_non_mc = tensor(10.3300, device='cuda:0')
# test_ll_mc = tensor(-3.2886, device='cuda:0')
#
# 100 test runs...
# rmse_mc = tensor(7.8670, device='cuda:0')
# rmse_non_mc = tensor(11.6010, device='cuda:0')
# test_ll_mc = tensor(-3.1918, device='cuda:0')
#
# 1000 test runs...
# rmse_mc = tensor(7.3908, device='cuda:0')
# rmse_non_mc = tensor(11.9558, device='cuda:0')
# test_ll_mc = tensor(-3.1835, device='cuda:0')
#
# 3000 test runs...
# rmse_mc = tensor(7.4796, device='cuda:0')
# rmse_non_mc = tensor(5.1437, device='cuda:0')
# test_ll_mc = tensor(-3.1857, device='cuda:0')
#
# 5000 test runs...
# rmse_mc = tensor(7.3668, device='cuda:0')
# rmse_non_mc = tensor(5.3702, device='cuda:0')
# test_ll_mc = tensor(-3.1778, device='cuda:0')
#
# 7000 test runs...
# rmse_mc = tensor(7.2646, device='cuda:0')
# rmse_non_mc = tensor(11.7417, device='cuda:0')
# test_ll_mc = tensor(-3.1813, device='cuda:0')
#
# 10000 test runs...
# rmse_mc = tensor(7.2574, device='cuda:0')
# rmse_non_mc = tensor(12.1859, device='cuda:0')
# test_ll_mc = tensor(-3.1790, device='cuda:0')
#
# training time = 17.22678780555725 seconds
# testing time (last set) = 2.977916717529297 seconds
#
# Using downloaded and verified file: ./datasets_files/yacht/yacht_hydrodynamics.data
# subset size = (61, 6)
# training set size = 48
# test set size = 13
# FCNetMCDropout(
#   (input): Linear(in_features=6, out_features=50, bias=True)
#   (hidden_layers): ModuleList(
#     (0): Linear(in_features=50, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=50, bias=True)
#   )
#   (output): Linear(in_features=50, out_features=1, bias=True)
# )
# Starting subset 0.200000, n_hidden 2, hidden_dim 50, dropout_rate 0.500000, reg_strength 0.075000
# final loss = 116.584045
# 10 test runs...
# rmse_mc = tensor(4.2859, device='cuda:0')
# rmse_non_mc = tensor(4.2577, device='cuda:0')
# test_ll_mc = tensor(-2.7989, device='cuda:0')
#
# 100 test runs...
# rmse_mc = tensor(4.3784, device='cuda:0')
# rmse_non_mc = tensor(7.3597, device='cuda:0')
# test_ll_mc = tensor(-2.8541, device='cuda:0')
#
# 1000 test runs...
# rmse_mc = tensor(4.5450, device='cuda:0')
# rmse_non_mc = tensor(8.3669, device='cuda:0')
# test_ll_mc = tensor(-2.7997, device='cuda:0')
#
# 3000 test runs...
# rmse_mc = tensor(4.5638, device='cuda:0')
# rmse_non_mc = tensor(8.9621, device='cuda:0')
# test_ll_mc = tensor(-2.8089, device='cuda:0')
#
# 5000 test runs...
# rmse_mc = tensor(4.5470, device='cuda:0')
# rmse_non_mc = tensor(7.6633, device='cuda:0')
# test_ll_mc = tensor(-2.7935, device='cuda:0')
#
# 7000 test runs...
# rmse_mc = tensor(4.4830, device='cuda:0')
# rmse_non_mc = tensor(9.5071, device='cuda:0')
# test_ll_mc = tensor(-2.7883, device='cuda:0')
#
# 10000 test runs...
# rmse_mc = tensor(4.5280, device='cuda:0')
# rmse_non_mc = tensor(10.4419, device='cuda:0')
# test_ll_mc = tensor(-2.7929, device='cuda:0')
#
# training time = 17.227542877197266 seconds
# testing time (last set) = 3.0069682598114014 seconds
#
# Using downloaded and verified file: ./datasets_files/yacht/yacht_hydrodynamics.data
# subset size = (61, 6)
# training set size = 48
# test set size = 13
# FCNetMCDropout(
#   (input): Linear(in_features=6, out_features=50, bias=True)
#   (hidden_layers): ModuleList(
#     (0): Linear(in_features=50, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=50, bias=True)
#     (2): Linear(in_features=50, out_features=50, bias=True)
#   )
#   (output): Linear(in_features=50, out_features=1, bias=True)
# )
# Starting subset 0.200000, n_hidden 3, hidden_dim 50, dropout_rate 0.100000, reg_strength 0.025000
# final loss = 10.248918
# 10 test runs...
# rmse_mc = tensor(6.2342, device='cuda:0')
# rmse_non_mc = tensor(5.7588, device='cuda:0')
# test_ll_mc = tensor(-3.1851, device='cuda:0')
#
# 100 test runs...
# rmse_mc = tensor(6.5088, device='cuda:0')
# rmse_non_mc = tensor(6.5026, device='cuda:0')
# test_ll_mc = tensor(-3.1863, device='cuda:0')
#
# 1000 test runs...
# rmse_mc = tensor(6.5036, device='cuda:0')
# rmse_non_mc = tensor(6.3664, device='cuda:0')
# test_ll_mc = tensor(-3.1693, device='cuda:0')
#
# 3000 test runs...
# rmse_mc = tensor(6.5323, device='cuda:0')
# rmse_non_mc = tensor(7.4120, device='cuda:0')
# test_ll_mc = tensor(-3.1709, device='cuda:0')
#
# 5000 test runs...
# rmse_mc = tensor(6.5535, device='cuda:0')
# rmse_non_mc = tensor(5.0015, device='cuda:0')
# test_ll_mc = tensor(-3.1708, device='cuda:0')
#
# 7000 test runs...
# rmse_mc = tensor(6.5467, device='cuda:0')
# rmse_non_mc = tensor(7.7718, device='cuda:0')
# test_ll_mc = tensor(-3.1728, device='cuda:0')
#
# 10000 test runs...
# rmse_mc = tensor(6.5659, device='cuda:0')
# rmse_non_mc = tensor(7.4857, device='cuda:0')
# test_ll_mc = tensor(-3.1709, device='cuda:0')
#
# training time = 19.914940357208252 seconds
# testing time (last set) = 3.926805257797241 seconds
#
# Using downloaded and verified file: ./datasets_files/yacht/yacht_hydrodynamics.data
# subset size = (61, 6)
# training set size = 48
# test set size = 13
# FCNetMCDropout(
#   (input): Linear(in_features=6, out_features=50, bias=True)
#   (hidden_layers): ModuleList(
#     (0): Linear(in_features=50, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=50, bias=True)
#     (2): Linear(in_features=50, out_features=50, bias=True)
#   )
#   (output): Linear(in_features=50, out_features=1, bias=True)
# )
# Starting subset 0.200000, n_hidden 3, hidden_dim 50, dropout_rate 0.100000, reg_strength 0.050000
# final loss = 9.078115
# 10 test runs...
# rmse_mc = tensor(4.3852, device='cuda:0')
# rmse_non_mc = tensor(5.9595, device='cuda:0')
# test_ll_mc = tensor(-2.8014, device='cuda:0')
#
# 100 test runs...
# rmse_mc = tensor(3.9164, device='cuda:0')
# rmse_non_mc = tensor(8.2247, device='cuda:0')
# test_ll_mc = tensor(-2.7777, device='cuda:0')
#
# 1000 test runs...
# rmse_mc = tensor(3.8197, device='cuda:0')
# rmse_non_mc = tensor(4.1755, device='cuda:0')
# test_ll_mc = tensor(-2.7695, device='cuda:0')
#
# 3000 test runs...
# rmse_mc = tensor(3.8765, device='cuda:0')
# rmse_non_mc = tensor(4.0736, device='cuda:0')
# test_ll_mc = tensor(-2.7732, device='cuda:0')
#
# 5000 test runs...
# rmse_mc = tensor(3.8828, device='cuda:0')
# rmse_non_mc = tensor(5.4950, device='cuda:0')
# test_ll_mc = tensor(-2.7745, device='cuda:0')
#
# 7000 test runs...
# rmse_mc = tensor(3.8659, device='cuda:0')
# rmse_non_mc = tensor(4.0929, device='cuda:0')
# test_ll_mc = tensor(-2.7727, device='cuda:0')
#
# 10000 test runs...
# rmse_mc = tensor(3.8774, device='cuda:0')
# rmse_non_mc = tensor(4.1114, device='cuda:0')
# test_ll_mc = tensor(-2.7737, device='cuda:0')
#
# training time = 18.90549612045288 seconds
# testing time (last set) = 3.8131256103515625 seconds
#
# Using downloaded and verified file: ./datasets_files/yacht/yacht_hydrodynamics.data
# subset size = (61, 6)
# training set size = 48
# test set size = 13
# FCNetMCDropout(
#   (input): Linear(in_features=6, out_features=50, bias=True)
#   (hidden_layers): ModuleList(
#     (0): Linear(in_features=50, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=50, bias=True)
#     (2): Linear(in_features=50, out_features=50, bias=True)
#   )
#   (output): Linear(in_features=50, out_features=1, bias=True)
# )
# Starting subset 0.200000, n_hidden 3, hidden_dim 50, dropout_rate 0.100000, reg_strength 0.075000
# final loss = 19.713518
# 10 test runs...
# rmse_mc = tensor(5.1836, device='cuda:0')
# rmse_non_mc = tensor(5.7307, device='cuda:0')
# test_ll_mc = tensor(-2.7388, device='cuda:0')
#
# 100 test runs...
# rmse_mc = tensor(4.9316, device='cuda:0')
# rmse_non_mc = tensor(5.3282, device='cuda:0')
# test_ll_mc = tensor(-2.8123, device='cuda:0')
#
# 1000 test runs...
# rmse_mc = tensor(5.2527, device='cuda:0')
# rmse_non_mc = tensor(5.0452, device='cuda:0')
# test_ll_mc = tensor(-2.8465, device='cuda:0')
#
# 3000 test runs...
# rmse_mc = tensor(5.2598, device='cuda:0')
# rmse_non_mc = tensor(6.6522, device='cuda:0')
# test_ll_mc = tensor(-2.8495, device='cuda:0')
#
# 5000 test runs...
# rmse_mc = tensor(5.2795, device='cuda:0')
# rmse_non_mc = tensor(8.1887, device='cuda:0')
# test_ll_mc = tensor(-2.8548, device='cuda:0')
#
# 7000 test runs...
# rmse_mc = tensor(5.2391, device='cuda:0')
# rmse_non_mc = tensor(5.1650, device='cuda:0')
# test_ll_mc = tensor(-2.8447, device='cuda:0')
#
# 10000 test runs...
# rmse_mc = tensor(5.2678, device='cuda:0')
# rmse_non_mc = tensor(4.6821, device='cuda:0')
# test_ll_mc = tensor(-2.8494, device='cuda:0')
#
# training time = 18.92023205757141 seconds
# testing time (last set) = 3.947420120239258 seconds
#
# Using downloaded and verified file: ./datasets_files/yacht/yacht_hydrodynamics.data
# subset size = (61, 6)
# training set size = 48
# test set size = 13
# FCNetMCDropout(
#   (input): Linear(in_features=6, out_features=50, bias=True)
#   (hidden_layers): ModuleList(
#     (0): Linear(in_features=50, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=50, bias=True)
#     (2): Linear(in_features=50, out_features=50, bias=True)
#   )
#   (output): Linear(in_features=50, out_features=1, bias=True)
# )
# Starting subset 0.200000, n_hidden 3, hidden_dim 50, dropout_rate 0.300000, reg_strength 0.025000

# %% [markdown]
# ### Print statistics

# %%
# Copied from DropoutUncertaintyExps repo
print('non-MC RMSE %f +- %f (stddev) +- %f (std error), median %f 25p %f 75p %f \n' % (
        np.mean(rmse_non_mc), np.std(rmse_non_mc), np.std(rmse_non_mc)/np.sqrt(n_splits),
        np.percentile(rmse_non_mc, 50), np.percentile(rmse_non_mc, 25), np.percentile(rmse_non_mc, 75)))

print('MC RMSE %f +- %f (stddev) +- %f (std error), median %f 25p %f 75p %f \n' % (
        np.mean(rmse_mc), np.std(rmse_mc), np.std(rmse_mc)/np.sqrt(n_splits),
        np.percentile(rmse_mc, 50), np.percentile(rmse_mc, 25), np.percentile(rmse_mc, 75)))

print('MC Test Log-likelihood %f +- %f (stddev) +- %f (std error), median %f 25p %f 75p %f \n' % (
        np.mean(test_lls_mc), np.std(test_lls_mc), np.std(test_lls_mc)/np.sqrt(n_splits), 
        np.percentile(test_lls_mc, 50), np.percentile(test_lls_mc, 25), np.percentile(test_lls_mc, 75)))
